# %% [markdown]
# Preparing Data
# ==============

# %%
import json
import cPickle as pickle
import numpy as np
import pandas as pd
from pandas import factorize

# %%
# !ls bossa/*json
# Out:
# bossa/tasks_export.json  bossa/tasks_runs_export.json

# %% [markdown]
# BOSSA Results
# -------------

# %% [markdown]
# Processing `results_bossa.json` to get a *dictionary* with keys the task ids, and values in as the average value of the scores. To do that, we first convert scores from categorical (`neg`, `neu`, `pos`) to a numeric scale.

# %%
bossa_results = pd.read_json("bossa/tasks_runs_export.json")
bossa_results.rename(columns={"created": "start_time", "id": "result_id", "info": "score"}, inplace=True)
bossa_results[['start_time']]= bossa_results[['start_time']].apply(pd.to_datetime, dayfirst=True)
bossa_results[['finish_time']]= bossa_results[['finish_time']].apply(pd.to_datetime, dayfirst=True)
bossa_results['score'] = pd.Categorical(bossa_results['score'], categories=['vneg', 'neg', 'neu', 'pos', 'vpos'])
bossa_results['score'].cat.rename_categories([-2, -1, 0, 1, 2], inplace=True)
# Normalize everything to -1, 0, 1
# bossa_results['score'] = bossa_results['score'].astype(float).apply(lambda x: -1 if x < 0 else 1 if x > 0 else 0)
bossa_results["seconds"] = (bossa_results["finish_time"] - bossa_results["start_time"]).astype('timedelta64[us]') / 1e6
bossa_results = bossa_results[["result_id", "seconds", "task_id", "score"]]
bossa_results.ix[[50]]
# Out:
#     result_id   seconds  task_id score
# 50      11203  0.000025    52775     1

# %% [markdown]
# The information about the sentence comes in a dictionary inside the cells of the serie `info`, so we expand it.

# %%
bossa_tasks = pd.read_json("bossa/tasks_export.json")
bossa_tasks[['created']]= bossa_tasks[['created']].apply(pd.to_datetime, dayfirst=True)
bossa_tasks.rename(columns={'id': 'task_id'}, inplace=True)
bossa_tasks = bossa_tasks[['task_id', 'info']]
bossa_tasks.ix[[50]]
# Out:
#     task_id                                               info
# 50    52851  {u'search_words': u'founder', u'appears_in_sen...

# %% [markdown]
# And finally we merge the `DataFrame` with the scores with the one containing the sentences.

# %%
bossa_tasks_scores = pd.merge(bossa_results, bossa_tasks, on='task_id')
bossa_tasks_scores.ix[[50]]
# Out:
#     result_id   seconds  task_id  score  \
# 50      11195  0.000021    52776      2
#
#                                                  info
# 50  {u'search_words': u'executive', u'appears_in_s...

# %% [markdown]
# Let's now expand the column `info` into as many new columns as keys has the dictionary `info`.

# %%
bossa_tasks_scores.ix[50].info.keys()
# Out:
# [u'search_words',
#  u'appears_in_sentence',
#  u'url',
#  u'media',
#  u'appears_in_noun_phrases',
#  u'noun_phrases',
#  u'sentence_id',
#  u'text',
#  u'sentence',
#  u'pub_date',
#  u'is_company']

# %%
def json_to_series(info):
    keys, values = zip(*info.iteritems())
    return pd.Series(values, index=keys)

bossa_info = bossa_tasks_scores["info"].apply(json_to_series)
bossa_info.reset_index()
bossa = pd.concat([bossa_tasks_scores, bossa_info], axis=1)
bossa.pop("info")
# bossa['id'] = bossa['id'].astype(float)
bossa.ix[50:53]
# Out:
#     result_id   seconds  task_id  score search_words appears_in_sentence  \
# 50      11195  0.000021    52776      2    executive                   0
# 51      11205  0.000018    52776     -1    executive                   0
# 52      11207  0.000017    52776      1    executive                   0
# 53      11209  0.000017    52776     -2    executive                   0
#
#                                                   url media  \
# 50  http://dealbook.nytimes.com/2013/05/17/a-toeho...   nyt
# 51  http://dealbook.nytimes.com/2013/05/17/a-toeho...   nyt
# 52  http://dealbook.nytimes.com/2013/05/17/a-toeho...   nyt
# 53  http://dealbook.nytimes.com/2013/05/17/a-toeho...   nyt
#
#    appears_in_noun_phrases                                       noun_phrases  \
# 50                       0  [chinese investors, overseas companies, politi...
# 51                       0  [chinese investors, overseas companies, politi...
# 52                       0  [chinese investors, overseas companies, politi...
# 53                       0  [chinese investors, overseas companies, politi...
#
#    sentence_id                                               text  \
# 50          14  Chinese investors are increasingly opting to b...
# 51          14  Chinese investors are increasingly opting to b...
# 52          14  Chinese investors are increasingly opting to b...
# 53          14  Chinese investors are increasingly opting to b...
#
#                                              sentence              pub_date  \
# 50  Chinese investors are increasingly opting to b...  2013-05-17T11:47:51Z
# 51  Chinese investors are increasingly opting to b...  2013-05-17T11:47:51Z
# 52  Chinese investors are increasingly opting to b...  2013-05-17T11:47:51Z
# 53  Chinese investors are increasingly opting to b...  2013-05-17T11:47:51Z
#
#    is_company
# 50          0
# 51          0
# 52          0
# 53          0

# %% [markdown]
# Aggregate
# ---------

# %% [markdown]
# We now aggregate calculating the average per `sentence_id` using a group by. In the process, we lose the source of the data, that's why we first have to save it.

# %%
bossa.to_csv("sentiment/scores_ungrouped.csv", encoding="utf8")

# %% [markdown]
# Finally, we aggregate and create a new `DataFrame` for the different sentences and their score.

# %%
sentences = bossa.groupby(['sentence'])[['score']].aggregate(np.average)
sentences.to_csv("sentiment/scores.csv", encoding="utf8")
print sentences.count()
sentences[1001:1004]
# Out:
# score    8996
# dtype: int64
#                                                                                                                                                                                                                                                                                                score
# sentence
# 'We must hope after so much prevarication that this time Google's proposals represent a genuine attempt to address the concerns identified,' said David Wood, the legal counsel for Icomp, an industry group backed by Microsoft and a number of other companies.                          -0.333333
# 'We must push our leaders to step up and commit to action,' said Hugh Evans, the founder and chief executive of the charity.                                                                                                                                                               -0.285714
# 'We need them to tell the story of how we are making decisions and putting the organization together,' said George Postolos, the Astros' president and chief executive, who added that the team would not want a broadcaster who was uncomfortable explaining the front office's strategy. -0.666667

# %%
from collections import Counter

def majority(series): #receives a Pandas Series
    return Counter(map(lambda x: 1 if x > 0 else -1 if x < 0 else 0, series)).most_common(1)[0][0]

# score_calculate = np.average
score_calculate = majority

sentences = bossa.groupby(['sentence'])[['score']].aggregate(score_calculate)

# %% [markdown]
# Sentence Classifier
# -------------------

# %%
from nltk.corpus import stopwords
from sklearn.cross_validation import cross_val_score
from sklearn.grid_search import GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import precision_recall_fscore_support
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC

# %% [markdown]
# Create the tranining and testing sets (data and labels) from a randomized version of the set of assessed sentences.

# %%
sentences.reset_index().count()
# Out:
# sentence    8996
# score       8996
# dtype: int64

# %% [markdown]
# We could consider 3 classes, but it toruns out that using binary classficication seems to produce better results. Still, try multi-classs classifiers is something worth trying.

# %%
raw_scores = sentences.reset_index()
scores = raw_scores
scores = scores[scores.score!=0]  # We ignore the neutral sentences
scores['sentiment'] = scores['score'].apply(lambda s: 'pos' if s > 0 else 'neg')
# scores['sentiment'] = scores['score'].apply(lambda s: 'pos' if s > 0 else 'neg' if s < 0 else 0)

# percentage = 0.85  #  percentage for training, rest for for testing
# # We split to have enough representativenesss for both positive and negative sentiments
# sent_min = min(
#     scores[scores.sentiment=='pos'].sentiment.count(),
#     scores[scores.sentiment=='neg'].sentiment.count(),
# )
# scores = scores[["sentence", "sentiment"]]
# train_data = np.array([])
# train_labels = np.array([])
# test_data = np.array([])
# test_labels = np.array([])
# for sent in ('pos', 'neg'):
#     sent_scores = scores[scores['sentiment']==sent]
#     sent_scores = sent_scores.reindex(np.random.permutation(sent_scores.index))
#     sent_sentences_count = int(sent_scores['sentence'].count())
#     sent_train = sent_scores[["sentence", "sentiment"]][:int(sent_sentences_count * percentage)]
#     sent_test = sent_scores[["sentence", "sentiment"]][int(sent_sentences_count * percentage) + 1:]
#     print sent, sent_min, sent_train.sentiment.count(), sent_test.sentiment.count()
#     train_data = np.append(train_data, sent_train["sentence"])
#     train_labels = np.append(train_labels, sent_train["sentiment"])
#     test_data = np.append(test_data, sent_test["sentence"])
#     test_labels = np.append(test_labels, sent_test["sentiment"])
# Out:
# /home/antonio/.virtualenvs/lexisnexis/lib/python2.7/site-packages/IPython/kernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# #NLTK

# %%
document_df = scores[['sentence', 'sentiment']]
document_df = document_df.reindex(np.random.permutation(document_df.index))

# %%
document_df.head()
# Out:
#                                                sentence sentiment
# 5784  Nissan's Leaf still has a starting price less ...       pos
# 1759  An article on Friday about the financing for M...       pos
# 5319  Mr Sanusi, however, makes a distinction betwee...       pos
# 6724  Speaking to Reuters, the manager of the city's...       neg
# 1152  (DirecTV, Dish Network, Verizon, and AT&T were...       neg

# %%
original_documents = [(r[1]['sentence'], r[1]['sentiment']) for r in document_df.iterrows()]

# %%
pos_file = open('positive-words.txt')
all_pos_words = [w.strip().lower() for w in pos_file]

neg_file = open('negative-words.txt')
all_neg_words = [w.strip().lower() for w in neg_file]

# %%
search_terms_f = open('search_terms.txt')
search_terms = []
for t in search_terms_f:
    l = t.strip().split()
    search_terms.extend(l)

# %%
import string

import nltk
from nltk.corpus import stopwords

# %% [markdown]
# ###Options

# %%
#stopwords_english
stopwords_english = stopwords.words('english')
#stopwords_domain
stopwords_domain = search_terms + ["'s", '--']
#stopwords_english
punctuation = string.punctuation

# %%
def document_features1(document):      
    document_words = set(document)
    features = {}
    for word in word_features:
        features[word] = word in document_words
    return features

# %%
def document_features2(document):      
    document_words = list(document)
    features = {}
    for word in document_words:
        if word in word_features:
            features[word] = features.get(word, 0) + 1
    return features

# %%
def document_features3(document):
    word_features3 = list(pos_words) + list(neg_words)
    document_words = set(document)
    features = {}
    for word in word_features3:
        features[word] = word in document_words
    return features

# %%
# Filter stopwords, punctuation marks, and numbers
# 'stopwords_english': stopwords_english,
# 'stopwords_domain': stopwords_domain,
# 'punctuation': punctuation,
# 'numbers': True,
#
# Do not filter stopwords, punctuation marks, or numbers
# 'stopwords_english': [],
# 'stopwords_domain': [],
# 'punctuation': [],
# 'numbers': False,

options = {}

#Option 1
opt1 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[1] = opt1

#Option 2
opt2 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': [],
    'numbers': True,
}
options[2] = opt2

#Option 3
opt3 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': [],
    'punctuation': punctuation,
    'numbers': True,
}
options[3] = opt3

#Option 4
opt4 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[4] = opt4

#Option 5
opt5 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': True,
}
options[5] = opt5

#Option 6
opt6 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': punctuation,
    'numbers': True,
}
options[6] = opt6

#Option 7
opt7 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': stopwords_domain,
    'punctuation': [],
    'numbers': True,
}
options[7] = opt7

#Option 8
opt8 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': True,
}
options[8] = opt8

#Option 9
opt9 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': False,
}
options[9] = opt9

#Option 10
opt10 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': [],
    'numbers': False,
}
options[10] = opt10

#Option 11
opt11 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': [],
    'punctuation': punctuation,
    'numbers': False,
}
options[11] = opt11

#Option 12
opt12 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': False,
}
options[12] = opt12

#Option 13
opt13 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[13] = opt13

#Option 14
opt14 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': punctuation,
    'numbers': False,
}
options[14] = opt14

#Option 15
opt15 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': stopwords_domain,
    'punctuation': [],
    'numbers': False,
}
options[15] = opt15

#Option 16
opt16 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[16] = opt16

#Option 17
opt17 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': [],
    'punctuation': punctuation,
    'numbers': True,
}
options[17] = opt17

#Option 18
opt18 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': True,
}
options[18] = opt18

#Option 19
opt19 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': punctuation,
    'numbers': True,
}
options[19] = opt19

#Option 20
opt20 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': True,
}
options[20] = opt20

#Option 21
opt21 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': [],
    'punctuation': punctuation,
    'numbers': False,
}
options[21] = opt21

#Option 22
opt22 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[22] = opt22

#Option 23
opt23 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': punctuation,
    'numbers': False,
}
options[23] = opt23

#Option 24
opt24 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[24] = opt24

################################################################################################

#Option 25
opt25 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features2,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[25] = opt25

#Option 26
opt26 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features3,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[26] = opt26

#Option 27
opt27 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features2,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[27] = opt27

#Option 28
opt28 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features3,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[28] = opt28

#Option 29
opt29 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features2,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[29] = opt29

#Option 30
opt30 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features3,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[30] = opt30

################################################################################################

options = {}

#Option 
opt31 = {
    'length': 100,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[31] = opt31

#Option 
opt32 = {
    'length': 100,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features2,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[32] = opt32

#Option 
opt33 = {
    'length': 100,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features3,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[33] = opt33

#Option 
opt34 = {
    'length': 500,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[34] = opt34

#Option 
opt35 = {
    'length': 500,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features2,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[35] = opt35

#Option 
opt36 = {
    'length': 500,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features3,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[36] = opt36

#Option 
opt37 = {
    'length': 900,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[37] = opt37

#Option 
opt38 = {
    'length': 900,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features2,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[38] = opt38

#Option 
opt39 = {
    'length': 900,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features3,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[39] = opt39

#Option 
opt40 = {
    'length': 1100,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[40] = opt40

#Option 
opt41 = {
    'length': 1100,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features2,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[41] = opt41

#Option 
opt42 = {
    'length': 1100,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features3,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[42] = opt42

#Option 
opt43 = {
    'length': 1500,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[43] = opt43

#Option 
opt44 = {
    'length': 1500,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features2,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[44] = opt44

#Option 
opt45 = {
    'length': 1500,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features3,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[45] = opt45

#Option 
opt46 = {
    'length': 2000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[46] = opt46

#Option 
opt47 = {
    'length': 2000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features2,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[47] = opt47

#Option 
opt48 = {
    'length': 2000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features3,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[48] = opt48

#Option 
opt49 = {
    'length': 100,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[49] = opt49

#Option 
opt50 = {
    'length': 100,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features2,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[50] = opt50

#Option 
opt51 = {
    'length': 100,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features3,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[51] = opt51

#Option 
opt52 = {
    'length': 500,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[52] = opt52

#Option 
opt53 = {
    'length': 500,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features2,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[53] = opt53

#Option 
opt54 = {
    'length': 500,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features3,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[54] = opt54

#Option 
opt55 = {
    'length': 900,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[55] = opt55

#Option 
opt56 = {
    'length': 900,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features2,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[56] = opt56

#Option 
opt57 = {
    'length': 900,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features3,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[57] = opt57

#Option 
opt58 = {
    'length': 1100,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[58] = opt58

#Option 
opt59 = {
    'length': 1100,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features2,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[59] = opt59

#Option 
opt60 = {
    'length': 1100,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features3,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[60] = opt60

#Option 
opt61 = {
    'length': 1500,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[61] = opt61

#Option 
opt62 = {
    'length': 1500,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features2,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[62] = opt62

#Option 
opt63 = {
    'length': 1500,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features3,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[63] = opt63

#Option 
opt64 = {
    'length': 2000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[64] = opt64

#Option 
opt65 = {
    'length': 2000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features2,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[65] = opt65

#Option 
opt66 = {
    'length': 2000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features3,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[66] = opt66

# %%
def filt(x):
    c1 = x not in options[opt]['stopwords_english']
    c2 = x not in options[opt]['stopwords_domain']
    c3 = x not in options[opt]['punctuation']
    c4 = not x.isdigit() if options[opt]['numbers'] else True
    
    cs = [c1, c2, c3, c4]
    return all(cs)
 
def preprocess(text):
    text = text.lower()
    tokens = nltk.word_tokenize(text)
    filtered_words = filter(filt, tokens)
    return filtered_words

def print_option(opt):
    d = dict(opt)
    for k in d:
        if (type(d[k]) == list or type(d[k]) == str) and len(d[k]) > 0:
            d[k] = ['...']
        elif hasattr(d[k], '__call__'):
            d[k] = d[k].func_name
    print(d)

# %%
#%%prun -l4
from collections import defaultdict
from random import shuffle

best_option = None
best_accuracy = 0
best_index = 0
d_accuracies = defaultdict(list)

all_words = [w.lower() for d in original_documents for w in nltk.word_tokenize(d[0])]

for i in range(10):
    shuffle(original_documents)
    for opt in options:
        print('=======================================================')
        print('RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:')
        print('\nOption {}'.format(opt))
        print_option(options[opt])
        print(score_calculate.func_name)
        print('\niteration: {}\n'.format(i))
        
        documents = [(preprocess(d[0]), d[1]) for d in original_documents]
        filtered_words = filter(filt, all_words)
        freq_dist = nltk.FreqDist(filtered_words)
        most_common_words = [word for word, freq in freq_dist.most_common()]
        most_common_words = filter(filt, most_common_words)

        if options[opt]['stopwords_domain_in_features']:
            most_common_words = list(set(most_common_words).difference(search_terms))
        if options[opt]['reverse']:
            most_common_words.reverse()
        
        word_features = most_common_words[:options[opt]['length']]
        print('----------------')
        print('Total features:')
        print(options[opt]['length'])
        print('Top 10 features:')
        print(word_features[:10])
        print('----------------')

        if options[opt]['document_features'] == document_features3:
            pos_words = set(all_pos_words).intersection(word_features)
            print('Total positive words:')
            print(len(pos_words))
            print('Top 10 positive words:')
            print list(pos_words)[:10]

            neg_words = set(all_neg_words).intersection(word_features)
            print('Total negative words:')
            print(len(neg_words))
            print('Top 10 negative words:')
            print list(neg_words)[:10]

        featureset = [(options[opt]['document_features'](d[0]), d[1]) for d in documents]
        size = int(len(featureset) * 0.9)
        train_set = featureset[:size]
        test_set = featureset[size:]

        classifier = nltk.NaiveBayesClassifier.train(train_set)
        accuracy = nltk.classify.accuracy(classifier, test_set)
        print('****************')
        print('ACCURACY = {}'.format(accuracy))
        print('****************')
        classifier.show_most_informative_features(10)
        print('\n\n\n\n\n')
        d_accuracies[opt].append(accuracy)

        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_option = options[opt]
            best_index = opt

print('**************** BEST RESULT ****************')
print('BEST OPTION: {}'.format(best_index))
print(best_option)
print('ACCURACY =', best_accuracy)
print('*********************************************')
# Out:
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 31
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 100, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 100
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'last']
# ----------------
# ****************
# ACCURACY = 0.658573596358
# ****************
# Most Informative Features
#                     news = True              neg : pos    =      2.4 : 1.0
#                     even = True              neg : pos    =      2.1 : 1.0
#               government = True              neg : pos    =      2.0 : 1.0
#                      may = True              neg : pos    =      2.0 : 1.0
#                      n't = True              neg : pos    =      1.8 : 1.0
#                 products = True              pos : neg    =      1.8 : 1.0
#                     much = True              neg : pos    =      1.8 : 1.0
#                    first = True              pos : neg    =      1.8 : 1.0
#                   mobile = True              pos : neg    =      1.8 : 1.0
#                  another = True              neg : pos    =      1.7 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 32
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 100, 'numbers': True, 'document_features': 'document_features2', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 100
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'last']
# ----------------
# ****************
# ACCURACY = 0.64339908953
# ****************
# Most Informative Features
#               government = 2                 neg : pos    =      6.0 : 1.0
#                     bank = 2                 neg : pos    =      4.9 : 1.0
#                       '' = 2                 neg : pos    =      4.7 : 1.0
#                   google = 2                 pos : neg    =      3.5 : 1.0
#                     firm = 2                 neg : pos    =      3.3 : 1.0
#                investors = 2                 neg : pos    =      3.3 : 1.0
#                 business = 2                 pos : neg    =      3.2 : 1.0
#                       `` = 2                 neg : pos    =      3.1 : 1.0
#                      one = 2                 pos : neg    =      2.8 : 1.0
#                   agency = 2                 neg : pos    =      2.6 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 33
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 100, 'numbers': True, 'document_features': 'document_features3', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 100
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'last']
# ----------------
# Total positive words:
# 3
# Top 10 positive words:
# [u'work', u'well', u'like']
# Total negative words:
# 1
# Top 10 negative words:
# [u'vice']
# ****************
# ACCURACY = 0.66464339909
# ****************
# Most Informative Features
#                     vice = True              pos : neg    =      1.4 : 1.0
#                     like = True              neg : pos    =      1.3 : 1.0
#                     well = True              pos : neg    =      1.1 : 1.0
#                     work = True              pos : neg    =      1.0 : 1.0
#                     like = False             pos : neg    =      1.0 : 1.0
#                     vice = False             neg : pos    =      1.0 : 1.0
#                     well = False             neg : pos    =      1.0 : 1.0
#                     work = False             neg : pos    =      1.0 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 34
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 500, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 500
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'last']
# ----------------
# ****************
# ACCURACY = 0.694992412747
# ****************
# Most Informative Features
#                     rose = True              pos : neg    =      7.3 : 1.0
#            investigation = True              neg : pos    =      6.0 : 1.0
#                     fell = True              neg : pos    =      4.1 : 1.0
#                      cut = True              neg : pos    =      4.1 : 1.0
#                  founded = True              pos : neg    =      3.8 : 1.0
#                     paid = True              neg : pos    =      3.7 : 1.0
#                      tax = True              neg : pos    =      3.6 : 1.0
#                education = True              pos : neg    =      3.5 : 1.0
#                   brands = True              pos : neg    =      3.3 : 1.0
#                 creative = True              pos : neg    =      3.1 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 35
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 500, 'numbers': True, 'document_features': 'document_features2', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 500
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'last']
# ----------------
# ****************
# ACCURACY = 0.682852807284
# ****************
# Most Informative Features
#                     rose = 1                 pos : neg    =      6.9 : 1.0
#               government = 2                 neg : pos    =      6.0 : 1.0
#                      tax = 2                 neg : pos    =      6.0 : 1.0
#            investigation = 1                 neg : pos    =      5.5 : 1.0
#                     bank = 2                 neg : pos    =      4.9 : 1.0
#                   health = 2                 neg : pos    =      4.7 : 1.0
#                     used = 2                 neg : pos    =      4.7 : 1.0
#                 european = 2                 neg : pos    =      4.7 : 1.0
#                       '' = 2                 neg : pos    =      4.7 : 1.0
#                  trading = 2                 neg : pos    =      4.7 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 36
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 500, 'numbers': True, 'document_features': 'document_features3', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 500
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'last']
# ----------------
# Total positive words:
# 23
# Top 10 positive words:
# [u'right', u'helped', u'best', u'lead', u'leading', u'top', u'creative', u'better', u'enough', u'available']
# Total negative words:
# 7
# Top 10 negative words:
# [u'vice', u'problems', u'fell', u'hedge', u'issue', u'problem', u'issues']
# ****************
# ACCURACY = 0.673748103187
# ****************
# Most Informative Features
#                     fell = True              neg : pos    =      4.1 : 1.0
#                 creative = True              pos : neg    =      3.1 : 1.0
#                    right = True              pos : neg    =      3.1 : 1.0
#                   helped = True              pos : neg    =      3.0 : 1.0
#                     best = True              pos : neg    =      2.9 : 1.0
#                 problems = True              neg : pos    =      2.5 : 1.0
#                  problem = True              neg : pos    =      2.4 : 1.0
#                important = True              pos : neg    =      2.4 : 1.0
#                     free = True              pos : neg    =      2.3 : 1.0
#                   strong = True              pos : neg    =      2.2 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 37
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 900, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 900
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'last']
# ----------------
# ****************
# ACCURACY = 0.690440060698
# ****************
# Most Informative Features
#                 declined = True              neg : pos    =     10.4 : 1.0
#                  comment = True              neg : pos    =      8.9 : 1.0
#                    force = True              neg : pos    =      8.2 : 1.0
#                     bowl = True              pos : neg    =      7.8 : 1.0
#                    built = True              pos : neg    =      7.5 : 1.0
#                     rose = True              pos : neg    =      7.3 : 1.0
#                   crisis = True              neg : pos    =      6.9 : 1.0
#                    space = True              pos : neg    =      6.8 : 1.0
#               securities = True              neg : pos    =      6.0 : 1.0
#            investigation = True              neg : pos    =      6.0 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 38
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 900, 'numbers': True, 'document_features': 'document_features2', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 900
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'last']
# ----------------
# ****************
# ACCURACY = 0.669195751138
# ****************
# Most Informative Features
#                 declined = 1                 neg : pos    =     10.4 : 1.0
#                  comment = 1                 neg : pos    =      8.9 : 1.0
#                    force = 1                 neg : pos    =      8.2 : 1.0
#                     bowl = 1                 pos : neg    =      7.5 : 1.0
#                    built = 1                 pos : neg    =      7.5 : 1.0
#                   crisis = 1                 neg : pos    =      6.9 : 1.0
#                     rose = 1                 pos : neg    =      6.9 : 1.0
#                    gates = 1                 pos : neg    =      6.5 : 1.0
#                    space = 1                 pos : neg    =      6.2 : 1.0
#               securities = 1                 neg : pos    =      6.0 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 39
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 900, 'numbers': True, 'document_features': 'document_features3', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 900
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'last']
# ----------------
# Total positive words:
# 36
# Top 10 positive words:
# [u'right', u'love', u'win', u'modern', u'helped', u'best', u'lead', u'leading', u'top', u'fans']
# Total negative words:
# 18
# Top 10 negative words:
# [u'criminal', u'risk', u'lost', u'vice', u'concerns', u'rival', u'hard', u'problems', u'crisis', u'bad']
# ****************
# ACCURACY = 0.685887708649
# ****************
# Most Informative Features
#                   crisis = True              neg : pos    =      6.9 : 1.0
#                     debt = True              neg : pos    =      5.7 : 1.0
#                    super = True              pos : neg    =      5.7 : 1.0
#                      win = True              pos : neg    =      5.5 : 1.0
#                 criminal = True              neg : pos    =      5.1 : 1.0
#                     lost = True              neg : pos    =      4.1 : 1.0
#                     fell = True              neg : pos    =      4.1 : 1.0
#                 positive = True              pos : neg    =      4.1 : 1.0
#                     died = True              neg : pos    =      3.9 : 1.0
#                    clear = True              neg : pos    =      3.4 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 40
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1100, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1100
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'last']
# ----------------
# ****************
# ACCURACY = 0.685887708649
# ****************
# Most Informative Features
#                 declined = True              neg : pos    =     10.4 : 1.0
#                  comment = True              neg : pos    =      8.9 : 1.0
#                    force = True              neg : pos    =      8.2 : 1.0
#                     bowl = True              pos : neg    =      7.8 : 1.0
#                    built = True              pos : neg    =      7.5 : 1.0
#                     rose = True              pos : neg    =      7.3 : 1.0
#                   crisis = True              neg : pos    =      6.9 : 1.0
#                    space = True              pos : neg    =      6.8 : 1.0
#                  dropped = True              neg : pos    =      6.5 : 1.0
#               securities = True              neg : pos    =      6.0 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 41
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1100, 'numbers': True, 'document_features': 'document_features2', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1100
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'last']
# ----------------
# ****************
# ACCURACY = 0.676783004552
# ****************
# Most Informative Features
#                 declined = 1                 neg : pos    =     10.4 : 1.0
#                  comment = 1                 neg : pos    =      8.9 : 1.0
#                    force = 1                 neg : pos    =      8.2 : 1.0
#                     bowl = 1                 pos : neg    =      7.5 : 1.0
#                    built = 1                 pos : neg    =      7.5 : 1.0
#                   crisis = 1                 neg : pos    =      6.9 : 1.0
#                     rose = 1                 pos : neg    =      6.9 : 1.0
#                    gates = 1                 pos : neg    =      6.5 : 1.0
#                  dropped = 1                 neg : pos    =      6.5 : 1.0
#                    space = 1                 pos : neg    =      6.2 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 42
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1100, 'numbers': True, 'document_features': 'document_features3', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1100
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'last']
# ----------------
# Total positive words:
# 40
# Top 10 positive words:
# [u'right', u'love', u'win', u'modern', u'helped', u'best', u'lead', u'leading', u'top', u'fans']
# Total negative words:
# 23
# Top 10 negative words:
# [u'hard', u'crisis', u'issues', u'death', u'failed', u'concerns', u'struggling', u'criminal', u'issue', u'risk']
# ****************
# ACCURACY = 0.687405159332
# ****************
# Most Informative Features
#                   crisis = True              neg : pos    =      6.9 : 1.0
#                     debt = True              neg : pos    =      5.7 : 1.0
#                    super = True              pos : neg    =      5.7 : 1.0
#                      win = True              pos : neg    =      5.5 : 1.0
#                 criminal = True              neg : pos    =      5.1 : 1.0
#                emergency = True              neg : pos    =      4.6 : 1.0
#                     lost = True              neg : pos    =      4.1 : 1.0
#                     fell = True              neg : pos    =      4.1 : 1.0
#                 positive = True              pos : neg    =      4.1 : 1.0
#                     died = True              neg : pos    =      3.9 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 43
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1500, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1500
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'last']
# ----------------
# ****************
# ACCURACY = 0.699544764795
# ****************
# Most Informative Features
#                 declined = True              neg : pos    =     10.4 : 1.0
#                  comment = True              neg : pos    =      8.9 : 1.0
#                    force = True              neg : pos    =      8.2 : 1.0
#                     bowl = True              pos : neg    =      7.8 : 1.0
#                    built = True              pos : neg    =      7.5 : 1.0
#                     rose = True              pos : neg    =      7.3 : 1.0
#                   crisis = True              neg : pos    =      6.9 : 1.0
#                    space = True              pos : neg    =      6.8 : 1.0
#                   forced = True              neg : pos    =      6.6 : 1.0
#                  dropped = True              neg : pos    =      6.5 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 44
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1500, 'numbers': True, 'document_features': 'document_features2', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1500
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'last']
# ----------------
# ****************
# ACCURACY = 0.670713201821
# ****************
# Most Informative Features
#                 declined = 1                 neg : pos    =     10.4 : 1.0
#                  comment = 1                 neg : pos    =      8.9 : 1.0
#                    force = 1                 neg : pos    =      8.2 : 1.0
#                     bowl = 1                 pos : neg    =      7.5 : 1.0
#                    built = 1                 pos : neg    =      7.5 : 1.0
#                   crisis = 1                 neg : pos    =      6.9 : 1.0
#                     rose = 1                 pos : neg    =      6.9 : 1.0
#                   forced = 1                 neg : pos    =      6.6 : 1.0
#                    gates = 1                 pos : neg    =      6.5 : 1.0
#                  dropped = 1                 neg : pos    =      6.5 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 45
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1500, 'numbers': True, 'document_features': 'document_features3', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1500
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'last']
# ----------------
# Total positive words:
# 64
# Top 10 positive words:
# [u'right', u'love', u'fair', u'win', u'modern', u'powerful', u'helped', u'likes', u'ready', u'trust']
# Total negative words:
# 31
# Top 10 negative words:
# [u'limited', u'hard', u'crisis', u'issues', u'death', u'failed', u'expensive', u'concerns', u'cloud', u'prison']
# ****************
# ACCURACY = 0.684370257967
# ****************
# Most Informative Features
#                   crisis = True              neg : pos    =      6.9 : 1.0
#                     debt = True              neg : pos    =      5.7 : 1.0
#                    super = True              pos : neg    =      5.7 : 1.0
#                   losses = True              neg : pos    =      5.6 : 1.0
#                      win = True              pos : neg    =      5.5 : 1.0
#                 criminal = True              neg : pos    =      5.1 : 1.0
#                emergency = True              neg : pos    =      4.6 : 1.0
#                     lost = True              neg : pos    =      4.1 : 1.0
#                     fell = True              neg : pos    =      4.1 : 1.0
#                 positive = True              pos : neg    =      4.1 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 46
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 2000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 2000
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'last']
# ----------------
# ****************
# ACCURACY = 0.717754172989
# ****************
# Most Informative Features
#                difficult = True              neg : pos    =     12.7 : 1.0
#                 declined = True              neg : pos    =     10.4 : 1.0
#                  comment = True              neg : pos    =      8.9 : 1.0
#                    force = True              neg : pos    =      8.2 : 1.0
#                     bowl = True              pos : neg    =      7.8 : 1.0
#                    built = True              pos : neg    =      7.5 : 1.0
#               conditions = True              neg : pos    =      7.3 : 1.0
#                     rose = True              pos : neg    =      7.3 : 1.0
#                   crisis = True              neg : pos    =      6.9 : 1.0
#                    space = True              pos : neg    =      6.8 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 47
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 2000, 'numbers': True, 'document_features': 'document_features2', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 2000
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'last']
# ----------------
# ****************
# ACCURACY = 0.676783004552
# ****************
# Most Informative Features
#                difficult = 1                 neg : pos    =     12.7 : 1.0
#                 declined = 1                 neg : pos    =     10.4 : 1.0
#                  comment = 1                 neg : pos    =      8.9 : 1.0
#                    force = 1                 neg : pos    =      8.2 : 1.0
#                     bowl = 1                 pos : neg    =      7.5 : 1.0
#                    built = 1                 pos : neg    =      7.5 : 1.0
#               conditions = 1                 neg : pos    =      7.3 : 1.0
#                   crisis = 1                 neg : pos    =      6.9 : 1.0
#                     rose = 1                 pos : neg    =      6.9 : 1.0
#                   guilty = 1                 neg : pos    =      6.8 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 48
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 2000, 'numbers': True, 'document_features': 'document_features3', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 2000
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'last']
# ----------------
# Total positive words:
# 86
# Top 10 positive words:
# [u'gold', u'competitive', u'fine', u'enough', u'better', u'willing', u'easy', u'worth', u'smart', u'good']
# Total negative words:
# 54
# Top 10 negative words:
# [u'fake', u'limited', u'criticized', u'hard', u'negative', u'bribery', u'falling', u'aggressive', u'conservative', u'crisis']
# ****************
# ACCURACY = 0.696509863429
# ****************
# Most Informative Features
#                difficult = True              neg : pos    =     12.7 : 1.0
#                   crisis = True              neg : pos    =      6.9 : 1.0
#                   guilty = True              neg : pos    =      6.8 : 1.0
#                   warned = True              neg : pos    =      6.8 : 1.0
#                     debt = True              neg : pos    =      5.7 : 1.0
#                    super = True              pos : neg    =      5.7 : 1.0
#                   losses = True              neg : pos    =      5.6 : 1.0
#                      win = True              pos : neg    =      5.5 : 1.0
#                     sued = True              neg : pos    =      5.2 : 1.0
#                 criminal = True              neg : pos    =      5.1 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 49
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 100, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 100
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# ****************
# ACCURACY = 0.667678300455
# ****************
# Most Informative Features
#                      not = True              neg : pos    =      2.1 : 1.0
#                      n't = True              neg : pos    =      1.8 : 1.0
#                     were = True              neg : pos    =      1.6 : 1.0
#                        . = False             neg : pos    =      1.5 : 1.0
#             entrepreneur = True              pos : neg    =      1.5 : 1.0
#                      had = True              neg : pos    =      1.4 : 1.0
#                  percent = True              neg : pos    =      1.4 : 1.0
#                      but = True              neg : pos    =      1.4 : 1.0
#                    after = True              neg : pos    =      1.4 : 1.0
#                      you = True              pos : neg    =      1.4 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 50
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 100, 'numbers': False, 'document_features': 'document_features2', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 100
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# ****************
# ACCURACY = 0.650986342944
# ****************
# Most Informative Features
#                      but = 2                 neg : pos    =      6.0 : 1.0
#                      not = 3                 neg : pos    =      4.7 : 1.0
#                        a = 7                 neg : pos    =      4.4 : 1.0
#                   google = 2                 pos : neg    =      3.5 : 1.0
#                executive = 3                 neg : pos    =      3.3 : 1.0
#                       in = 6                 neg : pos    =      3.3 : 1.0
#                       of = 8                 neg : pos    =      3.3 : 1.0
#                 business = 2                 pos : neg    =      3.2 : 1.0
#                    which = 2                 pos : neg    =      2.9 : 1.0
#                      one = 2                 pos : neg    =      2.8 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 51
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 100, 'numbers': False, 'document_features': 'document_features3', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 100
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# Total positive words:
# 1
# Top 10 positive words:
# [u'like']
# Total negative words:
# 0
# Top 10 negative words:
# []
# ****************
# ACCURACY = 0.66464339909
# ****************
# Most Informative Features
#                     like = True              neg : pos    =      1.3 : 1.0
#                     like = False             pos : neg    =      1.0 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 52
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 500, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 500
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# ****************
# ACCURACY = 0.672230652504
# ****************
# Most Informative Features
#                   brands = True              pos : neg    =      3.3 : 1.0
#                    right = True              pos : neg    =      3.1 : 1.0
#              advertising = True              pos : neg    =      3.0 : 1.0
#                   helped = True              pos : neg    =      3.0 : 1.0
#                     help = True              pos : neg    =      2.9 : 1.0
#                     best = True              pos : neg    =      2.9 : 1.0
#                    brand = True              pos : neg    =      2.9 : 1.0
#                     told = True              neg : pos    =      2.7 : 1.0
#                    north = True              pos : neg    =      2.7 : 1.0
#                      app = True              pos : neg    =      2.7 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 53
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 500, 'numbers': False, 'document_features': 'document_features2', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 500
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# ****************
# ACCURACY = 0.638846737481
# ****************
# Most Informative Features
#                      but = 2                 neg : pos    =      6.0 : 1.0
#               government = 2                 neg : pos    =      6.0 : 1.0
#                     bank = 2                 neg : pos    =      4.9 : 1.0
#                   health = 2                 neg : pos    =      4.7 : 1.0
#                     used = 2                 neg : pos    =      4.7 : 1.0
#                      not = 3                 neg : pos    =      4.7 : 1.0
#                 european = 2                 neg : pos    =      4.7 : 1.0
#                       '' = 2                 neg : pos    =      4.7 : 1.0
#                  trading = 2                 neg : pos    =      4.7 : 1.0
#                        a = 7                 neg : pos    =      4.4 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 54
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 500, 'numbers': False, 'document_features': 'document_features3', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 500
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# Total positive words:
# 14
# Top 10 positive words:
# [u'available', u'helped', u'great', u'good', u'led', u'like', u'top', u'work', u'well', u'better']
# Total negative words:
# 3
# Top 10 negative words:
# [u'hedge', u'problems', u'vice']
# ****************
# ACCURACY = 0.663125948407
# ****************
# Most Informative Features
#                    right = True              pos : neg    =      3.1 : 1.0
#                   helped = True              pos : neg    =      3.0 : 1.0
#                     best = True              pos : neg    =      2.9 : 1.0
#                 problems = True              neg : pos    =      2.5 : 1.0
#                    works = True              pos : neg    =      1.8 : 1.0
#                   better = True              pos : neg    =      1.7 : 1.0
#                    great = True              pos : neg    =      1.6 : 1.0
#                available = True              pos : neg    =      1.5 : 1.0
#                   worked = True              pos : neg    =      1.5 : 1.0
#                     vice = True              pos : neg    =      1.4 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 55
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 900, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 900
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# ****************
# ACCURACY = 0.685887708649
# ****************
# Most Informative Features
#                 declined = True              neg : pos    =     10.4 : 1.0
#                  comment = True              neg : pos    =      8.9 : 1.0
#                     rose = True              pos : neg    =      7.3 : 1.0
#                   crisis = True              neg : pos    =      6.9 : 1.0
#            investigation = True              neg : pos    =      6.0 : 1.0
#                    super = True              pos : neg    =      5.7 : 1.0
#                    gates = True              pos : neg    =      4.3 : 1.0
#                     lost = True              neg : pos    =      4.1 : 1.0
#                     fell = True              neg : pos    =      4.1 : 1.0
#                      cut = True              neg : pos    =      4.1 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 56
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 900, 'numbers': False, 'document_features': 'document_features2', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 900
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# ****************
# ACCURACY = 0.640364188164
# ****************
# Most Informative Features
#                 declined = 1                 neg : pos    =     10.4 : 1.0
#                  comment = 1                 neg : pos    =      8.9 : 1.0
#                   crisis = 1                 neg : pos    =      6.9 : 1.0
#                     rose = 1                 pos : neg    =      6.9 : 1.0
#                    gates = 1                 pos : neg    =      6.5 : 1.0
#               government = 2                 neg : pos    =      6.0 : 1.0
#                      but = 2                 neg : pos    =      6.0 : 1.0
#                      tax = 2                 neg : pos    =      6.0 : 1.0
#            investigation = 1                 neg : pos    =      5.5 : 1.0
#                    super = 1                 pos : neg    =      5.5 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 57
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 900, 'numbers': False, 'document_features': 'document_features3', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 900
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# Total positive words:
# 28
# Top 10 positive words:
# [u'right', u'helped', u'best', u'lead', u'leading', u'top', u'creative', u'better', u'enough', u'won']
# Total negative words:
# 14
# Top 10 negative words:
# [u'risk', u'lost', u'vice', u'rival', u'hard', u'problems', u'crisis', u'fell', u'died', u'fall']
# ****************
# ACCURACY = 0.675265553869
# ****************
# Most Informative Features
#                   crisis = True              neg : pos    =      6.9 : 1.0
#                    super = True              pos : neg    =      5.7 : 1.0
#                     lost = True              neg : pos    =      4.1 : 1.0
#                     fell = True              neg : pos    =      4.1 : 1.0
#                     died = True              neg : pos    =      3.9 : 1.0
#                 creative = True              pos : neg    =      3.1 : 1.0
#                    right = True              pos : neg    =      3.1 : 1.0
#                   helped = True              pos : neg    =      3.0 : 1.0
#                     best = True              pos : neg    =      2.9 : 1.0
#                 problems = True              neg : pos    =      2.5 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 58
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1100, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1100
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# ****************
# ACCURACY = 0.708649468892
# ****************
# Most Informative Features
#                 declined = True              neg : pos    =     10.4 : 1.0
#                  comment = True              neg : pos    =      8.9 : 1.0
#                    force = True              neg : pos    =      8.2 : 1.0
#                     bowl = True              pos : neg    =      7.8 : 1.0
#                    built = True              pos : neg    =      7.5 : 1.0
#                     rose = True              pos : neg    =      7.3 : 1.0
#                   crisis = True              neg : pos    =      6.9 : 1.0
#                    space = True              pos : neg    =      6.8 : 1.0
#               securities = True              neg : pos    =      6.0 : 1.0
#            investigation = True              neg : pos    =      6.0 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 59
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1100, 'numbers': False, 'document_features': 'document_features2', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1100
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# ****************
# ACCURACY = 0.638846737481
# ****************
# Most Informative Features
#                 declined = 1                 neg : pos    =     10.4 : 1.0
#                  comment = 1                 neg : pos    =      8.9 : 1.0
#                    force = 1                 neg : pos    =      8.2 : 1.0
#                     bowl = 1                 pos : neg    =      7.5 : 1.0
#                    built = 1                 pos : neg    =      7.5 : 1.0
#                   crisis = 1                 neg : pos    =      6.9 : 1.0
#                     rose = 1                 pos : neg    =      6.9 : 1.0
#                    gates = 1                 pos : neg    =      6.5 : 1.0
#                    space = 1                 pos : neg    =      6.2 : 1.0
#               securities = 1                 neg : pos    =      6.0 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 60
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1100, 'numbers': False, 'document_features': 'document_features3', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1100
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# Total positive words:
# 36
# Top 10 positive words:
# [u'right', u'love', u'modern', u'helped', u'best', u'lead', u'leading', u'top', u'fans', u'creative']
# Total negative words:
# 18
# Top 10 negative words:
# [u'criminal', u'risk', u'lost', u'vice', u'concerns', u'rival', u'hard', u'problems', u'crisis', u'bad']
# ****************
# ACCURACY = 0.685887708649
# ****************
# Most Informative Features
#                   crisis = True              neg : pos    =      6.9 : 1.0
#                     debt = True              neg : pos    =      5.7 : 1.0
#                    super = True              pos : neg    =      5.7 : 1.0
#                 criminal = True              neg : pos    =      5.1 : 1.0
#                     lost = True              neg : pos    =      4.1 : 1.0
#                     fell = True              neg : pos    =      4.1 : 1.0
#                 positive = True              pos : neg    =      4.1 : 1.0
#                     died = True              neg : pos    =      3.9 : 1.0
#                    clear = True              neg : pos    =      3.4 : 1.0
#                 creative = True              pos : neg    =      3.1 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 61
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1500, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1500
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# ****************
# ACCURACY = 0.704097116844
# ****************
# Most Informative Features
#                 declined = True              neg : pos    =     10.4 : 1.0
#                  comment = True              neg : pos    =      8.9 : 1.0
#                    force = True              neg : pos    =      8.2 : 1.0
#                     bowl = True              pos : neg    =      7.8 : 1.0
#                    built = True              pos : neg    =      7.5 : 1.0
#                     rose = True              pos : neg    =      7.3 : 1.0
#                   crisis = True              neg : pos    =      6.9 : 1.0
#                    space = True              pos : neg    =      6.8 : 1.0
#                  dropped = True              neg : pos    =      6.5 : 1.0
#               securities = True              neg : pos    =      6.0 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 62
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1500, 'numbers': False, 'document_features': 'document_features2', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1500
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# ****************
# ACCURACY = 0.663125948407
# ****************
# Most Informative Features
#                 declined = 1                 neg : pos    =     10.4 : 1.0
#                  comment = 1                 neg : pos    =      8.9 : 1.0
#                    force = 1                 neg : pos    =      8.2 : 1.0
#                     bowl = 1                 pos : neg    =      7.5 : 1.0
#                    built = 1                 pos : neg    =      7.5 : 1.0
#                   crisis = 1                 neg : pos    =      6.9 : 1.0
#                     rose = 1                 pos : neg    =      6.9 : 1.0
#                    gates = 1                 pos : neg    =      6.5 : 1.0
#                  dropped = 1                 neg : pos    =      6.5 : 1.0
#                    space = 1                 pos : neg    =      6.2 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 63
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1500, 'numbers': False, 'document_features': 'document_features3', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1500
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# Total positive words:
# 53
# Top 10 positive words:
# [u'right', u'love', u'win', u'modern', u'powerful', u'helped', u'likes', u'trust', u'best', u'lead']
# Total negative words:
# 25
# Top 10 negative words:
# [u'hard', u'crisis', u'issues', u'death', u'failed', u'concerns', u'struggling', u'criminal', u'issue', u'poor']
# ****************
# ACCURACY = 0.687405159332
# ****************
# Most Informative Features
#                   crisis = True              neg : pos    =      6.9 : 1.0
#                     debt = True              neg : pos    =      5.7 : 1.0
#                    super = True              pos : neg    =      5.7 : 1.0
#                   losses = True              neg : pos    =      5.6 : 1.0
#                      win = True              pos : neg    =      5.5 : 1.0
#                 criminal = True              neg : pos    =      5.1 : 1.0
#                emergency = True              neg : pos    =      4.6 : 1.0
#                     lost = True              neg : pos    =      4.1 : 1.0
#                     fell = True              neg : pos    =      4.1 : 1.0
#                 positive = True              pos : neg    =      4.1 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 64
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 2000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 2000
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# ****************
# ACCURACY = 0.710166919575
# ****************
# Most Informative Features
#                difficult = True              neg : pos    =     12.7 : 1.0
#                 declined = True              neg : pos    =     10.4 : 1.0
#                  comment = True              neg : pos    =      8.9 : 1.0
#                    force = True              neg : pos    =      8.2 : 1.0
#                     bowl = True              pos : neg    =      7.8 : 1.0
#                    built = True              pos : neg    =      7.5 : 1.0
#                     rose = True              pos : neg    =      7.3 : 1.0
# ...
#            investigation = True              neg : pos    =      6.0 : 1.0
#                  charges = True              neg : pos    =      5.6 : 1.0
#                     died = True              neg : pos    =      5.5 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 59
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1100, 'numbers': False, 'document_features': 'document_features2', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 9
#
# ----------------
# Total features:
# 1100
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# ****************
# ACCURACY = 0.628224582701
# ****************
# Most Informative Features
#                 criminal = 1                 neg : pos    =      8.9 : 1.0
#                  comment = 1                 neg : pos    =      8.6 : 1.0
#                    force = 1                 neg : pos    =      7.3 : 1.0
#                     debt = 1                 neg : pos    =      6.7 : 1.0
#                     rose = 1                 pos : neg    =      6.7 : 1.0
#                 positive = 1                 pos : neg    =      6.5 : 1.0
#                 declined = 1                 neg : pos    =      6.3 : 1.0
#                       '' = 2                 neg : pos    =      6.0 : 1.0
#                  charges = 1                 neg : pos    =      5.6 : 1.0
#            investigation = 1                 neg : pos    =      5.5 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 60
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1100, 'numbers': False, 'document_features': 'document_features3', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 9
#
# ----------------
# Total features:
# 1100
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# Total positive words:
# 36
# Top 10 positive words:
# [u'right', u'love', u'modern', u'helped', u'best', u'lead', u'leading', u'top', u'fans', u'creative']
# Total negative words:
# 18
# Top 10 negative words:
# [u'criminal', u'risk', u'lost', u'vice', u'concerns', u'rival', u'hard', u'problems', u'crisis', u'bad']
# ****************
# ACCURACY = 0.663125948407
# ****************
# Most Informative Features
#                 criminal = True              neg : pos    =      7.3 : 1.0
#                 positive = True              pos : neg    =      6.8 : 1.0
#                     debt = True              neg : pos    =      6.7 : 1.0
#                     died = True              neg : pos    =      5.5 : 1.0
#                   crisis = True              neg : pos    =      5.1 : 1.0
#                     lost = True              neg : pos    =      4.5 : 1.0
#                    clear = True              neg : pos    =      4.4 : 1.0
#                    super = True              pos : neg    =      4.2 : 1.0
#                     fell = True              neg : pos    =      3.9 : 1.0
#                 creative = True              pos : neg    =      3.5 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 61
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1500, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 9
#
# ----------------
# Total features:
# 1500
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# ****************
# ACCURACY = 0.670713201821
# ****************
# Most Informative Features
#                  accused = True              neg : pos    =     24.7 : 1.0
#                  comment = True              neg : pos    =      8.6 : 1.0
#                    force = True              neg : pos    =      7.3 : 1.0
#                 criminal = True              neg : pos    =      7.3 : 1.0
#                     rose = True              pos : neg    =      7.1 : 1.0
#                 positive = True              pos : neg    =      6.8 : 1.0
#                     debt = True              neg : pos    =      6.7 : 1.0
#                 declined = True              neg : pos    =      6.3 : 1.0
#                   gained = True              pos : neg    =      6.2 : 1.0
#                    track = True              pos : neg    =      6.2 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 62
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1500, 'numbers': False, 'document_features': 'document_features2', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 9
#
# ----------------
# Total features:
# 1500
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# ****************
# ACCURACY = 0.62215477997
# ****************
# Most Informative Features
#                  accused = 1                 neg : pos    =     24.7 : 1.0
#                 criminal = 1                 neg : pos    =      8.9 : 1.0
#                  comment = 1                 neg : pos    =      8.6 : 1.0
#                    force = 1                 neg : pos    =      7.3 : 1.0
#                     debt = 1                 neg : pos    =      6.7 : 1.0
#                     rose = 1                 pos : neg    =      6.7 : 1.0
#                 positive = 1                 pos : neg    =      6.5 : 1.0
#                 declined = 1                 neg : pos    =      6.3 : 1.0
#                   gained = 1                 pos : neg    =      6.2 : 1.0
#                    track = 1                 pos : neg    =      6.2 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 63
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1500, 'numbers': False, 'document_features': 'document_features3', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 9
#
# ----------------
# Total features:
# 1500
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# Total positive words:
# 53
# Top 10 positive words:
# [u'right', u'love', u'win', u'modern', u'powerful', u'helped', u'likes', u'trust', u'best', u'lead']
# Total negative words:
# 25
# Top 10 negative words:
# [u'hard', u'crisis', u'issues', u'death', u'failed', u'concerns', u'struggling', u'criminal', u'issue', u'poor']
# ****************
# ACCURACY = 0.670713201821
# ****************
# Most Informative Features
#                 criminal = True              neg : pos    =      7.3 : 1.0
#                 positive = True              pos : neg    =      6.8 : 1.0
#                     debt = True              neg : pos    =      6.7 : 1.0
#                   gained = True              pos : neg    =      6.2 : 1.0
#                   losses = True              neg : pos    =      5.6 : 1.0
#                     died = True              neg : pos    =      5.5 : 1.0
#                      win = True              pos : neg    =      5.2 : 1.0
#                   crisis = True              neg : pos    =      5.1 : 1.0
#                     lost = True              neg : pos    =      4.5 : 1.0
#                    clear = True              neg : pos    =      4.4 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 64
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 2000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 9
#
# ----------------
# Total features:
# 2000
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# ****************
# ACCURACY = 0.694992412747
# ****************
# Most Informative Features
#                  accused = True              neg : pos    =     24.7 : 1.0
#                difficult = True              neg : pos    =     12.7 : 1.0
#                  comment = True              neg : pos    =      8.6 : 1.0
#                     loss = True              neg : pos    =      7.6 : 1.0
#                    force = True              neg : pos    =      7.3 : 1.0
#                 criminal = True              neg : pos    =      7.3 : 1.0
#                     rose = True              pos : neg    =      7.1 : 1.0
#                 positive = True              pos : neg    =      6.8 : 1.0
#                   warned = True              neg : pos    =      6.8 : 1.0
#                     debt = True              neg : pos    =      6.7 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 65
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 2000, 'numbers': False, 'document_features': 'document_features2', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 9
#
# ----------------
# Total features:
# 2000
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# ****************
# ACCURACY = 0.616084977238
# ****************
# Most Informative Features
#                  accused = 1                 neg : pos    =     24.7 : 1.0
#                difficult = 1                 neg : pos    =     12.7 : 1.0
#                 criminal = 1                 neg : pos    =      8.9 : 1.0
#                  comment = 1                 neg : pos    =      8.6 : 1.0
#                     loss = 1                 neg : pos    =      7.6 : 1.0
#                    force = 1                 neg : pos    =      7.3 : 1.0
#                   warned = 1                 neg : pos    =      6.8 : 1.0
#                     debt = 1                 neg : pos    =      6.7 : 1.0
#                     rose = 1                 pos : neg    =      6.7 : 1.0
#                   forced = 1                 neg : pos    =      6.6 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 66
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 2000, 'numbers': False, 'document_features': 'document_features3', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 9
#
# ----------------
# Total features:
# 2000
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# Total positive words:
# 75
# Top 10 positive words:
# [u'right', u'love', u'secure', u'fair', u'win', u'modern', u'powerful', u'competitive', u'helped', u'likes']
# Total negative words:
# 46
# Top 10 negative words:
# [u'fake', u'limited', u'hard', u'bribery', u'fraud', u'falling', u'conservative', u'crisis', u'issues', u'collapse']
# ****************
# ACCURACY = 0.681335356601
# ****************
# Most Informative Features
#                difficult = True              neg : pos    =     12.7 : 1.0
#                     loss = True              neg : pos    =      7.6 : 1.0
#                 criminal = True              neg : pos    =      7.3 : 1.0
#                 positive = True              pos : neg    =      6.8 : 1.0
#                   warned = True              neg : pos    =      6.8 : 1.0
#                     debt = True              neg : pos    =      6.7 : 1.0
#                   gained = True              pos : neg    =      6.2 : 1.0
#                   losses = True              neg : pos    =      5.6 : 1.0
#                     died = True              neg : pos    =      5.5 : 1.0
#                      win = True              pos : neg    =      5.2 : 1.0
#
#
#
#
#
#
# **************** BEST RESULT ****************
# BEST OPTION: 48
# {'length': 2000, 'reverse': False, 'document_features': <function document_features3 at 0x7fe1f4009938>, 'numbers': True, 'stopwords_domain_in_features': False, 'punctuation': '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~', 'stopwords_domain': ['entrepreneur', 'startup', 'new', 'venture', 'manager', 'executive', 'founder', 'wal-mart', 'exxon', 'chevron', 'berkshire', 'hathaway', 'apple', 'samsung', 'phillips', '66', 'general', 'motors', 'ford', 'valero', 'exelon', 'corporation', 'dow', 'chemical', 'conocophillips', 'morgan', 'chase', 'world', 'fuel', 'services', 'illinois', 'tool', 'works', 'boeing', 'intel', 'corporation', 'pepsico', 'tjx', 'companies', 'costco', 'wholesale', 'metlife', 'blackrock', 'at&t', 'johnson', '&', 'johnson', 'abbott', 'laboratories', 'cvs', 'caremark', 'visa', 'cisco', 'systems', 'walt', 'disney', 'company', 'rock', 'tenn', 'company', 'halliburton', 'company', 'alcoa', 'fluor', 'corporation', 'general', 'electric', 'cbre', 'group', 'energy', 'transfer', 'equity', 'express', 'scripts', 'holding', 'hca', 'holdings', 'nrg', 'energy', 'aramark', 'holdings', 'corporation', 'honeywell', 'international', 'nike', 'amazon.com', 'procter', '&', 'gamble', 'unitedhealth', 'group', 'microsoft', 'Google', 'Salesforce', 'SAS', 'Quicken', 'Intuit', 'las', 'vegas', 'sands', 'autonation', '3m', 'company', 'danaher', 'corporation', 'new', 'york', 'life', 'insurance', 'company', 'mcdonalds', 'corporation', 'caterpillar', 'ryder', 'systems', 'd.r.', 'horton', 'stanley', 'black', '&', 'decker', 'archer', 'daniels', 'midland', 'coca-cola', 'company', 'united', 'continental', 'holdings', 'ingram', 'micro', 'chs', 'international', 'paper', 'company', 'mckesson', 'phillip', 'morris', 'international', 'state', 'farm', 'insurance', 'owens', 'corning', 'waste', 'management', 'c.h.', 'robinson', 'worldwide', 'harley-davidson', 'manpower', 'group', 'union', 'pacific', 'r.r', 'donnelley', '&', 'sons', 'company', 'graham', 'holdings', 'company', 'emc', 'corporation', 'mattel', 'united', 'parcel', 'service', 'omnicom', 'group', 'mckinsey', '&', 'company', 'pricewaterhousecoopers', 'intuitive', 'research', 'and', 'tech', 'international', 'bussiness', 'machines', 'formerly', 'BrightTag', 'aka', 'Wright', 'Foods', 'turospree.com', 'nirvanix.com', 'getpostrocket.com', 'votertide.com', 'gamelayers.com', 'unifyo.com', 'lookery.com', 'canv.as', 'blurtt.com', 'manilla.com', 'admaze.ly.com', 'springpad.com', 'ex.fm', 'sambamobile.com', 'qik.com', 'inbloom.org', 'intonow.com', 'getfindit.com', 'inqmobile.com', 'outboxmail.com', 'argylesocial.com', 'iamexec.com', 'stippleit.com', '500px', 'Inc', 'Wajam', 'Keek', 'Inc', 'GuySpy', 'Woozworld', 'TinEye', 'Idee', 'Inc', 'Jigsy', 'Voices.com', 'Snapsort', 'EmpireAvenue', 'Frank', 'and', 'Oak', 'LoginRadius', 'Chango', 'Inc', 'Pure', 'Energies', 'Group', 'Inc', 'Buytopia.ca', 'Smoke', 'NV', 'Inc', 'Just', 'Quality', 'International', 'Inc', 'Sterling', 'Cross', 'Defense', 'Systems', 'Corp', 'Magnet', 'Forensics', 'Inc', 'Greenlife', 'Water', 'Corp', 'Secure', 'Sense', 'Solutions', 'Sandstorm', 'Gold', 'Ltd', 'ScribbleLive', 'Technologies', 'Inc', 'TDot', 'Performance', 'Ltd', 'Redwood', 'Strategic', 'Inc', 'Emcision', 'International', 'Inc', 'Henkaa', 'Inc', 'Whirlscape', 'Inc', 'Bionym', 'Thalmic', 'Labs', 'Recon', 'Instruments', 'Om', 'Malik', 'Technology', 'Affino', 'AnalyzeRE', 'Atomic', 'Reach', 'Cloud', 'Dynamics', 'Exo', 'U', 'Fabric', 'Engine', 'Finmaven', 'Granify', 'InfraDog', 'Introhive', 'Invici', 'Technologies', 'Login', 'Radius', 'mnubo', 'Obero', 'Solutions', 'PeopleInsight', 'Procima', 'Experts', 'reelyActive', 'RtTech', 'Software', 'Seamless', 'Mobile', 'Health', 'Slyce', 'Smart', 'Employee', 'Benefits', 'SweetIQ', 'Thalmic', 'Labs', 'Vena', 'Solutions', 'WestonExprerssions', 'Linkett', '360pi', 'AcademixDirect', 'Inc', 'Adconion', 'Direct', 'Adesto', 'Technologies', 'Corporation', 'Alfresco', 'Aitierre', 'Corporation', 'Altitude', 'Digital', 'Anametrix', 'Aphios', 'Corporation', 'AppDirect', ' ...
# ('ACCURACY =', 0.723823975720789)
# *********************************************

# %%
for k in options:
    print('Option {}'.format(k))
    print(np.array(d_accuracies[k]).mean())
    print(np.array(d_accuracies[k]).std())
    print('--------')
# Out:
# Option 31
# 0.655993930197
# 0.0109435446022
# --------
# Option 32
# 0.641881638847
# 0.0154004424356
# --------
# Option 33
# 0.661001517451
# 0.0118361153263
# --------
# Option 34
# 0.66191198786
# 0.0134326530964
# --------
# Option 35
# 0.647647951442
# 0.0141668467581
# --------
# Option 36
# 0.667981790592
# 0.0135860572295
# --------
# Option 37
# 0.675569044006
# 0.0168266054939
# --------
# Option 38
# 0.650682852807
# 0.0172188867405
# --------
# Option 39
# 0.680273141123
# 0.0162026502802
# --------
# Option 40
# 0.676327769347
# 0.0160024509902
# --------
# Option 41
# 0.656904400607
# 0.0134950771953
# --------
# Option 42
# 0.683915022762
# 0.0166650355384
# --------
# Option 43
# 0.681942336874
# 0.0191487606123
# --------
# Option 44
# 0.649317147193
# 0.018126391441
# --------
# Option 45
# 0.682397572079
# 0.0160455611195
# --------
# Option 46
# 0.685735963581
# 0.0185532781842
# --------
# Option 47
# 0.65220030349
# 0.019383019547
# --------
# Option 48
# 0.687556904401
# 0.0165039766797
# --------
# Option 49
# 0.652807283763
# 0.0175893415852
# --------
# Option 50
# 0.62215477997
# 0.0225483163836
# --------
# Option 51
# 0.661001517451
# 0.0118361153263
# --------
# Option 52
# 0.666312594841
# 0.0133578762529
# --------
# Option 53
# 0.628679817906
# 0.0127149328792
# --------
# Option 54
# 0.663581183612
# 0.0124403194653
# --------
# Option 55
# 0.676934749621
# 0.0112424561105
# --------
# Option 56
# 0.634446130501
# 0.0144668053174
# --------
# Option 57
# 0.671016691958
# 0.0133294028868
# --------
# Option 58
# 0.68937784522
# 0.0175533038567
# --------
# Option 59
# 0.638239757208
# 0.0150403783834
# --------
# Option 60
# 0.680273141123
# 0.0162026502802
# --------
# Option 61
# 0.690136570561
# 0.0165228013218
# --------
# Option 62
# 0.644764795144
# 0.0171606162291
# --------
# Option 63
# 0.684218512898
# 0.0161941210726
# --------
# Option 64
# 0.696509863429
# 0.0143156011109
# --------
# Option 65
# 0.64597875569
# 0.0156973653866
# --------
# Option 66
# 0.687405159332
# 0.0166505210614
# --------

# %%
# import cPickle as pickle

# with open("sentiment/nltk_NaiveBayesClassifier_majority.pickle", "wb") as nltk_file:
#     pickle.dump(???, nltk_file)
