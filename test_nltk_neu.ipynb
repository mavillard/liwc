# %% [markdown]
# Preparing Data
# ==============

# %%
import json
import cPickle as pickle
import numpy as np
import pandas as pd
from pandas import factorize

# %%
# !ls bossa/*json
# Out:
# bossa/tasks_export.json  bossa/tasks_runs_export.json

# %% [markdown]
# BOSSA Results
# -------------

# %% [markdown]
# Processing `results_bossa.json` to get a *dictionary* with keys the task ids, and values in as the average value of the scores. To do that, we first convert scores from categorical (`neg`, `neu`, `pos`) to a numeric scale.

# %%
bossa_results = pd.read_json("bossa/tasks_runs_export.json")
bossa_results.rename(columns={"created": "start_time", "id": "result_id", "info": "score"}, inplace=True)
bossa_results[['start_time']]= bossa_results[['start_time']].apply(pd.to_datetime, dayfirst=True)
bossa_results[['finish_time']]= bossa_results[['finish_time']].apply(pd.to_datetime, dayfirst=True)
bossa_results['score'] = pd.Categorical(bossa_results['score'], categories=['vneg', 'neg', 'neu', 'pos', 'vpos'])
bossa_results['score'].cat.rename_categories([-2, -1, 0, 1, 2], inplace=True)
# Normalize everything to -1, 0, 1
# bossa_results['score'] = bossa_results['score'].astype(float).apply(lambda x: -1 if x < 0 else 1 if x > 0 else 0)
bossa_results["seconds"] = (bossa_results["finish_time"] - bossa_results["start_time"]).astype('timedelta64[us]') / 1e6
bossa_results = bossa_results[["result_id", "seconds", "task_id", "score"]]
bossa_results.ix[[50]]
# Out:
#     result_id   seconds  task_id score
# 50      11203  0.000025    52775     1

# %% [markdown]
# The information about the sentence comes in a dictionary inside the cells of the serie `info`, so we expand it.

# %%
bossa_tasks = pd.read_json("bossa/tasks_export.json")
bossa_tasks[['created']]= bossa_tasks[['created']].apply(pd.to_datetime, dayfirst=True)
bossa_tasks.rename(columns={'id': 'task_id'}, inplace=True)
bossa_tasks = bossa_tasks[['task_id', 'info']]
bossa_tasks.ix[[50]]
# Out:
#     task_id                                               info
# 50    52851  {u'search_words': u'founder', u'appears_in_sen...

# %% [markdown]
# And finally we merge the `DataFrame` with the scores with the one containing the sentences.

# %%
bossa_tasks_scores = pd.merge(bossa_results, bossa_tasks, on='task_id')
bossa_tasks_scores.ix[[50]]
# Out:
#     result_id   seconds  task_id  score  \
# 50      11195  0.000021    52776      2
#
#                                                  info
# 50  {u'search_words': u'executive', u'appears_in_s...

# %% [markdown]
# Let's now expand the column `info` into as many new columns as keys has the dictionary `info`.

# %%
bossa_tasks_scores.ix[50].info.keys()
# Out:
# [u'search_words',
#  u'appears_in_sentence',
#  u'url',
#  u'media',
#  u'appears_in_noun_phrases',
#  u'noun_phrases',
#  u'sentence_id',
#  u'text',
#  u'sentence',
#  u'pub_date',
#  u'is_company']

# %%
def json_to_series(info):
    keys, values = zip(*info.iteritems())
    return pd.Series(values, index=keys)

bossa_info = bossa_tasks_scores["info"].apply(json_to_series)
bossa_info.reset_index()
bossa = pd.concat([bossa_tasks_scores, bossa_info], axis=1)
bossa.pop("info")
# bossa['id'] = bossa['id'].astype(float)
bossa.ix[50:53]
# Out:
#     result_id   seconds  task_id  score search_words appears_in_sentence  \
# 50      11195  0.000021    52776      2    executive                   0
# 51      11205  0.000018    52776     -1    executive                   0
# 52      11207  0.000017    52776      1    executive                   0
# 53      11209  0.000017    52776     -2    executive                   0
#
#                                                   url media  \
# 50  http://dealbook.nytimes.com/2013/05/17/a-toeho...   nyt
# 51  http://dealbook.nytimes.com/2013/05/17/a-toeho...   nyt
# 52  http://dealbook.nytimes.com/2013/05/17/a-toeho...   nyt
# 53  http://dealbook.nytimes.com/2013/05/17/a-toeho...   nyt
#
#    appears_in_noun_phrases                                       noun_phrases  \
# 50                       0  [chinese investors, overseas companies, politi...
# 51                       0  [chinese investors, overseas companies, politi...
# 52                       0  [chinese investors, overseas companies, politi...
# 53                       0  [chinese investors, overseas companies, politi...
#
#    sentence_id                                               text  \
# 50          14  Chinese investors are increasingly opting to b...
# 51          14  Chinese investors are increasingly opting to b...
# 52          14  Chinese investors are increasingly opting to b...
# 53          14  Chinese investors are increasingly opting to b...
#
#                                              sentence              pub_date  \
# 50  Chinese investors are increasingly opting to b...  2013-05-17T11:47:51Z
# 51  Chinese investors are increasingly opting to b...  2013-05-17T11:47:51Z
# 52  Chinese investors are increasingly opting to b...  2013-05-17T11:47:51Z
# 53  Chinese investors are increasingly opting to b...  2013-05-17T11:47:51Z
#
#    is_company
# 50          0
# 51          0
# 52          0
# 53          0

# %% [markdown]
# Aggregate
# ---------

# %% [markdown]
# We now aggregate calculating the average per `sentence_id` using a group by. In the process, we lose the source of the data, that's why we first have to save it.

# %%
bossa.to_csv("sentiment/scores_ungrouped.csv", encoding="utf8")

# %% [markdown]
# Finally, we aggregate and create a new `DataFrame` for the different sentences and their score.

# %%
sentences = bossa.groupby(['sentence'])[['score']].aggregate(np.average)
sentences.to_csv("sentiment/scores.csv", encoding="utf8")
print sentences.count()
sentences[1001:1004]
# Out:
# score    8996
# dtype: int64
#                                                                                                                                                                                                                                                                                                score
# sentence
# 'We must hope after so much prevarication that this time Google's proposals represent a genuine attempt to address the concerns identified,' said David Wood, the legal counsel for Icomp, an industry group backed by Microsoft and a number of other companies.                          -0.333333
# 'We must push our leaders to step up and commit to action,' said Hugh Evans, the founder and chief executive of the charity.                                                                                                                                                               -0.285714
# 'We need them to tell the story of how we are making decisions and putting the organization together,' said George Postolos, the Astros' president and chief executive, who added that the team would not want a broadcaster who was uncomfortable explaining the front office's strategy. -0.666667

# %%
from collections import Counter

def majority(series): #receives a Pandas Series
    return Counter(map(lambda x: 1 if x > 0 else -1 if x < 0 else 0, series)).most_common(1)[0][0]

# score_calculate = np.average
score_calculate = majority

sentences = bossa.groupby(['sentence'])[['score']].aggregate(score_calculate)

# %% [markdown]
# Sentence Classifier
# -------------------

# %%
from nltk.corpus import stopwords
from sklearn.cross_validation import cross_val_score
from sklearn.grid_search import GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import precision_recall_fscore_support
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC

# %% [markdown]
# Create the tranining and testing sets (data and labels) from a randomized version of the set of assessed sentences.

# %%
sentences.reset_index().count()
# Out:
# sentence    8996
# score       8996
# dtype: int64

# %% [markdown]
# We could consider 3 classes, but it toruns out that using binary classficication seems to produce better results. Still, try multi-classs classifiers is something worth trying.

# %%
raw_scores = sentences.reset_index()
scores = raw_scores
# scores = scores[scores.score!=0]  # We ignore the neutral sentences
scores['sentiment'] = scores['score'].apply(lambda s: 'pos' if s > 0 else 'neg' if s < 0 else 0)
# percentage = 0.85  #  percentage for training, rest for for testing
# # We split to have enough representativenesss for both positive and negative sentiments
# sent_min = min(
#     scores[scores.sentiment=='pos'].sentiment.count(),
#     scores[scores.sentiment=='neg'].sentiment.count(),
# )
# scores = scores[["sentence", "sentiment"]]
# train_data = np.array([])
# train_labels = np.array([])
# test_data = np.array([])
# test_labels = np.array([])
# for sent in ('pos', 'neg'):
#     sent_scores = scores[scores['sentiment']==sent]
#     sent_scores = sent_scores.reindex(np.random.permutation(sent_scores.index))
#     sent_sentences_count = int(sent_scores['sentence'].count())
#     sent_train = sent_scores[["sentence", "sentiment"]][:int(sent_sentences_count * percentage)]
#     sent_test = sent_scores[["sentence", "sentiment"]][int(sent_sentences_count * percentage) + 1:]
#     print sent, sent_min, sent_train.sentiment.count(), sent_test.sentiment.count()
#     train_data = np.append(train_data, sent_train["sentence"])
#     train_labels = np.append(train_labels, sent_train["sentiment"])
#     test_data = np.append(test_data, sent_test["sentence"])
#     test_labels = np.append(test_labels, sent_test["sentiment"])

# %% [markdown]
# #NLTK

# %%
document_df = scores[['sentence', 'sentiment']]
document_df = document_df.reindex(np.random.permutation(document_df.index))

# %%
document_df.head()
# Out:
#                                                sentence sentiment
# 2908  Coming off a quarterly earnings report that pl...       pos
# 7570  The executive who replaced Mr. Zucker just thr...       neg
# 1282  A copy of the filing, which was provided to Th...       neg
# 674   'The Justice Department had a clear view on th...       pos
# 2125  Arsenal manager Arsène Wenger offers an intrig...       pos

# %%
original_documents = [(r[1]['sentence'], r[1]['sentiment']) for r in document_df.iterrows()]

# %%
pos_file = open('positive-words.txt')
all_pos_words = [w.strip().lower() for w in pos_file]

neg_file = open('negative-words.txt')
all_neg_words = [w.strip().lower() for w in neg_file]

# %%
search_terms_f = open('search_terms.txt')
search_terms = []
for t in search_terms_f:
    l = t.strip().split()
    search_terms.extend(l)

# %%
import string

import nltk
from nltk.corpus import stopwords

# %% [markdown]
# ###Options

# %%
#stopwords_english
stopwords_english = stopwords.words('english')
#stopwords_domain
stopwords_domain = search_terms + ["'s", '--']
#stopwords_english
punctuation = string.punctuation

# %%
def document_features1(document):      
    document_words = set(document)
    features = {}
    for word in word_features:
        features[word] = word in document_words
    return features

# %%
def document_features2(document):      
    document_words = list(document)
    features = {}
    for word in document_words:
        if word in word_features:
            features[word] = features.get(word, 0) + 1
    return features

# %%
def document_features3(document):
    word_features3 = list(pos_words) + list(neg_words)
    document_words = set(document)
    features = {}
    for word in word_features3:
        features[word] = word in document_words
    return features

# %%
# Filter stopwords, punctuation marks, and numbers
# 'stopwords_english': stopwords_english,
# 'stopwords_domain': stopwords_domain,
# 'punctuation': punctuation,
# 'numbers': True,
#
# Do not filter stopwords, punctuation marks, or numbers
# 'stopwords_english': [],
# 'stopwords_domain': [],
# 'punctuation': [],
# 'numbers': False,

options = {}

#Option 1
opt1 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[1] = opt1

#Option 2
opt2 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': [],
    'numbers': True,
}
options[2] = opt2

#Option 3
opt3 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': [],
    'punctuation': punctuation,
    'numbers': True,
}
options[3] = opt3

#Option 4
opt4 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[4] = opt4

#Option 5
opt5 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': True,
}
options[5] = opt5

#Option 6
opt6 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': punctuation,
    'numbers': True,
}
options[6] = opt6

#Option 7
opt7 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': stopwords_domain,
    'punctuation': [],
    'numbers': True,
}
options[7] = opt7

#Option 8
opt8 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': True,
}
options[8] = opt8

#Option 9
opt9 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': False,
}
options[9] = opt9

#Option 10
opt10 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': [],
    'numbers': False,
}
options[10] = opt10

#Option 11
opt11 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': [],
    'punctuation': punctuation,
    'numbers': False,
}
options[11] = opt11

#Option 12
opt12 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': False,
}
options[12] = opt12

#Option 13
opt13 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[13] = opt13

#Option 14
opt14 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': punctuation,
    'numbers': False,
}
options[14] = opt14

#Option 15
opt15 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': stopwords_domain,
    'punctuation': [],
    'numbers': False,
}
options[15] = opt15

#Option 16
opt16 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[16] = opt16

#Option 17
opt17 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': [],
    'punctuation': punctuation,
    'numbers': True,
}
options[17] = opt17

#Option 18
opt18 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': True,
}
options[18] = opt18

#Option 19
opt19 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': punctuation,
    'numbers': True,
}
options[19] = opt19

#Option 20
opt20 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': True,
}
options[20] = opt20

#Option 21
opt21 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': [],
    'punctuation': punctuation,
    'numbers': False,
}
options[21] = opt21

#Option 22
opt22 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[22] = opt22

#Option 23
opt23 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': punctuation,
    'numbers': False,
}
options[23] = opt23

#Option 24
opt24 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[24] = opt24

################################################################################################

#Option 25
opt25 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features2,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[25] = opt25

#Option 26
opt26 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features3,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[26] = opt26

#Option 27
opt27 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features2,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[27] = opt27

#Option 28
opt28 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features3,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[28] = opt28

#Option 29
opt29 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features2,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[29] = opt29

#Option 30
opt30 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features3,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[30] = opt30

# %%
def filt(x):
    c1 = x not in options[opt]['stopwords_english']
    c2 = x not in options[opt]['stopwords_domain']
    c3 = x not in options[opt]['punctuation']
    c4 = True if options[opt]['numbers'] else not x.isdigit()
    
    cs = [c1, c2, c3, c4]
    return all(cs)
 
def preprocess(text):
    text = text.lower()
    tokens = nltk.word_tokenize(text)
    filtered_words = filter(filt, tokens)
    return filtered_words

def print_option(opt):
    d = dict(opt)
    for k in d:
        if (type(d[k]) == list or type(d[k]) == str) and len(d[k]) > 0:
            d[k] = ['...']
        elif hasattr(d[k], '__call__'):
            d[k] = d[k].func_name
    print(d)

# %%
#%%prun -l4
from collections import defaultdict
from random import shuffle

best_option = None
best_accuracy = 0
best_index = 0
d_accuracies = defaultdict(list)

all_words = [w.lower() for d in original_documents for w in nltk.word_tokenize(d[0])]

for i in range(10):
    shuffle(original_documents)
    for opt in options:
        print('=======================================================')
        print('RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:')
        print('\nOption {}'.format(opt))
        print_option(options[opt])
        print(score_calculate.func_name)
        print('\niteration: {}\n'.format(i))
        
        documents = [(preprocess(d[0]), d[1]) for d in original_documents]
        filtered_words = filter(filt, all_words)
        freq_dist = nltk.FreqDist(filtered_words)
        most_common_words = [word for word, freq in freq_dist.most_common()]
        most_common_words = filter(filt, most_common_words)

        if options[opt]['stopwords_domain_in_features']:
            most_common_words = list(set(most_common_words).difference(search_terms))
        if options[opt]['reverse']:
            most_common_words.reverse()
        
        word_features = most_common_words[:options[opt]['length']]
        print('----------------')
        print('Total features:')
        print(options[opt]['length'])
        print('Top 10 features:')
        print(word_features[:10])
        print('----------------')

        if options[opt]['document_features'] == document_features3:
            pos_words = set(all_pos_words).intersection(word_features)
            print('Total positive words:')
            print(len(pos_words))
            print('Top 10 positive words:')
            print list(pos_words)[:10]

            neg_words = set(all_neg_words).intersection(word_features)
            print('Total positive words:')
            print(len(neg_words))
            print('Top 10 positive words:')
            print list(neg_words)[:10]

        featureset = [(options[opt]['document_features'](d[0]), d[1]) for d in documents]
        size = int(len(featureset) * 0.9)
        train_set = featureset[:size]
        test_set = featureset[size:]

        classifier = nltk.NaiveBayesClassifier.train(train_set)
        accuracy = nltk.classify.accuracy(classifier, test_set)
        print('****************')
        print('ACCURACY = {}'.format(accuracy))
        print('****************')
        classifier.show_most_informative_features(10)
        print('\n\n\n\n\n')
        d_accuracies[opt].append(accuracy)

        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_option = options[opt]
            best_index = opt

print('**************** BEST RESULT ****************')
print('BEST OPTION: {}'.format(best_index))
print(best_option)
print('ACCURACY =', best_accuracy)
print('*********************************************')
# Out:
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 1
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'president']
# ----------------
# ****************
# ACCURACY = 0.453333333333
# ****************
# Most Informative Features
#                    force = True              neg : pos    =     11.2 : 1.0
#                    built = True                0 : neg    =      9.4 : 1.0
#                scheduled = True                0 : neg    =      9.4 : 1.0
#                  comment = True              neg : pos    =      9.3 : 1.0
#                    space = True                0 : neg    =      8.2 : 1.0
#                 declined = True              neg : pos    =      8.2 : 1.0
#                  compete = True              neg : 0      =      7.7 : 1.0
#                     cnbc = True                0 : neg    =      7.6 : 1.0
#                      500 = True              pos : 0      =      7.5 : 1.0
#                     rose = True              pos : neg    =      7.3 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 2
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'.', u"'", u'said', u'chief', u'mr.', u'$', u'like', u';', u'would']
# ----------------
# ****************
# ACCURACY = 0.458888888889
# ****************
# Most Informative Features
#                    force = True              neg : pos    =     11.2 : 1.0
#                    built = True                0 : neg    =      9.4 : 1.0
#                scheduled = True                0 : neg    =      9.4 : 1.0
#                  comment = True              neg : pos    =      9.3 : 1.0
#                    space = True                0 : neg    =      8.2 : 1.0
#                 declined = True              neg : pos    =      8.2 : 1.0
#                  compete = True              neg : 0      =      7.7 : 1.0
#                     cnbc = True                0 : neg    =      7.6 : 1.0
#                      500 = True              pos : 0      =      7.5 : 1.0
#                     rose = True              pos : neg    =      7.3 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 3
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u"'s", u'executive', u'said', u'chief', u'manager', u'apple', u'company', u'mr.', u'new', u'founder']
# ----------------
# ****************
# ACCURACY = 0.456666666667
# ****************
# Most Informative Features
#                    force = True              neg : pos    =     11.2 : 1.0
#                    built = True                0 : neg    =      9.4 : 1.0
#                scheduled = True                0 : neg    =      9.4 : 1.0
#                  comment = True              neg : pos    =      9.3 : 1.0
#                    space = True                0 : neg    =      8.2 : 1.0
#                 declined = True              neg : pos    =      8.2 : 1.0
#                  compete = True              neg : 0      =      7.7 : 1.0
#                     cnbc = True                0 : neg    =      7.6 : 1.0
#                     rose = True              pos : neg    =      7.3 : 1.0
#               california = True                0 : neg    =      6.4 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 4
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'the', u'of', u'a', u'to', u'in', u'that', u'for', u'is', u'said', u'on']
# ----------------
# ****************
# ACCURACY = 0.486666666667
# ****************
# Most Informative Features
#                    force = True              neg : pos    =     11.2 : 1.0
#                    built = True                0 : neg    =      9.4 : 1.0
#                scheduled = True                0 : neg    =      9.4 : 1.0
#                  comment = True              neg : pos    =      9.3 : 1.0
#                    space = True                0 : neg    =      8.2 : 1.0
#                 declined = True              neg : pos    =      8.2 : 1.0
#                  compete = True              neg : 0      =      7.7 : 1.0
#                     cnbc = True                0 : neg    =      7.6 : 1.0
#                     rose = True              pos : neg    =      7.3 : 1.0
#               california = True                0 : neg    =      6.4 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 5
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'.', u"'s", u"'", u'executive', u'said', u'chief', u'manager', u'apple', u'company']
# ----------------
# ****************
# ACCURACY = 0.461111111111
# ****************
# Most Informative Features
#                    force = True              neg : pos    =     11.2 : 1.0
#                    built = True                0 : neg    =      9.4 : 1.0
#                scheduled = True                0 : neg    =      9.4 : 1.0
#                  comment = True              neg : pos    =      9.3 : 1.0
#                    space = True                0 : neg    =      8.2 : 1.0
#                 declined = True              neg : pos    =      8.2 : 1.0
#                  compete = True              neg : 0      =      7.7 : 1.0
#                     cnbc = True                0 : neg    =      7.6 : 1.0
#                     rose = True              pos : neg    =      7.3 : 1.0
#               california = True                0 : neg    =      6.4 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 6
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'the', u'of', u'and', u'a', u'to', u'in', u"'s", u'that', u'for', u'executive']
# ----------------
# ****************
# ACCURACY = 0.484444444444
# ****************
# Most Informative Features
#                    force = True              neg : pos    =     11.2 : 1.0
#                    built = True                0 : neg    =      9.4 : 1.0
#                scheduled = True                0 : neg    =      9.4 : 1.0
#                  comment = True              neg : pos    =      9.3 : 1.0
#                    space = True                0 : neg    =      8.2 : 1.0
#                 declined = True              neg : pos    =      8.2 : 1.0
#                  compete = True              neg : 0      =      7.7 : 1.0
#                     cnbc = True                0 : neg    =      7.6 : 1.0
#                     rose = True              pos : neg    =      7.3 : 1.0
#                     debt = True              neg : pos    =      6.0 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 7
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'the', u'.', u'of', u'a', u'to', u'in', u'that', u'for', u"'"]
# ----------------
# ****************
# ACCURACY = 0.483333333333
# ****************
# Most Informative Features
#                    force = True              neg : pos    =     11.2 : 1.0
#                    built = True                0 : neg    =      9.4 : 1.0
#                scheduled = True                0 : neg    =      9.4 : 1.0
#                  comment = True              neg : pos    =      9.3 : 1.0
#                    space = True                0 : neg    =      8.2 : 1.0
#                 declined = True              neg : pos    =      8.2 : 1.0
#                  compete = True              neg : 0      =      7.7 : 1.0
#                     cnbc = True                0 : neg    =      7.6 : 1.0
#                     rose = True              pos : neg    =      7.3 : 1.0
#                     debt = True              neg : pos    =      6.0 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 8
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# ****************
# ACCURACY = 0.483333333333
# ****************
# Most Informative Features
#                    force = True              neg : pos    =     11.2 : 1.0
#                    built = True                0 : neg    =      9.4 : 1.0
#                scheduled = True                0 : neg    =      9.4 : 1.0
#                  comment = True              neg : pos    =      9.3 : 1.0
#                    space = True                0 : neg    =      8.2 : 1.0
#                 declined = True              neg : pos    =      8.2 : 1.0
#                  compete = True              neg : 0      =      7.7 : 1.0
#                     cnbc = True                0 : neg    =      7.6 : 1.0
#                     rose = True              pos : neg    =      7.3 : 1.0
#                     debt = True              neg : pos    =      6.0 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 9
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'president']
# ----------------
# ****************
# ACCURACY = 0.457777777778
# ****************
# Most Informative Features
#                    force = True              neg : pos    =     11.2 : 1.0
#                    built = True                0 : neg    =      9.4 : 1.0
#                scheduled = True                0 : neg    =      9.4 : 1.0
#                  comment = True              neg : pos    =      9.3 : 1.0
#                    space = True                0 : neg    =      8.2 : 1.0
#                 declined = True              neg : pos    =      8.2 : 1.0
#                  compete = True              neg : 0      =      7.7 : 1.0
#                     cnbc = True                0 : neg    =      7.6 : 1.0
#                     rose = True              pos : neg    =      7.3 : 1.0
#                  related = True              neg : 0      =      6.4 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 10
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'.', u"'", u'said', u'chief', u'mr.', u'$', u'like', u';', u'would']
# ----------------
# ****************
# ACCURACY = 0.464444444444
# ****************
# Most Informative Features
#                    force = True              neg : pos    =     11.2 : 1.0
#                    built = True                0 : neg    =      9.4 : 1.0
#                scheduled = True                0 : neg    =      9.4 : 1.0
#                  comment = True              neg : pos    =      9.3 : 1.0
#                    space = True                0 : neg    =      8.2 : 1.0
#                 declined = True              neg : pos    =      8.2 : 1.0
#                  compete = True              neg : 0      =      7.7 : 1.0
#                     cnbc = True                0 : neg    =      7.6 : 1.0
#                     rose = True              pos : neg    =      7.3 : 1.0
#                  related = True              neg : 0      =      6.4 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 11
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u"'s", u'executive', u'said', u'chief', u'manager', u'apple', u'company', u'mr.', u'new', u'founder']
# ----------------
# ****************
# ACCURACY = 0.46
# ****************
# Most Informative Features
#                    force = True              neg : pos    =     11.2 : 1.0
#                    built = True                0 : neg    =      9.4 : 1.0
#                scheduled = True                0 : neg    =      9.4 : 1.0
#                  comment = True              neg : pos    =      9.3 : 1.0
#                    space = True                0 : neg    =      8.2 : 1.0
#                 declined = True              neg : pos    =      8.2 : 1.0
#                  compete = True              neg : 0      =      7.7 : 1.0
#                     cnbc = True                0 : neg    =      7.6 : 1.0
#                     rose = True              pos : neg    =      7.3 : 1.0
#               california = True                0 : neg    =      6.4 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 12
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'the', u'of', u'a', u'to', u'in', u'that', u'for', u'is', u'said', u'on']
# ----------------
# ****************
# ACCURACY = 0.484444444444
# ****************
# Most Informative Features
#                    force = True              neg : pos    =     11.2 : 1.0
#                    built = True                0 : neg    =      9.4 : 1.0
#                scheduled = True                0 : neg    =      9.4 : 1.0
#                  comment = True              neg : pos    =      9.3 : 1.0
#                    space = True                0 : neg    =      8.2 : 1.0
#                 declined = True              neg : pos    =      8.2 : 1.0
#                  compete = True              neg : 0      =      7.7 : 1.0
#                     cnbc = True                0 : neg    =      7.6 : 1.0
#                     rose = True              pos : neg    =      7.3 : 1.0
#               california = True                0 : neg    =      6.4 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 13
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'.', u"'s", u"'", u'executive', u'said', u'chief', u'manager', u'apple', u'company']
# ----------------
# ****************
# ACCURACY = 0.466666666667
# ****************
# Most Informative Features
#                    force = True              neg : pos    =     11.2 : 1.0
#                    built = True                0 : neg    =      9.4 : 1.0
#                scheduled = True                0 : neg    =      9.4 : 1.0
#                  comment = True              neg : pos    =      9.3 : 1.0
#                    space = True                0 : neg    =      8.2 : 1.0
#                 declined = True              neg : pos    =      8.2 : 1.0
#                  compete = True              neg : 0      =      7.7 : 1.0
#                     cnbc = True                0 : neg    =      7.6 : 1.0
#                     rose = True              pos : neg    =      7.3 : 1.0
#               california = True                0 : neg    =      6.4 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 14
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'the', u'of', u'and', u'a', u'to', u'in', u"'s", u'that', u'for', u'executive']
# ----------------
# ****************
# ACCURACY = 0.48
# ****************
# Most Informative Features
#                    force = True              neg : pos    =     11.2 : 1.0
#                    built = True                0 : neg    =      9.4 : 1.0
#                scheduled = True                0 : neg    =      9.4 : 1.0
#                  comment = True              neg : pos    =      9.3 : 1.0
#                    space = True                0 : neg    =      8.2 : 1.0
#                 declined = True              neg : pos    =      8.2 : 1.0
#                  compete = True              neg : 0      =      7.7 : 1.0
#                     cnbc = True                0 : neg    =      7.6 : 1.0
#                     rose = True              pos : neg    =      7.3 : 1.0
#                     debt = True              neg : pos    =      6.0 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 15
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'the', u'.', u'of', u'a', u'to', u'in', u'that', u'for', u"'"]
# ----------------
# ****************
# ACCURACY = 0.482222222222
# ****************
# Most Informative Features
#                    force = True              neg : pos    =     11.2 : 1.0
#                    built = True                0 : neg    =      9.4 : 1.0
#                scheduled = True                0 : neg    =      9.4 : 1.0
#                  comment = True              neg : pos    =      9.3 : 1.0
#                    space = True                0 : neg    =      8.2 : 1.0
#                 declined = True              neg : pos    =      8.2 : 1.0
#                  compete = True              neg : 0      =      7.7 : 1.0
#                     cnbc = True                0 : neg    =      7.6 : 1.0
#                     rose = True              pos : neg    =      7.3 : 1.0
#               california = True                0 : neg    =      6.4 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 16
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# ****************
# ACCURACY = 0.48
# ****************
# Most Informative Features
#                    force = True              neg : pos    =     11.2 : 1.0
#                    built = True                0 : neg    =      9.4 : 1.0
#                scheduled = True                0 : neg    =      9.4 : 1.0
#                  comment = True              neg : pos    =      9.3 : 1.0
#                    space = True                0 : neg    =      8.2 : 1.0
#                 declined = True              neg : pos    =      8.2 : 1.0
#                  compete = True              neg : 0      =      7.7 : 1.0
#                     cnbc = True                0 : neg    =      7.6 : 1.0
#                     rose = True              pos : neg    =      7.3 : 1.0
#                     debt = True              neg : pos    =      6.0 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 17
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'shaye', u'revelers', u'woods', u'thirst']
# ----------------
# ****************
# ACCURACY = 0.472222222222
# ****************
# Most Informative Features
#                   losing = True              neg : pos    =     10.0 : 1.0
#                  schools = True              pos : 0      =      7.1 : 1.0
#                     debt = True              neg : pos    =      6.0 : 1.0
#                 channels = True              neg : pos    =      6.0 : 1.0
#                  effects = True              neg : pos    =      6.0 : 1.0
#                     fake = True              neg : pos    =      6.0 : 1.0
#              controversy = True              neg : pos    =      6.0 : 1.0
#                following = True              neg : pos    =      5.6 : 1.0
#                   saying = True              neg : 0      =      4.8 : 1.0
#                criticism = True              neg : pos    =      4.7 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 18
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': [], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'shaye', u'revelers', u'woods', u'thirst']
# ----------------
# ****************
# ACCURACY = 0.473333333333
# ****************
# Most Informative Features
#                   losing = True              neg : pos    =     10.0 : 1.0
#                  schools = True              pos : 0      =      7.1 : 1.0
#                     debt = True              neg : pos    =      6.0 : 1.0
#                 channels = True              neg : pos    =      6.0 : 1.0
#                  effects = True              neg : pos    =      6.0 : 1.0
#                     fake = True              neg : pos    =      6.0 : 1.0
#              controversy = True              neg : pos    =      6.0 : 1.0
#                following = True              neg : pos    =      5.6 : 1.0
#                   saying = True              neg : 0      =      4.8 : 1.0
#                criticism = True              neg : pos    =      4.7 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 19
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'shaye', u'revelers', u'woods', u'thirst']
# ----------------
# ****************
# ACCURACY = 0.468888888889
# ****************
# Most Informative Features
#                   losing = True              neg : pos    =     10.0 : 1.0
#                  schools = True              pos : 0      =      7.1 : 1.0
#                     debt = True              neg : pos    =      6.0 : 1.0
#                 channels = True              neg : pos    =      6.0 : 1.0
#                  effects = True              neg : pos    =      6.0 : 1.0
#                     fake = True              neg : pos    =      6.0 : 1.0
#              controversy = True              neg : pos    =      6.0 : 1.0
#                following = True              neg : pos    =      5.6 : 1.0
#                   saying = True              neg : 0      =      4.8 : 1.0
#                criticism = True              neg : pos    =      4.7 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 20
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': [], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'shaye', u'revelers', u'woods', u'thirst']
# ----------------
# ****************
# ACCURACY = 0.47
# ****************
# Most Informative Features
#                   losing = True              neg : pos    =     10.0 : 1.0
#                  schools = True              pos : 0      =      7.1 : 1.0
#                     debt = True              neg : pos    =      6.0 : 1.0
#                 channels = True              neg : pos    =      6.0 : 1.0
#                  effects = True              neg : pos    =      6.0 : 1.0
#                     fake = True              neg : pos    =      6.0 : 1.0
#              controversy = True              neg : pos    =      6.0 : 1.0
#                following = True              neg : pos    =      5.6 : 1.0
#                   saying = True              neg : 0      =      4.8 : 1.0
#                criticism = True              neg : pos    =      4.7 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 21
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': ['...'], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'shaye', u'revelers', u'woods', u'thirst']
# ----------------
# ****************
# ACCURACY = 0.472222222222
# ****************
# Most Informative Features
#                   losing = True              neg : pos    =     10.0 : 1.0
#                  schools = True              pos : 0      =      7.1 : 1.0
#                     debt = True              neg : pos    =      6.0 : 1.0
#                 channels = True              neg : pos    =      6.0 : 1.0
#                  effects = True              neg : pos    =      6.0 : 1.0
#                     fake = True              neg : pos    =      6.0 : 1.0
#              controversy = True              neg : pos    =      6.0 : 1.0
#                following = True              neg : pos    =      5.6 : 1.0
#                   saying = True              neg : 0      =      4.8 : 1.0
#                criticism = True              neg : pos    =      4.7 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 22
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'shaye', u'revelers', u'woods', u'thirst']
# ----------------
# ****************
# ACCURACY = 0.471111111111
# ****************
# Most Informative Features
#                   losing = True              neg : pos    =     10.0 : 1.0
#                  schools = True              pos : 0      =      7.1 : 1.0
#                     debt = True              neg : pos    =      6.0 : 1.0
#                 channels = True              neg : pos    =      6.0 : 1.0
#                  effects = True              neg : pos    =      6.0 : 1.0
#                     fake = True              neg : pos    =      6.0 : 1.0
#              controversy = True              neg : pos    =      6.0 : 1.0
#                following = True              neg : pos    =      5.6 : 1.0
#                   saying = True              neg : 0      =      4.8 : 1.0
#                criticism = True              neg : pos    =      4.7 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 23
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': ['...'], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'shaye', u'revelers', u'woods', u'thirst']
# ----------------
# ****************
# ACCURACY = 0.468888888889
# ****************
# Most Informative Features
#                   losing = True              neg : pos    =     10.0 : 1.0
#                  schools = True              pos : 0      =      7.1 : 1.0
#                     debt = True              neg : pos    =      6.0 : 1.0
#                 channels = True              neg : pos    =      6.0 : 1.0
#                  effects = True              neg : pos    =      6.0 : 1.0
#                     fake = True              neg : pos    =      6.0 : 1.0
#              controversy = True              neg : pos    =      6.0 : 1.0
#                following = True              neg : pos    =      5.6 : 1.0
#                   saying = True              neg : 0      =      4.8 : 1.0
#                criticism = True              neg : pos    =      4.7 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 24
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'shaye', u'revelers', u'woods', u'thirst']
# ----------------
# ****************
# ACCURACY = 0.468888888889
# ****************
# Most Informative Features
#                   losing = True              neg : pos    =     10.0 : 1.0
#                  schools = True              pos : 0      =      7.1 : 1.0
#                     debt = True              neg : pos    =      6.0 : 1.0
#                 channels = True              neg : pos    =      6.0 : 1.0
#                  effects = True              neg : pos    =      6.0 : 1.0
#                     fake = True              neg : pos    =      6.0 : 1.0
#              controversy = True              neg : pos    =      6.0 : 1.0
#                following = True              neg : pos    =      5.6 : 1.0
#                   saying = True              neg : 0      =      4.8 : 1.0
#                criticism = True              neg : pos    =      4.7 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 25
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features2', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'president']
# ----------------
# ****************
# ACCURACY = 0.454444444444
# ****************
# Most Informative Features
#                       '' = 2                   0 : pos    =     11.5 : 1.0
#                    force = 1                 neg : pos    =     11.2 : 1.0
#                  comment = 1                 neg : pos    =      9.3 : 1.0
#                    built = 1                   0 : neg    =      8.8 : 1.0
#                financing = 1                   0 : neg    =      8.8 : 1.0
#                 declined = 1                 neg : pos    =      8.2 : 1.0
#                  compete = 1                 neg : 0      =      7.7 : 1.0
#                    space = 1                   0 : neg    =      7.6 : 1.0
#               government = 2                 neg : pos    =      7.3 : 1.0
#                      500 = 1                 pos : 0      =      7.1 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 26
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features3', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'president']
# ----------------
# Total positive words:
# 35
# Top 10 positive words:
# [u'right', u'love', u'modern', u'helped', u'best', u'lead', u'leading', u'top', u'fans', u'creative']
# Total positive words:
# 17
# Top 10 positive words:
# [u'risk', u'lost', u'vice', u'concerns', u'rival', u'hard', u'problems', u'crisis', u'bad', u'fell']
# ****************
# ACCURACY = 0.481111111111
# ****************
# Most Informative Features
#                     debt = True              neg : pos    =      6.0 : 1.0
#                   helped = True              pos : neg    =      5.3 : 1.0
#                  problem = True              neg : 0      =      5.3 : 1.0
#               successful = True              pos : 0      =      5.1 : 1.0
#                     died = True              neg : pos    =      4.9 : 1.0
#                     lost = True              neg : pos    =      4.5 : 1.0
#                 problems = True              neg : 0      =      4.3 : 1.0
#                    super = True              pos : neg    =      3.9 : 1.0
#                     fell = True              neg : pos    =      3.9 : 1.0
#                   crisis = True              neg : pos    =      3.9 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 27
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features2', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# ****************
# ACCURACY = 0.458888888889
# ****************
# Most Informative Features
#                       '' = 2                   0 : pos    =     11.5 : 1.0
#                    force = 1                 neg : pos    =     11.2 : 1.0
#                  comment = 1                 neg : pos    =      9.3 : 1.0
#                    built = 1                   0 : neg    =      8.8 : 1.0
#                 declined = 1                 neg : pos    =      8.2 : 1.0
#                  compete = 1                 neg : 0      =      7.7 : 1.0
#                    space = 1                   0 : neg    =      7.6 : 1.0
#               government = 2                 neg : pos    =      7.3 : 1.0
#                 festival = 1                   0 : neg    =      7.0 : 1.0
#                     rose = 1                 pos : neg    =      6.9 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 28
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features3', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# Total positive words:
# 32
# Top 10 positive words:
# [u'right', u'helped', u'best', u'lead', u'leading', u'top', u'creative', u'better', u'enough', u'won']
# Total positive words:
# 15
# Top 10 positive words:
# [u'risk', u'lost', u'vice', u'concerns', u'rival', u'hard', u'problems', u'crisis', u'fell', u'fall']
# ****************
# ACCURACY = 0.478888888889
# ****************
# Most Informative Features
#                     debt = True              neg : pos    =      6.0 : 1.0
#                   helped = True              pos : neg    =      5.3 : 1.0
#                  problem = True              neg : 0      =      5.3 : 1.0
#               successful = True              pos : 0      =      5.1 : 1.0
#                     lost = True              neg : pos    =      4.5 : 1.0
#                 problems = True              neg : 0      =      4.3 : 1.0
#                    super = True              pos : neg    =      3.9 : 1.0
#                     fell = True              neg : pos    =      3.9 : 1.0
#                   crisis = True              neg : pos    =      3.9 : 1.0
#                    right = True              pos : neg    =      3.6 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 29
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features2', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'shaye', u'revelers', u'woods', u'thirst']
# ----------------
# ****************
# ACCURACY = 0.475555555556
# ****************
# Most Informative Features
#                       '' = 2                   0 : pos    =     11.5 : 1.0
#                   losing = 1                 neg : pos    =     10.0 : 1.0
#                  schools = 1                 pos : 0      =      6.8 : 1.0
#                  effects = 1                 neg : pos    =      6.0 : 1.0
#              controversy = 1                 neg : pos    =      6.0 : 1.0
#                   mining = 1                 neg : pos    =      6.0 : 1.0
#                     debt = 1                 neg : pos    =      6.0 : 1.0
#                following = 1                 neg : pos    =      5.6 : 1.0
#                   saying = 1                 neg : 0      =      4.8 : 1.0
#                criticism = 1                 neg : pos    =      4.7 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 30
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features3', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'shaye', u'revelers', u'woods', u'thirst']
# ----------------
# Total positive words:
# 42
# Top 10 positive words:
# [u'golden', u'spiritual', u'willingness', u'awesome', u'premier', u'magnificent', u'logical', u'upscale', u'valiant', u'principled']
# Total positive words:
# 55
# Top 10 positive words:
# [u'criticism', u'obsessively', u'obese', u'doubts', u'foul', u'freeze', u'antagonistic', u'louder', u'thirst', u'stern']
# ****************
# ACCURACY = 0.483333333333
# ****************
# Most Informative Features
#                   losing = True              neg : pos    =     10.0 : 1.0
#                     debt = True              neg : pos    =      6.0 : 1.0
#                     fake = True              neg : pos    =      6.0 : 1.0
#              controversy = True              neg : pos    =      6.0 : 1.0
#                criticism = True              neg : pos    =      4.7 : 1.0
#                    angry = True              neg : pos    =      4.7 : 1.0
#                    split = True              neg : pos    =      4.4 : 1.0
#                  beloved = True              neg : pos    =      3.3 : 1.0
#                   worked = True                0 : neg    =      3.2 : 1.0
#                  premier = True              neg : pos    =      2.8 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 1
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 1
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'president']
# ----------------
# ****************
# ACCURACY = 0.468888888889
# ****************
# Most Informative Features
#                    force = True              neg : pos    =     12.6 : 1.0
#                  comment = True              neg : pos    =     10.6 : 1.0
#                    built = True                0 : neg    =      9.9 : 1.0
#                    space = True                0 : neg    =      9.3 : 1.0
#                scheduled = True                0 : neg    =      8.7 : 1.0
#                 declined = True              neg : pos    =      7.4 : 1.0
#                    filed = True              neg : 0      =      7.3 : 1.0
#                   hiring = True              neg : 0      =      7.0 : 1.0
#                     rose = True              pos : neg    =      7.0 : 1.0
#                     ever = True              pos : 0      =      6.8 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 2
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 1
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'.', u"'", u'said', u'chief', u'mr.', u'$', u'like', u';', u'would']
# ----------------
# ****************
# ACCURACY = 0.477777777778
# ****************
# Most Informative Features
#                    force = True              neg : pos    =     12.6 : 1.0
#                  comment = True              neg : pos    =     10.6 : 1.0
#                    built = True                0 : neg    =      9.9 : 1.0
#                    space = True                0 : neg    =      9.3 : 1.0
#                scheduled = True                0 : neg    =      8.7 : 1.0
#                 declined = True              neg : pos    =      7.4 : 1.0
#                    filed = True              neg : 0      =      7.3 : 1.0
#                   hiring = True              neg : 0      =      7.0 : 1.0
#                     rose = True              pos : neg    =      7.0 : 1.0
#                     ever = True              pos : 0      =      6.8 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 3
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': ['...']}
# majority
#
# iteration: 1
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u"'s", u'executive', u'said', u'chief', u'manager', u'apple', u'company', u'mr.', u'new', u'founder']
# ----------------
# ****************
# ACCURACY = 0.466666666667
# ****************
# Most Informative Features
#                    force = True              neg : pos    =     12.6 : 1.0
#                  comment = True              neg : pos    =     10.6 : 1.0
#                    built = True                0 : neg    =      9.9 : 1.0
#                    space = True                0 : neg    =      9.3 : 1.0
#                scheduled = True                0 : neg    =      8.7 : 1.0
#                 declined = True              neg : pos    =      7.4 : 1.0
#                    filed = True              neg : 0      =      7.3 : 1.0
#                     rose = True              pos : neg    =      7.0 : 1.0
#                 students = True              pos : 0      =      6.2 : 1.0
#                     debt = True              neg : pos    =      5.8 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 4
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': []}
# majority
#
# iteration: 1
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'the', u'of', u'a', u'to', u'in', u'that', u'for', u'is', u'said', u'on']
# ----------------
# ****************
# ACCURACY = 0.472222222222
# ****************
# Most Informative Features
#                    force = True              neg : pos    =     12.6 : 1.0
#                  comment = True              neg : pos    =     10.6 : 1.0
#                    built = True                0 : neg    =      9.9 : 1.0
#                    space = True                0 : neg    =      9.3 : 1.0
#                scheduled = True                0 : neg    =      8.7 : 1.0
#                 declined = True              neg : pos    =      7.4 : 1.0
#                     rose = True              pos : neg    =      7.0 : 1.0
#                 students = True              pos : 0      =      6.2 : 1.0
#                     debt = True              neg : pos    =      5.8 : 1.0
#                financing = True                0 : neg    =      5.6 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 5
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': ['...']}
# majority
#
# iteration: 1
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'.', u"'s", u"'", u'executive', u'said', u'chief', u'manager', u'apple', u'company']
# ----------------
# ****************
# ACCURACY = 0.457777777778
# ****************
# Most Informative Features
#                    force = True              neg : pos    =     12.6 : 1.0
# ...
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 23
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': ['...'], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 9
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'shaye', u'revelers', u'woods', u'thirst']
# ----------------
# ****************
# ACCURACY = 0.463333333333
# ****************
# Most Informative Features
#                   losing = True              neg : pos    =     10.0 : 1.0
#                  schools = True              pos : 0      =      7.1 : 1.0
#                 lapierre = True              neg : pos    =      6.0 : 1.0
#              controversy = True              neg : pos    =      6.0 : 1.0
#                     debt = True              neg : pos    =      5.7 : 1.0
#                   saying = True              neg : 0      =      5.2 : 1.0
#                     jury = True              neg : pos    =      5.2 : 1.0
#               threatened = True              neg : pos    =      4.7 : 1.0
#                  beloved = True              neg : pos    =      4.7 : 1.0
#               pioneering = True              neg : pos    =      4.7 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 24
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 9
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'shaye', u'revelers', u'woods', u'thirst']
# ----------------
# ****************
# ACCURACY = 0.463333333333
# ****************
# Most Informative Features
#                   losing = True              neg : pos    =     10.0 : 1.0
#                  schools = True              pos : 0      =      7.1 : 1.0
#                 lapierre = True              neg : pos    =      6.0 : 1.0
#              controversy = True              neg : pos    =      6.0 : 1.0
#                     debt = True              neg : pos    =      5.7 : 1.0
#                   saying = True              neg : 0      =      5.2 : 1.0
#                     jury = True              neg : pos    =      5.2 : 1.0
#               threatened = True              neg : pos    =      4.7 : 1.0
#                  beloved = True              neg : pos    =      4.7 : 1.0
#               pioneering = True              neg : pos    =      4.7 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 25
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features2', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 9
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'president']
# ----------------
# ****************
# ACCURACY = 0.433333333333
# ****************
# Most Informative Features
#                  comment = 1                 neg : pos    =     10.9 : 1.0
#                financing = 1                   0 : neg    =      9.5 : 1.0
#                    space = 1                   0 : neg    =      8.9 : 1.0
#                    built = 1                   0 : neg    =      8.9 : 1.0
#                    force = 1                 neg : pos    =      8.7 : 1.0
#                 declined = 1                 neg : pos    =      7.5 : 1.0
#               government = 2                 neg : pos    =      7.3 : 1.0
#                     rose = 1                 pos : neg    =      6.9 : 1.0
#                  problem = 1                 neg : 0      =      6.4 : 1.0
#                 festival = 1                   0 : neg    =      6.4 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 26
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features3', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 9
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'president']
# ----------------
# Total positive words:
# 35
# Top 10 positive words:
# [u'right', u'love', u'modern', u'helped', u'best', u'lead', u'leading', u'top', u'fans', u'creative']
# Total positive words:
# 17
# Top 10 positive words:
# [u'risk', u'lost', u'vice', u'concerns', u'rival', u'hard', u'problems', u'crisis', u'bad', u'fell']
# ****************
# ACCURACY = 0.487777777778
# ****************
# Most Informative Features
#                  problem = True              neg : 0      =      6.4 : 1.0
#                     debt = True              neg : pos    =      5.7 : 1.0
#                   crisis = True              neg : pos    =      4.5 : 1.0
#                    super = True              pos : neg    =      4.4 : 1.0
#                     fell = True              neg : pos    =      4.3 : 1.0
#                     died = True              neg : 0      =      4.2 : 1.0
#                     lost = True              neg : pos    =      4.1 : 1.0
#               successful = True              pos : 0      =      3.8 : 1.0
#                     love = True              pos : neg    =      3.7 : 1.0
#                    clear = True              neg : pos    =      3.7 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 27
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features2', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 9
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# ****************
# ACCURACY = 0.444444444444
# ****************
# Most Informative Features
#                  comment = 1                 neg : pos    =     10.9 : 1.0
#                    space = 1                   0 : neg    =      8.9 : 1.0
#                    built = 1                   0 : neg    =      8.9 : 1.0
#                    force = 1                 neg : pos    =      8.7 : 1.0
#                 declined = 1                 neg : pos    =      7.5 : 1.0
#               government = 2                 neg : pos    =      7.3 : 1.0
#                     rose = 1                 pos : neg    =      6.9 : 1.0
#                  problem = 1                 neg : 0      =      6.4 : 1.0
#                 festival = 1                   0 : neg    =      6.4 : 1.0
#                      tax = 2                 neg : pos    =      6.0 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 28
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features3', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 9
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# Total positive words:
# 32
# Top 10 positive words:
# [u'right', u'helped', u'best', u'lead', u'leading', u'top', u'creative', u'better', u'enough', u'won']
# Total positive words:
# 15
# Top 10 positive words:
# [u'risk', u'lost', u'vice', u'concerns', u'rival', u'hard', u'problems', u'crisis', u'fell', u'fall']
# ****************
# ACCURACY = 0.485555555556
# ****************
# Most Informative Features
#                  problem = True              neg : 0      =      6.4 : 1.0
#                     debt = True              neg : pos    =      5.7 : 1.0
#                   crisis = True              neg : pos    =      4.5 : 1.0
#                    super = True              pos : neg    =      4.4 : 1.0
#                     fell = True              neg : pos    =      4.3 : 1.0
#                     lost = True              neg : pos    =      4.1 : 1.0
#               successful = True              pos : 0      =      3.8 : 1.0
#                    clear = True              neg : pos    =      3.7 : 1.0
#                   helped = True              pos : neg    =      3.7 : 1.0
#                 problems = True              neg : 0      =      3.6 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 29
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features2', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 9
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'shaye', u'revelers', u'woods', u'thirst']
# ----------------
# ****************
# ACCURACY = 0.456666666667
# ****************
# Most Informative Features
#                   losing = 1                 neg : pos    =     10.0 : 1.0
#                  schools = 1                 pos : 0      =      6.7 : 1.0
#                 lapierre = 1                 neg : pos    =      6.0 : 1.0
#              controversy = 1                 neg : pos    =      6.0 : 1.0
#                   mining = 1                 neg : pos    =      6.0 : 1.0
#                     debt = 1                 neg : pos    =      5.7 : 1.0
#                 european = 2                   0 : pos    =      5.5 : 1.0
#                  natural = 1                 pos : neg    =      5.5 : 1.0
#                   saying = 1                 neg : 0      =      5.2 : 1.0
#                     jury = 1                 neg : pos    =      5.2 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 30
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features3', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 9
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'shaye', u'revelers', u'woods', u'thirst']
# ----------------
# Total positive words:
# 42
# Top 10 positive words:
# [u'golden', u'spiritual', u'willingness', u'awesome', u'premier', u'magnificent', u'logical', u'upscale', u'valiant', u'principled']
# Total positive words:
# 55
# Top 10 positive words:
# [u'criticism', u'obsessively', u'obese', u'doubts', u'foul', u'freeze', u'antagonistic', u'louder', u'thirst', u'stern']
# ****************
# ACCURACY = 0.48
# ****************
# Most Informative Features
#                   losing = True              neg : pos    =     10.0 : 1.0
#              controversy = True              neg : pos    =      6.0 : 1.0
#                     debt = True              neg : pos    =      5.7 : 1.0
#                  beloved = True              neg : pos    =      4.7 : 1.0
#                    split = True              neg : pos    =      4.4 : 1.0
#                criticism = True              neg : pos    =      3.3 : 1.0
#                  upscale = True                0 : pos    =      3.1 : 1.0
#                    boost = True              pos : neg    =      2.8 : 1.0
#                     fake = True              neg : pos    =      2.8 : 1.0
#                   strike = True              pos : 0      =      2.7 : 1.0
#
#
#
#
#
#
# **************** BEST RESULT ****************
# BEST OPTION: 26
# {'length': 1000, 'reverse': False, 'document_features': <function document_features3 at 0x7f9ee73b37d0>, 'numbers': True, 'stopwords_domain_in_features': False, 'punctuation': '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~', 'stopwords_domain': ['entrepreneur', 'startup', 'new', 'venture', 'manager', 'executive', 'founder', 'wal-mart', 'exxon', 'chevron', 'berkshire', 'hathaway', 'apple', 'samsung', 'phillips', '66', 'general', 'motors', 'ford', 'valero', 'exelon', 'corporation', 'dow', 'chemical', 'conocophillips', 'morgan', 'chase', 'world', 'fuel', 'services', 'illinois', 'tool', 'works', 'boeing', 'intel', 'corporation', 'pepsico', 'tjx', 'companies', 'costco', 'wholesale', 'metlife', 'blackrock', 'at&t', 'johnson', '&', 'johnson', 'abbott', 'laboratories', 'cvs', 'caremark', 'visa', 'cisco', 'systems', 'walt', 'disney', 'company', 'rock', 'tenn', 'company', 'halliburton', 'company', 'alcoa', 'fluor', 'corporation', 'general', 'electric', 'cbre', 'group', 'energy', 'transfer', 'equity', 'express', 'scripts', 'holding', 'hca', 'holdings', 'nrg', 'energy', 'aramark', 'holdings', 'corporation', 'honeywell', 'international', 'nike', 'amazon.com', 'procter', '&', 'gamble', 'unitedhealth', 'group', 'microsoft', 'Google', 'Salesforce', 'SAS', 'Quicken', 'Intuit', 'las', 'vegas', 'sands', 'autonation', '3m', 'company', 'danaher', 'corporation', 'new', 'york', 'life', 'insurance', 'company', 'mcdonalds', 'corporation', 'caterpillar', 'ryder', 'systems', 'd.r.', 'horton', 'stanley', 'black', '&', 'decker', 'archer', 'daniels', 'midland', 'coca-cola', 'company', 'united', 'continental', 'holdings', 'ingram', 'micro', 'chs', 'international', 'paper', 'company', 'mckesson', 'phillip', 'morris', 'international', 'state', 'farm', 'insurance', 'owens', 'corning', 'waste', 'management', 'c.h.', 'robinson', 'worldwide', 'harley-davidson', 'manpower', 'group', 'union', 'pacific', 'r.r', 'donnelley', '&', 'sons', 'company', 'graham', 'holdings', 'company', 'emc', 'corporation', 'mattel', 'united', 'parcel', 'service', 'omnicom', 'group', 'mckinsey', '&', 'company', 'pricewaterhousecoopers', 'intuitive', 'research', 'and', 'tech', 'international', 'bussiness', 'machines', 'formerly', 'BrightTag', 'aka', 'Wright', 'Foods', 'turospree.com', 'nirvanix.com', 'getpostrocket.com', 'votertide.com', 'gamelayers.com', 'unifyo.com', 'lookery.com', 'canv.as', 'blurtt.com', 'manilla.com', 'admaze.ly.com', 'springpad.com', 'ex.fm', 'sambamobile.com', 'qik.com', 'inbloom.org', 'intonow.com', 'getfindit.com', 'inqmobile.com', 'outboxmail.com', 'argylesocial.com', 'iamexec.com', 'stippleit.com', '500px', 'Inc', 'Wajam', 'Keek', 'Inc', 'GuySpy', 'Woozworld', 'TinEye', 'Idee', 'Inc', 'Jigsy', 'Voices.com', 'Snapsort', 'EmpireAvenue', 'Frank', 'and', 'Oak', 'LoginRadius', 'Chango', 'Inc', 'Pure', 'Energies', 'Group', 'Inc', 'Buytopia.ca', 'Smoke', 'NV', 'Inc', 'Just', 'Quality', 'International', 'Inc', 'Sterling', 'Cross', 'Defense', 'Systems', 'Corp', 'Magnet', 'Forensics', 'Inc', 'Greenlife', 'Water', 'Corp', 'Secure', 'Sense', 'Solutions', 'Sandstorm', 'Gold', 'Ltd', 'ScribbleLive', 'Technologies', 'Inc', 'TDot', 'Performance', 'Ltd', 'Redwood', 'Strategic', 'Inc', 'Emcision', 'International', 'Inc', 'Henkaa', 'Inc', 'Whirlscape', 'Inc', 'Bionym', 'Thalmic', 'Labs', 'Recon', 'Instruments', 'Om', 'Malik', 'Technology', 'Affino', 'AnalyzeRE', 'Atomic', 'Reach', 'Cloud', 'Dynamics', 'Exo', 'U', 'Fabric', 'Engine', 'Finmaven', 'Granify', 'InfraDog', 'Introhive', 'Invici', 'Technologies', 'Login', 'Radius', 'mnubo', 'Obero', 'Solutions', 'PeopleInsight', 'Procima', 'Experts', 'reelyActive', 'RtTech', 'Software', 'Seamless', 'Mobile', 'Health', 'Slyce', 'Smart', 'Employee', 'Benefits', 'SweetIQ', 'Thalmic', 'Labs', 'Vena', 'Solutions', 'WestonExprerssions', 'Linkett', '360pi', 'AcademixDirect', 'Inc', 'Adconion', 'Direct', 'Adesto', 'Technologies', 'Corporation', 'Alfresco', 'Aitierre', 'Corporation', 'Altitude', 'Digital', 'Anametrix', 'Aphios', 'Corporation', 'AppDirect', ' ...
# ('ACCURACY =', 0.5222222222222223)
# *********************************************

# %%
np.array(d_accuracies[7]).mean()
# Out:
# 0.47833333333333333

# %%
np.array(d_accuracies[7]).std()
# Out:
# 0.016157022705809668

# %%
for k in options:
    print(np.array(d_accuracies[k]).mean())
    print(np.array(d_accuracies[k]).std())
# Out:
# 0.465888888889
# 0.0151620872207
# 0.467222222222
# 0.0139243990495
# 0.468
# 0.013533679981
# 0.478777777778
# 0.0159044213125
# 0.469333333333
# 0.013601016665
# 0.482333333333
# 0.0143711817259
# 0.478333333333
# 0.0161570227058
# 0.480777777778
# 0.0149983538191
# 0.466666666667
# 0.0146565621759
# 0.467333333333
# 0.0144802973846
# 0.466666666667
# 0.0136716341469
# 0.478444444444
# 0.0149583784689
# 0.467222222222
# 0.0144209210165
# 0.481777777778
# 0.0129214148979
# 0.478222222222
# 0.0145568277646
# 0.480444444444
# 0.0133351850566
# 0.469444444444
# 0.0150738920728
# 0.469333333333
# 0.0152526055252
# 0.468333333333
# 0.0142746429762
# 0.468
# 0.0144768866444
# 0.469333333333
# 0.014974876079
# 0.469
# 0.0153272934964
# 0.468333333333
# 0.0143694635071
# 0.468111111111
# 0.0145894431646
# 0.454666666667
# 0.0115127411973
# 0.492777777778
# 0.0142486733192
# 0.461555555556
# 0.0161642800835
# 0.490666666667
# 0.0133906176846
# 0.471555555556
# 0.0174001560941
# 0.484555555556
# 0.0135487232326
