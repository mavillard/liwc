# %% [markdown]
# Preparing Data
# ==============

# %%
import json
import cPickle as pickle
import numpy as np
import pandas as pd
from pandas import factorize

# %%
# !ls bossa/*json
# Out:
# bossa/control_tasks.json       bossa/tasks_export.json
# bossa/control_tasks_runs.json  bossa/tasks_runs_export.json

# %% [markdown]
# BOSSA Results
# -------------

# %% [markdown]
# Processing `results_bossa.json` to get a *dictionary* with keys the task ids, and values in as the average value of the scores. To do that, we first convert scores from categorical (`neg`, `neu`, `pos`) to a numeric scale.

# %%
bossa_results = pd.read_json("bossa/control_tasks_runs.json")
bossa_results.rename(columns={"created": "start_time", "id": "result_id", "info": "score"}, inplace=True)
bossa_results[['start_time']]= bossa_results[['start_time']].apply(pd.to_datetime, dayfirst=True)
bossa_results[['finish_time']]= bossa_results[['finish_time']].apply(pd.to_datetime, dayfirst=True)
bossa_results['score'] = pd.Categorical(bossa_results['score'], categories=['vneg', 'neg', 'neu', 'pos', 'vpos'])
bossa_results['score'].cat.rename_categories([-2, -1, 0, 1, 2], inplace=True)
# Normalize everything to -1, 0, 1
# bossa_results['score'] = bossa_results['score'].astype(float).apply(lambda x: -1 if x < 0 else 1 if x > 0 else 0)
bossa_results["seconds"] = (bossa_results["finish_time"] - bossa_results["start_time"]).astype('timedelta64[us]') / 1e6
bossa_results = bossa_results[["result_id", "seconds", "task_id", "score"]]
bossa_results.ix[[50]]
# Out:
#     result_id   seconds  task_id score
# 50      60199  0.000021    61882     1

# %% [markdown]
# The information about the sentence comes in a dictionary inside the cells of the serie `info`, so we expand it.

# %%
bossa_tasks = pd.read_json("bossa/control_tasks.json")
bossa_tasks[['created']]= bossa_tasks[['created']].apply(pd.to_datetime, dayfirst=True)
bossa_tasks.rename(columns={'id': 'task_id'}, inplace=True)
bossa_tasks = bossa_tasks[['task_id', 'info']]
bossa_tasks.ix[[50]]
# Out:
#     task_id                                               info
# 50    61838  {u'id': u'76', u'sentence': u'The house, which...

# %% [markdown]
# And finally we merge the `DataFrame` with the scores with the one containing the sentences.

# %%
bossa_tasks_scores = pd.merge(bossa_results, bossa_tasks, on='task_id')
bossa_tasks_scores.ix[[50]]
# Out:
#     result_id  seconds  task_id  score  \
# 50      60496  0.00002    61779     -1
#
#                                                  info
# 50  {u'id': u'17', u'sentence': u'The veteran, Eri...

# %% [markdown]
# Let's now expand the column `info` into as many new columns as keys has the dictionary `info`.

# %%
bossa_tasks_scores.ix[50].info.keys()
# Out:
# [u'id', u'sentence']

# %%
def json_to_series(info):
    keys, values = zip(*info.iteritems())
    return pd.Series(values, index=keys)

bossa_info = bossa_tasks_scores["info"].apply(json_to_series)
bossa_info.reset_index()
bossa = pd.concat([bossa_tasks_scores, bossa_info], axis=1)
bossa.pop("info")
# bossa['id'] = bossa['id'].astype(float)
bossa.ix[50:53]
# Out:
#     result_id   seconds  task_id  score  id  \
# 50      60496  0.000020    61779     -1  17
# 51      60097  0.000027    61780      1  18
# 52      60297  0.000022    61780      1  18
# 53      60497  0.000023    61780      0  18
#
#                                              sentence
# 50  The veteran, Eric Harroun, 31, of Phoenix, had...
# 51  The Mets' four-game sweep of the Yankees was b...
# 52  The Mets' four-game sweep of the Yankees was b...
# 53  The Mets' four-game sweep of the Yankees was b...

# %% [markdown]
# Aggregate
# ---------

# %% [markdown]
# We now aggregate calculating the average per `sentence_id` using a group by. In the process, we lose the source of the data, that's why we first have to save it.

# %%
bossa.to_csv("sentiment/control_scores_ungrouped.csv", encoding="utf8")

# %% [markdown]
# Finally, we aggregate and create a new `DataFrame` for the different sentences and their score.

# %%
sentences = bossa.groupby(['sentence'])[['score']].aggregate(np.average)
sentences.to_csv("sentiment/control_scores.csv", encoding="utf8")
print sentences.count()
sentences[51:54]
# Out:
# score    199
# dtype: int64
#                                                                                                                                                                                                                              score
# sentence
# Dark floors and sunken rooms on the first floor could be challenging for small children and visitors.                                                                                                                    -0.666667
# Dozens of cars were scorched, and a ghostly layer of ash coated the shelves of a supermarket                                                                                                                             -1.000000
# Ecuador's government expressed "outrage and dismay" and warned the rebels, believed to be members of the Revolutionary Armed Forces of Colombia, or FARC, that it would be "relentless" in the defense of its territory.  0.333333

# %%
from collections import Counter

def majority(series): #receives a Pandas Series
    return Counter(map(lambda x: 1 if x > 0 else -1 if x < 0 else 0, series)).most_common(1)[0][0]

# score_calculate = np.average
score_calculate = majority

sentences = bossa.groupby(['sentence'])[['score']].aggregate(score_calculate)

# %% [markdown]
# Sentence Classifier
# -------------------

# %%
from nltk.corpus import stopwords
from sklearn.cross_validation import cross_val_score
from sklearn.grid_search import GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import precision_recall_fscore_support
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC

# %% [markdown]
# Create the tranining and testing sets (data and labels) from a randomized version of the set of assessed sentences.

# %%
sentences.reset_index().count()
# Out:
# sentence    8996
# score       8996
# dtype: int64

# %% [markdown]
# We could consider 3 classes, but it toruns out that using binary classficication seems to produce better results. Still, try multi-classs classifiers is something worth trying.

# %%
raw_scores = sentences.reset_index()
scores = raw_scores
scores = scores[scores.score!=0]  # We ignore the neutral sentences
scores['sentiment'] = scores['score'].apply(lambda s: 'pos' if s > 0 else 'neg')
# percentage = 0.85  #  percentage for training, rest for for testing
# # We split to have enough representativenesss for both positive and negative sentiments
# sent_min = min(
#     scores[scores.sentiment=='pos'].sentiment.count(),
#     scores[scores.sentiment=='neg'].sentiment.count(),
# )
# scores = scores[["sentence", "sentiment"]]
# train_data = np.array([])
# train_labels = np.array([])
# test_data = np.array([])
# test_labels = np.array([])
# for sent in ('pos', 'neg'):
#     sent_scores = scores[scores['sentiment']==sent]
#     sent_scores = sent_scores.reindex(np.random.permutation(sent_scores.index))
#     sent_sentences_count = int(sent_scores['sentence'].count())
#     sent_train = sent_scores[["sentence", "sentiment"]][:int(sent_sentences_count * percentage)]
#     sent_test = sent_scores[["sentence", "sentiment"]][int(sent_sentences_count * percentage) + 1:]
#     print sent, sent_min, sent_train.sentiment.count(), sent_test.sentiment.count()
#     train_data = np.append(train_data, sent_train["sentence"])
#     train_labels = np.append(train_labels, sent_train["sentiment"])
#     test_data = np.append(test_data, sent_test["sentence"])
#     test_labels = np.append(test_labels, sent_test["sentiment"])
# Out:
# /home/antonio/.virtualenvs/lexisnexis/lib/python2.7/site-packages/IPython/kernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# #NLTK

# %%
document_df = scores[['sentence', 'sentiment']]
document_df = document_df.reindex(np.random.permutation(document_df.index))

# %%
document_df.head()
# Out:
#                                                sentence sentiment
# 6881  Ten miles north of the Robert Mondavi Winery i...       pos
# 6936  That re-created surface filled with objects in...       pos
# 5593  Mr. Wheeler served from 1992 to 2004 as the ch...       pos
# 5248  Mitch Nash, a Lenox, Mass., based art director...       pos
# 1599  Alcoa, based in Pittsburgh, released its earni...       neg

# %%
original_documents = [(r[1]['sentence'], r[1]['sentiment']) for r in document_df.iterrows()]

# %%
pos_file = open('positive-words.txt')
all_pos_words = [w.strip().lower() for w in pos_file]

neg_file = open('negative-words.txt')
all_neg_words = [w.strip().lower() for w in neg_file]

# %%
search_terms_f = open('search_terms.txt')
search_terms = []
for t in search_terms_f:
    l = t.strip().split()
    search_terms.extend(l)

# %%
import string

import nltk
from nltk.corpus import stopwords

# %% [markdown]
# ###Options

# %%
#stopwords_english
stopwords_english = stopwords.words('english')
#stopwords_domain
stopwords_domain = search_terms + ["'s", '--']
#stopwords_english
punctuation = string.punctuation

# %%
def document_features1(document):      
    document_words = set(document)
    features = {}
    for word in word_features:
        features[word] = word in document_words
    return features

# %%
def document_features2(document):      
    document_words = list(document)
    features = {}
    for word in document_words:
        if word in word_features:
            features[word] = features.get(word, 0) + 1
    return features

# %%
def document_features3(document):
    word_features3 = list(pos_words) + list(neg_words)
    document_words = set(document)
    features = {}
    for word in word_features3:
        features[word] = word in document_words
    return features

# %%
# Filter stopwords, punctuation marks, and numbers
# 'stopwords_english': stopwords_english,
# 'stopwords_domain': stopwords_domain,
# 'punctuation': punctuation,
# 'numbers': True,
#
# Do not filter stopwords, punctuation marks, or numbers
# 'stopwords_english': [],
# 'stopwords_domain': [],
# 'punctuation': [],
# 'numbers': False,

options = {}

#Option 1
opt1 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[1] = opt1

#Option 2
opt2 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': [],
    'numbers': True,
}
options[2] = opt2

#Option 3
opt3 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': [],
    'punctuation': punctuation,
    'numbers': True,
}
options[3] = opt3

#Option 4
opt4 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[4] = opt4

#Option 5
opt5 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': True,
}
options[5] = opt5

#Option 6
opt6 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': punctuation,
    'numbers': True,
}
options[6] = opt6

#Option 7
opt7 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': stopwords_domain,
    'punctuation': [],
    'numbers': True,
}
options[7] = opt7

#Option 8
opt8 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': True,
}
options[8] = opt8

#Option 9
opt9 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': False,
}
options[9] = opt9

#Option 10
opt10 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': [],
    'numbers': False,
}
options[10] = opt10

#Option 11
opt11 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': [],
    'punctuation': punctuation,
    'numbers': False,
}
options[11] = opt11

#Option 12
opt12 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': False,
}
options[12] = opt12

#Option 13
opt13 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[13] = opt13

#Option 14
opt14 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': punctuation,
    'numbers': False,
}
options[14] = opt14

#Option 15
opt15 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': stopwords_domain,
    'punctuation': [],
    'numbers': False,
}
options[15] = opt15

#Option 16
opt16 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[16] = opt16

#Option 17
opt17 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': [],
    'punctuation': punctuation,
    'numbers': True,
}
options[17] = opt17

#Option 18
opt18 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': True,
}
options[18] = opt18

#Option 19
opt19 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': punctuation,
    'numbers': True,
}
options[19] = opt19

#Option 20
opt20 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': True,
}
options[20] = opt20

#Option 21
opt21 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': [],
    'punctuation': punctuation,
    'numbers': False,
}
options[21] = opt21

#Option 22
opt22 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features1,
    'stopwords_english': stopwords_english,
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[22] = opt22

#Option 23
opt23 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': punctuation,
    'numbers': False,
}
options[23] = opt23

#Option 24
opt24 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features1,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[24] = opt24

################################################################################################

#Option 25
opt25 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features2,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[25] = opt25

#Option 26
opt26 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features3,
    'stopwords_english': stopwords_english,
    'stopwords_domain': stopwords_domain,
    'punctuation': punctuation,
    'numbers': True,
}
options[26] = opt26

#Option 27
opt27 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features2,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[27] = opt27

#Option 28
opt28 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': False,
    'document_features': document_features3,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[28] = opt28

#Option 29
opt29 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features2,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[29] = opt29

#Option 30
opt30 = {
    'length': 1000,
    'reverse': False,
    'stopwords_domain_in_features': True,
    'document_features': document_features3,
    'stopwords_english': [],
    'stopwords_domain': [],
    'punctuation': [],
    'numbers': False,
}
options[30] = opt30

# %%
def filt(x):
    c1 = x not in options[opt]['stopwords_english']
    c2 = x not in options[opt]['stopwords_domain']
    c3 = x not in options[opt]['punctuation']
    c4 = True if options[opt]['numbers'] else not x.isdigit()
    
    cs = [c1, c2, c3, c4]
    return all(cs)
 
def preprocess(text):
    text = text.lower()
    tokens = nltk.word_tokenize(text)
    filtered_words = filter(filt, tokens)
    return filtered_words

def print_option(opt):
    d = dict(opt)
    for k in d:
        if (type(d[k]) == list or type(d[k]) == str) and len(d[k]) > 0:
            d[k] = ['...']
        elif hasattr(d[k], '__call__'):
            d[k] = d[k].func_name
    print(d)

# %%
#%%prun -l4
from collections import defaultdict
from random import shuffle

best_option = None
best_accuracy = 0
best_index = 0
d_accuracies = defaultdict(list)

all_words = [w.lower() for d in original_documents for w in nltk.word_tokenize(d[0])]

for i in range(10):
    shuffle(original_documents)
    for opt in options:
        print('=======================================================')
        print('RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:')
        print('\nOption {}'.format(opt))
        print_option(options[opt])
        print(score_calculate.func_name)
        print('\niteration: {}\n'.format(i))
        
        documents = [(preprocess(d[0]), d[1]) for d in original_documents]
        filtered_words = filter(filt, all_words)
        freq_dist = nltk.FreqDist(filtered_words)
        most_common_words = [word for word, freq in freq_dist.most_common()]
        most_common_words = filter(filt, most_common_words)

        if options[opt]['stopwords_domain_in_features']:
            most_common_words = list(set(most_common_words).difference(search_terms))
        if options[opt]['reverse']:
            most_common_words.reverse()
        
        word_features = most_common_words[:options[opt]['length']]
        print('----------------')
        print('Total features:')
        print(options[opt]['length'])
        print('Top 10 features:')
        print(word_features[:10])
        print('----------------')

        if options[opt]['document_features'] == document_features3:
            pos_words = set(all_pos_words).intersection(word_features)
            print('Total positive words:')
            print(len(pos_words))
            print('Top 10 positive words:')
            print list(pos_words)[:10]

            neg_words = set(all_neg_words).intersection(word_features)
            print('Total positive words:')
            print(len(neg_words))
            print('Top 10 positive words:')
            print list(neg_words)[:10]

        featureset = [(options[opt]['document_features'](d[0]), d[1]) for d in documents]
        size = int(len(featureset) * 0.9)
        train_set = featureset[:size]
        test_set = featureset[size:]

        classifier = nltk.NaiveBayesClassifier.train(train_set)
        accuracy = nltk.classify.accuracy(classifier, test_set)
        print('****************')
        print('ACCURACY = {}'.format(accuracy))
        print('****************')
        classifier.show_most_informative_features(10)
        print('\n\n\n\n\n')
        d_accuracies[opt].append(accuracy)

        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_option = options[opt]
            best_index = opt

print('**************** BEST RESULT ****************')
print('BEST OPTION: {}'.format(best_index))
print(best_option)
print('ACCURACY =', best_accuracy)
print('*********************************************')
# Out:
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 1
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'last']
# ----------------
# ****************
# ACCURACY = 0.702579666161
# ****************
# Most Informative Features
#                  accused = True              neg : pos    =     25.6 : 1.0
#                  comment = True              neg : pos    =      8.4 : 1.0
#                    force = True              neg : pos    =      8.1 : 1.0
#                 declined = True              neg : pos    =      7.7 : 1.0
#                    built = True              pos : neg    =      7.3 : 1.0
#                     rose = True              pos : neg    =      7.0 : 1.0
#                    space = True              pos : neg    =      6.6 : 1.0
#                 positive = True              pos : neg    =      5.9 : 1.0
#                   gained = True              pos : neg    =      5.9 : 1.0
#                    bride = True              pos : neg    =      5.9 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 2
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'.', u"'", u'said', u'chief', u'mr.', u'$', u'like', u'would', u'director']
# ----------------
# ****************
# ACCURACY = 0.693474962064
# ****************
# Most Informative Features
#                  accused = True              neg : pos    =     25.6 : 1.0
#                  comment = True              neg : pos    =      8.4 : 1.0
#                    force = True              neg : pos    =      8.1 : 1.0
#                 declined = True              neg : pos    =      7.7 : 1.0
#                    built = True              pos : neg    =      7.3 : 1.0
#                     rose = True              pos : neg    =      7.0 : 1.0
#                    space = True              pos : neg    =      6.6 : 1.0
#                 positive = True              pos : neg    =      5.9 : 1.0
#                   gained = True              pos : neg    =      5.9 : 1.0
#                    bride = True              pos : neg    =      5.9 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 3
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u"'s", u'executive', u'said', u'chief', u'apple', u'company', u'manager', u'mr.', u'new', u'--']
# ----------------
# ****************
# ACCURACY = 0.682852807284
# ****************
# Most Informative Features
#                  comment = True              neg : pos    =      8.4 : 1.0
#                    force = True              neg : pos    =      8.1 : 1.0
#                 declined = True              neg : pos    =      7.7 : 1.0
#                    built = True              pos : neg    =      7.3 : 1.0
#                     rose = True              pos : neg    =      7.0 : 1.0
#                    space = True              pos : neg    =      6.6 : 1.0
#                 positive = True              pos : neg    =      5.9 : 1.0
#                    bride = True              pos : neg    =      5.9 : 1.0
#            investigation = True              neg : pos    =      5.7 : 1.0
#                     debt = True              neg : pos    =      5.6 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 4
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'the', u'of', u'a', u'to', u'in', u'that', u'for', u'is', u'said', u'on']
# ----------------
# ****************
# ACCURACY = 0.691957511381
# ****************
# Most Informative Features
#                  comment = True              neg : pos    =      8.4 : 1.0
#                    force = True              neg : pos    =      8.1 : 1.0
#                 declined = True              neg : pos    =      7.7 : 1.0
#                    built = True              pos : neg    =      7.3 : 1.0
#                     rose = True              pos : neg    =      7.0 : 1.0
#                    space = True              pos : neg    =      6.6 : 1.0
#                 positive = True              pos : neg    =      5.9 : 1.0
#            investigation = True              neg : pos    =      5.7 : 1.0
#                     debt = True              neg : pos    =      5.6 : 1.0
#                 criminal = True              neg : pos    =      5.6 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 5
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'.', u"'s", u"'", u'executive', u'said', u'chief', u'apple', u'company', u'manager']
# ----------------
# ****************
# ACCURACY = 0.675265553869
# ****************
# Most Informative Features
#                  comment = True              neg : pos    =      8.4 : 1.0
#                    force = True              neg : pos    =      8.1 : 1.0
#                 declined = True              neg : pos    =      7.7 : 1.0
#                    built = True              pos : neg    =      7.3 : 1.0
#                     rose = True              pos : neg    =      7.0 : 1.0
#                    space = True              pos : neg    =      6.6 : 1.0
#                 positive = True              pos : neg    =      5.9 : 1.0
#                    bride = True              pos : neg    =      5.9 : 1.0
#            investigation = True              neg : pos    =      5.7 : 1.0
#                     debt = True              neg : pos    =      5.6 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 6
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'the', u'of', u'and', u'a', u'to', u'in', u"'s", u'that', u'for', u'executive']
# ----------------
# ****************
# ACCURACY = 0.669195751138
# ****************
# Most Informative Features
#                  comment = True              neg : pos    =      8.4 : 1.0
#                 declined = True              neg : pos    =      7.7 : 1.0
#                    built = True              pos : neg    =      7.3 : 1.0
#                     rose = True              pos : neg    =      7.0 : 1.0
#            investigation = True              neg : pos    =      5.7 : 1.0
#                     debt = True              neg : pos    =      5.6 : 1.0
#                    groom = True              pos : neg    =      5.4 : 1.0
#                    clear = True              neg : pos    =      5.3 : 1.0
#                     died = True              neg : pos    =      5.1 : 1.0
#                  charges = True              neg : pos    =      5.0 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 7
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'the', u'.', u'of', u'a', u'to', u'in', u'that', u'for', u"'"]
# ----------------
# ****************
# ACCURACY = 0.681335356601
# ****************
# Most Informative Features
#                  comment = True              neg : pos    =      8.4 : 1.0
#                    force = True              neg : pos    =      8.1 : 1.0
#                 declined = True              neg : pos    =      7.7 : 1.0
#                    built = True              pos : neg    =      7.3 : 1.0
#                     rose = True              pos : neg    =      7.0 : 1.0
#                    space = True              pos : neg    =      6.6 : 1.0
#                 positive = True              pos : neg    =      5.9 : 1.0
#            investigation = True              neg : pos    =      5.7 : 1.0
#                     debt = True              neg : pos    =      5.6 : 1.0
#                 criminal = True              neg : pos    =      5.6 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 8
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# ****************
# ACCURACY = 0.673748103187
# ****************
# Most Informative Features
#                  comment = True              neg : pos    =      8.4 : 1.0
#                 declined = True              neg : pos    =      7.7 : 1.0
#                    built = True              pos : neg    =      7.3 : 1.0
#                     rose = True              pos : neg    =      7.0 : 1.0
#            investigation = True              neg : pos    =      5.7 : 1.0
#                     debt = True              neg : pos    =      5.6 : 1.0
#                    groom = True              pos : neg    =      5.4 : 1.0
#                    clear = True              neg : pos    =      5.3 : 1.0
#                     died = True              neg : pos    =      5.1 : 1.0
#                     bowl = True              pos : neg    =      4.4 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 9
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'last']
# ----------------
# ****************
# ACCURACY = 0.705614567527
# ****************
# Most Informative Features
#                  accused = True              neg : pos    =     25.6 : 1.0
#                  comment = True              neg : pos    =      8.4 : 1.0
#                    force = True              neg : pos    =      8.1 : 1.0
#                 declined = True              neg : pos    =      7.7 : 1.0
#                    built = True              pos : neg    =      7.3 : 1.0
#                     rose = True              pos : neg    =      7.0 : 1.0
#                    space = True              pos : neg    =      6.6 : 1.0
#                 positive = True              pos : neg    =      5.9 : 1.0
#                   gained = True              pos : neg    =      5.9 : 1.0
#                    bride = True              pos : neg    =      5.9 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 10
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'.', u"'", u'said', u'chief', u'mr.', u'$', u'like', u'would', u'director']
# ----------------
# ****************
# ACCURACY = 0.694992412747
# ****************
# Most Informative Features
#                  accused = True              neg : pos    =     25.6 : 1.0
#                  comment = True              neg : pos    =      8.4 : 1.0
#                    force = True              neg : pos    =      8.1 : 1.0
#                 declined = True              neg : pos    =      7.7 : 1.0
#                    built = True              pos : neg    =      7.3 : 1.0
#                     rose = True              pos : neg    =      7.0 : 1.0
#                    space = True              pos : neg    =      6.6 : 1.0
#                 positive = True              pos : neg    =      5.9 : 1.0
#                   gained = True              pos : neg    =      5.9 : 1.0
#                    bride = True              pos : neg    =      5.9 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 11
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u"'s", u'executive', u'said', u'chief', u'apple', u'company', u'manager', u'mr.', u'new', u'--']
# ----------------
# ****************
# ACCURACY = 0.690440060698
# ****************
# Most Informative Features
#                  comment = True              neg : pos    =      8.4 : 1.0
#                    force = True              neg : pos    =      8.1 : 1.0
#                 declined = True              neg : pos    =      7.7 : 1.0
#                    built = True              pos : neg    =      7.3 : 1.0
#                     rose = True              pos : neg    =      7.0 : 1.0
#                    space = True              pos : neg    =      6.6 : 1.0
#                 positive = True              pos : neg    =      5.9 : 1.0
#                   gained = True              pos : neg    =      5.9 : 1.0
#                    bride = True              pos : neg    =      5.9 : 1.0
#            investigation = True              neg : pos    =      5.7 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 12
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'the', u'of', u'a', u'to', u'in', u'that', u'for', u'is', u'said', u'on']
# ----------------
# ****************
# ACCURACY = 0.699544764795
# ****************
# Most Informative Features
#                  comment = True              neg : pos    =      8.4 : 1.0
#                    force = True              neg : pos    =      8.1 : 1.0
#                 declined = True              neg : pos    =      7.7 : 1.0
#                    built = True              pos : neg    =      7.3 : 1.0
#                     rose = True              pos : neg    =      7.0 : 1.0
#                    space = True              pos : neg    =      6.6 : 1.0
#                 positive = True              pos : neg    =      5.9 : 1.0
#                    bride = True              pos : neg    =      5.9 : 1.0
#            investigation = True              neg : pos    =      5.7 : 1.0
#                     debt = True              neg : pos    =      5.6 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 13
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'.', u"'s", u"'", u'executive', u'said', u'chief', u'apple', u'company', u'manager']
# ----------------
# ****************
# ACCURACY = 0.687405159332
# ****************
# Most Informative Features
#                  comment = True              neg : pos    =      8.4 : 1.0
#                    force = True              neg : pos    =      8.1 : 1.0
#                 declined = True              neg : pos    =      7.7 : 1.0
#                    built = True              pos : neg    =      7.3 : 1.0
#                     rose = True              pos : neg    =      7.0 : 1.0
#                    space = True              pos : neg    =      6.6 : 1.0
#                 positive = True              pos : neg    =      5.9 : 1.0
#                    bride = True              pos : neg    =      5.9 : 1.0
#            investigation = True              neg : pos    =      5.7 : 1.0
#                     debt = True              neg : pos    =      5.6 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 14
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'the', u'of', u'and', u'a', u'to', u'in', u"'s", u'that', u'for', u'executive']
# ----------------
# ****************
# ACCURACY = 0.672230652504
# ****************
# Most Informative Features
#                  comment = True              neg : pos    =      8.4 : 1.0
#                 declined = True              neg : pos    =      7.7 : 1.0
#                    built = True              pos : neg    =      7.3 : 1.0
#                     rose = True              pos : neg    =      7.0 : 1.0
#            investigation = True              neg : pos    =      5.7 : 1.0
#                     debt = True              neg : pos    =      5.6 : 1.0
#                    groom = True              pos : neg    =      5.4 : 1.0
#                    clear = True              neg : pos    =      5.3 : 1.0
#                     died = True              neg : pos    =      5.1 : 1.0
#                  charges = True              neg : pos    =      5.0 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 15
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'the', u'.', u'of', u'a', u'to', u'in', u'that', u'for', u"'"]
# ----------------
# ****************
# ACCURACY = 0.690440060698
# ****************
# Most Informative Features
#                  comment = True              neg : pos    =      8.4 : 1.0
#                    force = True              neg : pos    =      8.1 : 1.0
#                 declined = True              neg : pos    =      7.7 : 1.0
#                    built = True              pos : neg    =      7.3 : 1.0
#                     rose = True              pos : neg    =      7.0 : 1.0
#                    space = True              pos : neg    =      6.6 : 1.0
#                 positive = True              pos : neg    =      5.9 : 1.0
#            investigation = True              neg : pos    =      5.7 : 1.0
#                     debt = True              neg : pos    =      5.6 : 1.0
#                 criminal = True              neg : pos    =      5.6 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 16
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# ****************
# ACCURACY = 0.669195751138
# ****************
# Most Informative Features
#                  comment = True              neg : pos    =      8.4 : 1.0
#                 declined = True              neg : pos    =      7.7 : 1.0
#                    built = True              pos : neg    =      7.3 : 1.0
#                     rose = True              pos : neg    =      7.0 : 1.0
#            investigation = True              neg : pos    =      5.7 : 1.0
#                     debt = True              neg : pos    =      5.6 : 1.0
#                    groom = True              pos : neg    =      5.4 : 1.0
#                    clear = True              neg : pos    =      5.3 : 1.0
#                     died = True              neg : pos    =      5.1 : 1.0
#                  charges = True              neg : pos    =      5.0 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 17
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'four', u'woods', u'woody', u'cyprus']
# ----------------
# ****************
# ACCURACY = 0.688922610015
# ****************
# Most Informative Features
#                   losing = True              neg : pos    =      9.9 : 1.0
#              controversy = True              neg : pos    =      7.2 : 1.0
#                  effects = True              neg : pos    =      5.9 : 1.0
#            investigation = True              neg : pos    =      5.7 : 1.0
#                     debt = True              neg : pos    =      5.6 : 1.0
#                   ground = True              neg : pos    =      5.1 : 1.0
#                     jury = True              neg : pos    =      5.1 : 1.0
#               threatened = True              neg : pos    =      4.6 : 1.0
#                 innocent = True              neg : pos    =      4.6 : 1.0
#                    argue = True              neg : pos    =      4.6 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 18
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': [], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'four', u'woods', u'woody', u'cyprus']
# ----------------
# ****************
# ACCURACY = 0.690440060698
# ****************
# Most Informative Features
#                   losing = True              neg : pos    =      9.9 : 1.0
#              controversy = True              neg : pos    =      7.2 : 1.0
#                  effects = True              neg : pos    =      5.9 : 1.0
#            investigation = True              neg : pos    =      5.7 : 1.0
#                     debt = True              neg : pos    =      5.6 : 1.0
#                   ground = True              neg : pos    =      5.1 : 1.0
#                     jury = True              neg : pos    =      5.1 : 1.0
#               threatened = True              neg : pos    =      4.6 : 1.0
#                 innocent = True              neg : pos    =      4.6 : 1.0
#                    argue = True              neg : pos    =      4.6 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 19
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'four', u'woods', u'woody', u'cyprus']
# ----------------
# ****************
# ACCURACY = 0.685887708649
# ****************
# Most Informative Features
#                   losing = True              neg : pos    =      9.9 : 1.0
#              controversy = True              neg : pos    =      7.2 : 1.0
#                  effects = True              neg : pos    =      5.9 : 1.0
#            investigation = True              neg : pos    =      5.7 : 1.0
#                     debt = True              neg : pos    =      5.6 : 1.0
#                   ground = True              neg : pos    =      5.1 : 1.0
#                     jury = True              neg : pos    =      5.1 : 1.0
#               threatened = True              neg : pos    =      4.6 : 1.0
#                 innocent = True              neg : pos    =      4.6 : 1.0
#                    argue = True              neg : pos    =      4.6 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 20
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': [], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'four', u'woods', u'woody', u'cyprus']
# ----------------
# ****************
# ACCURACY = 0.685887708649
# ****************
# Most Informative Features
#                   losing = True              neg : pos    =      9.9 : 1.0
#              controversy = True              neg : pos    =      7.2 : 1.0
#                  effects = True              neg : pos    =      5.9 : 1.0
#            investigation = True              neg : pos    =      5.7 : 1.0
#                     debt = True              neg : pos    =      5.6 : 1.0
#                   ground = True              neg : pos    =      5.1 : 1.0
#                     jury = True              neg : pos    =      5.1 : 1.0
#               threatened = True              neg : pos    =      4.6 : 1.0
#                 innocent = True              neg : pos    =      4.6 : 1.0
#                    argue = True              neg : pos    =      4.6 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 21
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': ['...'], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'four', u'woods', u'woody', u'cyprus']
# ----------------
# ****************
# ACCURACY = 0.688922610015
# ****************
# Most Informative Features
#                   losing = True              neg : pos    =      9.9 : 1.0
#              controversy = True              neg : pos    =      7.2 : 1.0
#                  effects = True              neg : pos    =      5.9 : 1.0
#            investigation = True              neg : pos    =      5.7 : 1.0
#                     debt = True              neg : pos    =      5.6 : 1.0
#                   ground = True              neg : pos    =      5.1 : 1.0
#                     jury = True              neg : pos    =      5.1 : 1.0
#               threatened = True              neg : pos    =      4.6 : 1.0
#                 innocent = True              neg : pos    =      4.6 : 1.0
#                    argue = True              neg : pos    =      4.6 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 22
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'four', u'woods', u'woody', u'cyprus']
# ----------------
# ****************
# ACCURACY = 0.690440060698
# ****************
# Most Informative Features
#                   losing = True              neg : pos    =      9.9 : 1.0
#              controversy = True              neg : pos    =      7.2 : 1.0
#                  effects = True              neg : pos    =      5.9 : 1.0
#            investigation = True              neg : pos    =      5.7 : 1.0
#                     debt = True              neg : pos    =      5.6 : 1.0
#                   ground = True              neg : pos    =      5.1 : 1.0
#                     jury = True              neg : pos    =      5.1 : 1.0
#               threatened = True              neg : pos    =      4.6 : 1.0
#                 innocent = True              neg : pos    =      4.6 : 1.0
#                    argue = True              neg : pos    =      4.6 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 23
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': ['...'], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'four', u'woods', u'woody', u'cyprus']
# ----------------
# ****************
# ACCURACY = 0.684370257967
# ****************
# Most Informative Features
#                   losing = True              neg : pos    =      9.9 : 1.0
#              controversy = True              neg : pos    =      7.2 : 1.0
#                  effects = True              neg : pos    =      5.9 : 1.0
#            investigation = True              neg : pos    =      5.7 : 1.0
#                     debt = True              neg : pos    =      5.6 : 1.0
#                   ground = True              neg : pos    =      5.1 : 1.0
#                     jury = True              neg : pos    =      5.1 : 1.0
#               threatened = True              neg : pos    =      4.6 : 1.0
#                 innocent = True              neg : pos    =      4.6 : 1.0
#                    argue = True              neg : pos    =      4.6 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 24
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'four', u'woods', u'woody', u'cyprus']
# ----------------
# ****************
# ACCURACY = 0.684370257967
# ****************
# Most Informative Features
#                   losing = True              neg : pos    =      9.9 : 1.0
#              controversy = True              neg : pos    =      7.2 : 1.0
#                  effects = True              neg : pos    =      5.9 : 1.0
#            investigation = True              neg : pos    =      5.7 : 1.0
#                     debt = True              neg : pos    =      5.6 : 1.0
#                   ground = True              neg : pos    =      5.1 : 1.0
#                     jury = True              neg : pos    =      5.1 : 1.0
#               threatened = True              neg : pos    =      4.6 : 1.0
#                 innocent = True              neg : pos    =      4.6 : 1.0
#                    argue = True              neg : pos    =      4.6 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 25
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features2', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'last']
# ----------------
# ****************
# ACCURACY = 0.669195751138
# ****************
# Most Informative Features
#                  accused = 1                 neg : pos    =     25.6 : 1.0
#                  comment = 1                 neg : pos    =      8.4 : 1.0
#                    force = 1                 neg : pos    =      8.1 : 1.0
#                 declined = 1                 neg : pos    =      7.7 : 1.0
#                    built = 1                 pos : neg    =      7.3 : 1.0
#                     rose = 1                 pos : neg    =      6.6 : 1.0
#                 criminal = 1                 neg : pos    =      6.3 : 1.0
#                    space = 1                 pos : neg    =      5.9 : 1.0
#                   gained = 1                 pos : neg    =      5.9 : 1.0
#                    bride = 1                 pos : neg    =      5.9 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 26
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features3', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'last']
# ----------------
# Total positive words:
# 39
# Top 10 positive words:
# [u'right', u'love', u'win', u'modern', u'helped', u'best', u'lead', u'leading', u'top', u'fans']
# Total positive words:
# 18
# Top 10 positive words:
# [u'criminal', u'risk', u'lost', u'vice', u'concerns', u'rival', u'hard', u'problems', u'crisis', u'bad']
# ****************
# ACCURACY = 0.699544764795
# ****************
# Most Informative Features
#                 positive = True              pos : neg    =      5.9 : 1.0
#                   gained = True              pos : neg    =      5.9 : 1.0
#                     debt = True              neg : pos    =      5.6 : 1.0
#                 criminal = True              neg : pos    =      5.6 : 1.0
#                    clear = True              neg : pos    =      5.3 : 1.0
#                     died = True              neg : pos    =      5.1 : 1.0
#                      win = True              pos : neg    =      4.9 : 1.0
#                     fell = True              neg : pos    =      4.2 : 1.0
#                     lost = True              neg : pos    =      4.0 : 1.0
#                    super = True              pos : neg    =      4.0 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 27
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features2', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# ****************
# ACCURACY = 0.599393019727
# ****************
# Most Informative Features
#                  comment = 1                 neg : pos    =      8.4 : 1.0
#                 declined = 1                 neg : pos    =      7.7 : 1.0
#                    built = 1                 pos : neg    =      7.3 : 1.0
#                      but = 2                 neg : pos    =      7.2 : 1.0
#                        a = 7                 neg : pos    =      7.2 : 1.0
#                     rose = 1                 pos : neg    =      6.6 : 1.0
#                   health = 2                 neg : pos    =      5.9 : 1.0
#                      tax = 2                 neg : pos    =      5.9 : 1.0
#                     debt = 1                 neg : pos    =      5.6 : 1.0
#                    clear = 1                 neg : pos    =      5.3 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 28
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features3', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# Total positive words:
# 34
# Top 10 positive words:
# [u'right', u'love', u'modern', u'helped', u'best', u'lead', u'leading', u'top', u'fans', u'creative']
# Total positive words:
# 16
# Top 10 positive words:
# [u'risk', u'lost', u'vice', u'concerns', u'rival', u'hard', u'problems', u'crisis', u'fell', u'died']
# ****************
# ACCURACY = 0.698027314112
# ****************
# Most Informative Features
#                     debt = True              neg : pos    =      5.6 : 1.0
#                    clear = True              neg : pos    =      5.3 : 1.0
#                     died = True              neg : pos    =      5.1 : 1.0
#                     fell = True              neg : pos    =      4.2 : 1.0
#                     lost = True              neg : pos    =      4.0 : 1.0
#                    super = True              pos : neg    =      4.0 : 1.0
#                 concerns = True              neg : pos    =      3.8 : 1.0
#                   crisis = True              neg : pos    =      3.7 : 1.0
#                    right = True              pos : neg    =      3.6 : 1.0
#                 creative = True              pos : neg    =      2.8 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 29
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features2', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'four', u'woods', u'woody', u'cyprus']
# ----------------
# ****************
# ACCURACY = 0.690440060698
# ****************
# Most Informative Features
#                   losing = 1                 neg : pos    =      9.9 : 1.0
#              controversy = 1                 neg : pos    =      7.2 : 1.0
#                  effects = 1                 neg : pos    =      5.9 : 1.0
#                     debt = 1                 neg : pos    =      5.6 : 1.0
#            investigation = 1                 neg : pos    =      5.2 : 1.0
#                   ground = 1                 neg : pos    =      5.1 : 1.0
#                     jury = 1                 neg : pos    =      5.1 : 1.0
#               threatened = 1                 neg : pos    =      4.6 : 1.0
#                 innocent = 1                 neg : pos    =      4.6 : 1.0
#                    argue = 1                 neg : pos    =      4.6 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 30
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features3', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 0
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'four', u'woods', u'woody', u'cyprus']
# ----------------
# Total positive words:
# 40
# Top 10 positive words:
# [u'golden', u'spiritual', u'willingness', u'awesome', u'logical', u'upscale', u'resilient', u'amusingly', u'avid', u'fashionable']
# Total positive words:
# 55
# Top 10 positive words:
# [u'criticism', u'obsessively', u'scarred', u'obese', u'fake', u'foul', u'antagonistic', u'bumpy', u'illness', u'dismissive']
# ****************
# ACCURACY = 0.705614567527
# ****************
# Most Informative Features
#                   losing = True              neg : pos    =      9.9 : 1.0
#              controversy = True              neg : pos    =      7.2 : 1.0
#                     debt = True              neg : pos    =      5.6 : 1.0
#                 resigned = True              neg : pos    =      4.3 : 1.0
#                lucrative = True              neg : pos    =      3.5 : 1.0
#                     fake = True              neg : pos    =      3.3 : 1.0
#                criticism = True              neg : pos    =      3.3 : 1.0
#                    boost = True              pos : neg    =      2.9 : 1.0
#                    angry = True              neg : pos    =      2.8 : 1.0
#                   strike = True              pos : neg    =      2.5 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 1
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 1
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'last']
# ----------------
# ****************
# ACCURACY = 0.704097116844
# ****************
# Most Informative Features
#                  accused = True              neg : pos    =     26.2 : 1.0
#                  comment = True              neg : pos    =      9.3 : 1.0
#                    force = True              neg : pos    =      7.8 : 1.0
#                     debt = True              neg : pos    =      7.1 : 1.0
#                 declined = True              neg : pos    =      7.1 : 1.0
#                    built = True              pos : neg    =      6.5 : 1.0
#                     rose = True              pos : neg    =      6.3 : 1.0
#                    space = True              pos : neg    =      5.8 : 1.0
#                   gained = True              pos : neg    =      5.8 : 1.0
#                 positive = True              pos : neg    =      5.1 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 2
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 1
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'.', u"'", u'said', u'chief', u'mr.', u'$', u'like', u'would', u'director']
# ----------------
# ****************
# ACCURACY = 0.710166919575
# ****************
# Most Informative Features
#                  accused = True              neg : pos    =     26.2 : 1.0
#                  comment = True              neg : pos    =      9.3 : 1.0
#                    force = True              neg : pos    =      7.8 : 1.0
#                     debt = True              neg : pos    =      7.1 : 1.0
#                 declined = True              neg : pos    =      7.1 : 1.0
#                    built = True              pos : neg    =      6.5 : 1.0
#                     rose = True              pos : neg    =      6.3 : 1.0
#                    space = True              pos : neg    =      5.8 : 1.0
#                   gained = True              pos : neg    =      5.8 : 1.0
#                 positive = True              pos : neg    =      5.1 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 3
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': ['...']}
# majority
#
# iteration: 1
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u"'s", u'executive', u'said', u'chief', u'apple', u'company', u'manager', u'mr.', u'new', u'--']
# ----------------
# ****************
# ACCURACY = 0.705614567527
# ****************
# Most Informative Features
#                  comment = True              neg : pos    =      9.3 : 1.0
#                    force = True              neg : pos    =      7.8 : 1.0
#                     debt = True              neg : pos    =      7.1 : 1.0
#                 declined = True              neg : pos    =      7.1 : 1.0
#                    built = True              pos : neg    =      6.5 : 1.0
#                     rose = True              pos : neg    =      6.3 : 1.0
#                    space = True              pos : neg    =      5.8 : 1.0
#                 positive = True              pos : neg    =      5.1 : 1.0
#                      win = True              pos : neg    =      5.1 : 1.0
#                  charges = True              neg : pos    =      5.1 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 4
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': ['...'], 'stopwords_english': []}
# majority
#
# iteration: 1
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'the', u'of', u'a', u'to', u'in', u'that', u'for', u'is', u'said', u'on']
# ----------------
# ****************
# ACCURACY = 0.707132018209
# ****************
# Most Informative Features
#                  comment = True              neg : pos    =      9.3 : 1.0
#                    force = True              neg : pos    =      7.8 : 1.0
#                     debt = True              neg : pos    =      7.1 : 1.0
#                 declined = True              neg : pos    =      7.1 : 1.0
#                    built = True              pos : neg    =      6.5 : 1.0
#                     rose = True              pos : neg    =      6.3 : 1.0
#                    space = True              pos : neg    =      5.8 : 1.0
#                 positive = True              pos : neg    =      5.1 : 1.0
#                  charges = True              neg : pos    =      5.1 : 1.0
#                 criminal = True              neg : pos    =      4.9 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 5
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': True, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': ['...']}
# majority
#
# iteration: 1
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'.', u"'s", u"'", u'executive', u'said', u'chief', u'apple', u'company', u'manager']
# ----------------
# ****************
# ACCURACY = 0.708649468892
# ****************
# Most Informative Features
#                  comment = True              neg : pos    =      9.3 : 1.0
# ...
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 23
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': ['...'], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 9
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'four', u'woods', u'woody', u'cyprus']
# ----------------
# ****************
# ACCURACY = 0.63277693475
# ****************
# Most Informative Features
#              controversy = True              neg : pos    =      7.3 : 1.0
#                     debt = True              neg : pos    =      7.1 : 1.0
#            investigation = True              neg : pos    =      6.0 : 1.0
#                 channels = True              neg : pos    =      6.0 : 1.0
#                  effects = True              neg : pos    =      6.0 : 1.0
#                     fake = True              neg : pos    =      6.0 : 1.0
#                     jury = True              neg : pos    =      5.2 : 1.0
#                 resigned = True              neg : pos    =      5.2 : 1.0
#                criticism = True              neg : pos    =      4.7 : 1.0
#               threatened = True              neg : pos    =      4.7 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 24
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features1', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 9
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'four', u'woods', u'woody', u'cyprus']
# ----------------
# ****************
# ACCURACY = 0.63277693475
# ****************
# Most Informative Features
#              controversy = True              neg : pos    =      7.3 : 1.0
#                     debt = True              neg : pos    =      7.1 : 1.0
#            investigation = True              neg : pos    =      6.0 : 1.0
#                 channels = True              neg : pos    =      6.0 : 1.0
#                  effects = True              neg : pos    =      6.0 : 1.0
#                     fake = True              neg : pos    =      6.0 : 1.0
#                     jury = True              neg : pos    =      5.2 : 1.0
#                 resigned = True              neg : pos    =      5.2 : 1.0
#                criticism = True              neg : pos    =      4.7 : 1.0
#               threatened = True              neg : pos    =      4.7 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 25
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features2', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 9
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'last']
# ----------------
# ****************
# ACCURACY = 0.66464339909
# ****************
# Most Informative Features
#                  accused = 1                 neg : pos    =     24.6 : 1.0
#                     rose = 1                 pos : neg    =     10.8 : 1.0
#                  comment = 1                 neg : pos    =      9.3 : 1.0
#                    force = 1                 neg : pos    =      7.8 : 1.0
#               government = 2                 neg : pos    =      7.3 : 1.0
#                    built = 1                 pos : neg    =      7.2 : 1.0
#                     debt = 1                 neg : pos    =      7.1 : 1.0
#                 declined = 1                 neg : pos    =      6.8 : 1.0
#                 criminal = 1                 neg : pos    =      6.4 : 1.0
#                    space = 1                 pos : neg    =      6.2 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 26
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': ['...'], 'length': 1000, 'numbers': True, 'document_features': 'document_features3', 'stopwords_domain': ['...'], 'stopwords_english': ['...']}
# majority
#
# iteration: 9
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'said', u'chief', u'mr.', u'like', u'would', u'director', u'one', u'year', u'also', u'last']
# ----------------
# Total positive words:
# 39
# Top 10 positive words:
# [u'right', u'love', u'win', u'modern', u'helped', u'best', u'lead', u'leading', u'top', u'fans']
# Total positive words:
# 18
# Top 10 positive words:
# [u'criminal', u'risk', u'lost', u'vice', u'concerns', u'rival', u'hard', u'problems', u'crisis', u'bad']
# ****************
# ACCURACY = 0.676783004552
# ****************
# Most Informative Features
#                     debt = True              neg : pos    =      7.1 : 1.0
#                      win = True              pos : neg    =      6.2 : 1.0
#                   gained = True              pos : neg    =      6.2 : 1.0
#                 criminal = True              neg : pos    =      5.6 : 1.0
#                     fell = True              neg : pos    =      5.5 : 1.0
#                     died = True              neg : pos    =      4.6 : 1.0
#                   crisis = True              neg : pos    =      4.5 : 1.0
#                    super = True              pos : neg    =      4.2 : 1.0
#                     lost = True              neg : pos    =      3.9 : 1.0
#                    clear = True              neg : pos    =      3.7 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 27
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features2', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 9
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# ****************
# ACCURACY = 0.660091047041
# ****************
# Most Informative Features
#                     rose = 1                 pos : neg    =     10.8 : 1.0
#                  comment = 1                 neg : pos    =      9.3 : 1.0
#               government = 2                 neg : pos    =      7.3 : 1.0
#                    built = 1                 pos : neg    =      7.2 : 1.0
#                     debt = 1                 neg : pos    =      7.1 : 1.0
#                 declined = 1                 neg : pos    =      6.8 : 1.0
#                      tax = 2                 neg : pos    =      6.0 : 1.0
#                       '' = 2                 neg : pos    =      6.0 : 1.0
#                     fell = 1                 neg : pos    =      5.7 : 1.0
#            investigation = 1                 neg : pos    =      5.5 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 28
# {'reverse': False, 'stopwords_domain_in_features': False, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features3', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 9
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u',', u'the', u'.', u'of', u'and', u'a', u'to', u'in', u"'s", u'that']
# ----------------
# Total positive words:
# 34
# Top 10 positive words:
# [u'right', u'love', u'modern', u'helped', u'best', u'lead', u'leading', u'top', u'fans', u'creative']
# Total positive words:
# 16
# Top 10 positive words:
# [u'risk', u'lost', u'vice', u'concerns', u'rival', u'hard', u'problems', u'crisis', u'fell', u'died']
# ****************
# ACCURACY = 0.672230652504
# ****************
# Most Informative Features
#                     debt = True              neg : pos    =      7.1 : 1.0
#                     fell = True              neg : pos    =      5.5 : 1.0
#                     died = True              neg : pos    =      4.6 : 1.0
#                   crisis = True              neg : pos    =      4.5 : 1.0
#                    super = True              pos : neg    =      4.2 : 1.0
#                     lost = True              neg : pos    =      3.9 : 1.0
#                    clear = True              neg : pos    =      3.7 : 1.0
#                    right = True              pos : neg    =      3.3 : 1.0
#                 concerns = True              neg : pos    =      3.1 : 1.0
#                     free = True              pos : neg    =      3.1 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 29
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features2', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 9
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'four', u'woods', u'woody', u'cyprus']
# ----------------
# ****************
# ACCURACY = 0.635811836115
# ****************
# Most Informative Features
#              controversy = 1                 neg : pos    =      7.3 : 1.0
#                     debt = 1                 neg : pos    =      7.1 : 1.0
#                  effects = 1                 neg : pos    =      6.0 : 1.0
#                       '' = 2                 neg : pos    =      6.0 : 1.0
#            investigation = 1                 neg : pos    =      5.5 : 1.0
#                     jury = 1                 neg : pos    =      5.2 : 1.0
#                 resigned = 1                 neg : pos    =      5.2 : 1.0
#                criticism = 1                 neg : pos    =      4.7 : 1.0
#               threatened = 1                 neg : pos    =      4.7 : 1.0
#                   buried = 1                 neg : pos    =      4.7 : 1.0
#
#
#
#
#
#
# =======================================================
# RUNNING THE NaiveBayesClassifier WITH THE NEXT OPTIONS:
#
# Option 30
# {'reverse': False, 'stopwords_domain_in_features': True, 'punctuation': [], 'length': 1000, 'numbers': False, 'document_features': 'document_features3', 'stopwords_domain': [], 'stopwords_english': []}
# majority
#
# iteration: 9
#
# ----------------
# Total features:
# 1000
# Top 10 features:
# [u'third-longest', u'nallen', u'hordes', u'glisson', u"'parties", u'foul', u'four', u'woods', u'woody', u'cyprus']
# ----------------
# Total positive words:
# 40
# Top 10 positive words:
# [u'golden', u'spiritual', u'willingness', u'awesome', u'logical', u'upscale', u'resilient', u'amusingly', u'avid', u'fashionable']
# Total positive words:
# 55
# Top 10 positive words:
# [u'criticism', u'obsessively', u'scarred', u'obese', u'fake', u'foul', u'antagonistic', u'bumpy', u'illness', u'dismissive']
# ****************
# ACCURACY = 0.661608497724
# ****************
# Most Informative Features
#              controversy = True              neg : pos    =      7.3 : 1.0
#                     debt = True              neg : pos    =      7.1 : 1.0
#                     fake = True              neg : pos    =      6.0 : 1.0
#                 resigned = True              neg : pos    =      5.2 : 1.0
#                criticism = True              neg : pos    =      4.7 : 1.0
#                lucrative = True              neg : pos    =      3.6 : 1.0
#                    angry = True              neg : pos    =      2.8 : 1.0
#                 troubled = True              neg : pos    =      2.6 : 1.0
#                   strike = True              pos : neg    =      2.5 : 1.0
#                    staid = True              neg : pos    =      2.0 : 1.0
#
#
#
#
#
#
# **************** BEST RESULT ****************
# BEST OPTION: 12
# {'length': 1000, 'reverse': False, 'document_features': <function document_features1 at 0x7ff0eb6aa8c0>, 'numbers': False, 'stopwords_domain_in_features': False, 'punctuation': '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~', 'stopwords_domain': ['entrepreneur', 'startup', 'new', 'venture', 'manager', 'executive', 'founder', 'wal-mart', 'exxon', 'chevron', 'berkshire', 'hathaway', 'apple', 'samsung', 'phillips', '66', 'general', 'motors', 'ford', 'valero', 'exelon', 'corporation', 'dow', 'chemical', 'conocophillips', 'morgan', 'chase', 'world', 'fuel', 'services', 'illinois', 'tool', 'works', 'boeing', 'intel', 'corporation', 'pepsico', 'tjx', 'companies', 'costco', 'wholesale', 'metlife', 'blackrock', 'at&t', 'johnson', '&', 'johnson', 'abbott', 'laboratories', 'cvs', 'caremark', 'visa', 'cisco', 'systems', 'walt', 'disney', 'company', 'rock', 'tenn', 'company', 'halliburton', 'company', 'alcoa', 'fluor', 'corporation', 'general', 'electric', 'cbre', 'group', 'energy', 'transfer', 'equity', 'express', 'scripts', 'holding', 'hca', 'holdings', 'nrg', 'energy', 'aramark', 'holdings', 'corporation', 'honeywell', 'international', 'nike', 'amazon.com', 'procter', '&', 'gamble', 'unitedhealth', 'group', 'microsoft', 'Google', 'Salesforce', 'SAS', 'Quicken', 'Intuit', 'las', 'vegas', 'sands', 'autonation', '3m', 'company', 'danaher', 'corporation', 'new', 'york', 'life', 'insurance', 'company', 'mcdonalds', 'corporation', 'caterpillar', 'ryder', 'systems', 'd.r.', 'horton', 'stanley', 'black', '&', 'decker', 'archer', 'daniels', 'midland', 'coca-cola', 'company', 'united', 'continental', 'holdings', 'ingram', 'micro', 'chs', 'international', 'paper', 'company', 'mckesson', 'phillip', 'morris', 'international', 'state', 'farm', 'insurance', 'owens', 'corning', 'waste', 'management', 'c.h.', 'robinson', 'worldwide', 'harley-davidson', 'manpower', 'group', 'union', 'pacific', 'r.r', 'donnelley', '&', 'sons', 'company', 'graham', 'holdings', 'company', 'emc', 'corporation', 'mattel', 'united', 'parcel', 'service', 'omnicom', 'group', 'mckinsey', '&', 'company', 'pricewaterhousecoopers', 'intuitive', 'research', 'and', 'tech', 'international', 'bussiness', 'machines', 'formerly', 'BrightTag', 'aka', 'Wright', 'Foods', 'turospree.com', 'nirvanix.com', 'getpostrocket.com', 'votertide.com', 'gamelayers.com', 'unifyo.com', 'lookery.com', 'canv.as', 'blurtt.com', 'manilla.com', 'admaze.ly.com', 'springpad.com', 'ex.fm', 'sambamobile.com', 'qik.com', 'inbloom.org', 'intonow.com', 'getfindit.com', 'inqmobile.com', 'outboxmail.com', 'argylesocial.com', 'iamexec.com', 'stippleit.com', '500px', 'Inc', 'Wajam', 'Keek', 'Inc', 'GuySpy', 'Woozworld', 'TinEye', 'Idee', 'Inc', 'Jigsy', 'Voices.com', 'Snapsort', 'EmpireAvenue', 'Frank', 'and', 'Oak', 'LoginRadius', 'Chango', 'Inc', 'Pure', 'Energies', 'Group', 'Inc', 'Buytopia.ca', 'Smoke', 'NV', 'Inc', 'Just', 'Quality', 'International', 'Inc', 'Sterling', 'Cross', 'Defense', 'Systems', 'Corp', 'Magnet', 'Forensics', 'Inc', 'Greenlife', 'Water', 'Corp', 'Secure', 'Sense', 'Solutions', 'Sandstorm', 'Gold', 'Ltd', 'ScribbleLive', 'Technologies', 'Inc', 'TDot', 'Performance', 'Ltd', 'Redwood', 'Strategic', 'Inc', 'Emcision', 'International', 'Inc', 'Henkaa', 'Inc', 'Whirlscape', 'Inc', 'Bionym', 'Thalmic', 'Labs', 'Recon', 'Instruments', 'Om', 'Malik', 'Technology', 'Affino', 'AnalyzeRE', 'Atomic', 'Reach', 'Cloud', 'Dynamics', 'Exo', 'U', 'Fabric', 'Engine', 'Finmaven', 'Granify', 'InfraDog', 'Introhive', 'Invici', 'Technologies', 'Login', 'Radius', 'mnubo', 'Obero', 'Solutions', 'PeopleInsight', 'Procima', 'Experts', 'reelyActive', 'RtTech', 'Software', 'Seamless', 'Mobile', 'Health', 'Slyce', 'Smart', 'Employee', 'Benefits', 'SweetIQ', 'Thalmic', 'Labs', 'Vena', 'Solutions', 'WestonExprerssions', 'Linkett', '360pi', 'AcademixDirect', 'Inc', 'Adconion', 'Direct', 'Adesto', 'Technologies', 'Corporation', 'Alfresco', 'Aitierre', 'Corporation', 'Altitude', 'Digital', 'Anametrix', 'Aphios', 'Corporation', 'AppDirect',  ...
# ('ACCURACY =', 0.723823975720789)
# *********************************************

# %%
np.array(d_accuracies[12]).mean()
# Out:
# 0.70136570561456746

# %%
np.array(d_accuracies[12]).std()
# Out:
# 0.010768555386470502

# %%
np.array(d_accuracies[16]).mean()
# Out:
# 0.69317147192716244

# %%
np.array(d_accuracies[16]).std()
# Out:
# 0.020311178005161891

# %%
for k in options:
    print('Option {}'.format(k))
    print(np.array(d_accuracies[k]).mean())
    print(np.array(d_accuracies[k]).std())
    print('--------')
# Out:
# Option 1
# 0.691350531108
# 0.0168320784508
# --------
# Option 2
# 0.689226100152
# 0.0150801314098
# --------
# Option 3
# 0.686494688923
# 0.0175027263797
# --------
# Option 4
# 0.701517450683
# 0.0122161848635
# --------
# Option 5
# 0.685584218513
# 0.0158977855584
# --------
# Option 6
# 0.691957511381
# 0.0205948862851
# --------
# Option 7
# 0.699544764795
# 0.0150219953515
# --------
# Option 8
# 0.691198786039
# 0.0191012024305
# --------
# Option 9
# 0.691957511381
# 0.0184730534671
# --------
# Option 10
# 0.690895295903
# 0.016273553167
# --------
# Option 11
# 0.686494688923
# 0.0149943785457
# --------
# Option 12
# 0.701365705615
# 0.0107685553865
# --------
# Option 13
# 0.686949924127
# 0.0186350110829
# --------
# Option 14
# 0.692564491654
# 0.0177249672236
# --------
# Option 15
# 0.698786039454
# 0.013005003861
# --------
# Option 16
# 0.693171471927
# 0.0203111780052
# --------
# Option 17
# 0.658573596358
# 0.021265976378
# --------
# Option 18
# 0.658573596358
# 0.0216735308909
# --------
# Option 19
# 0.658877086495
# 0.0185948087187
# --------
# Option 20
# 0.658877086495
# 0.0189140351452
# --------
# Option 21
# 0.658725341426
# 0.0210532269284
# --------
# Option 22
# 0.659180576631
# 0.0213976688766
# --------
# Option 23
# 0.658118361153
# 0.0172088541773
# --------
# Option 24
# 0.658877086495
# 0.0182195217236
# --------
# Option 25
# 0.669347496206
# 0.0117629347352
# --------
# Option 26
# 0.683459787557
# 0.0183253768005
# --------
# Option 27
# 0.6406676783
# 0.0235454368609
# --------
# Option 28
# 0.680424886191
# 0.0194352202083
# --------
# Option 29
# 0.659484066768
# 0.0206640904771
# --------
# Option 30
# 0.674658573596
# 0.0211378211221
# --------

# %%
import cPickle as pickle

with open("sentiment/nltk_NaiveBayesClassifier_majority.pickle", "wb") as nltk_file:
    pickle.dump(???, nltk_file)
