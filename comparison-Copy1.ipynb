# %%
# %pylab inline

matplotlib.rcParams['figure.figsize'] = (12, 7)
matplotlib.rcParams.update({'figure.autolayout': True})
font = {'size': 12}
matplotlib.rc('font', **font)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import csv
import pandas as pd

# %%
def same_result(row):
    res = False
    if row['norm_score'] < 0 and row['norm_liwc'] < 0:
        res = True
    if row['norm_score'] > 0 and row['norm_liwc'] > 0:
        res = True
    if row['norm_score'] == 0 and row['norm_liwc'] == 0:
        res = True
    return res

# %% [markdown]
# ###a) 1)

# %%
df_a1 = pd.read_csv('results_subtraction_100.csv')
# df_a1 = df_a1[df_a1.norm_liwc!=0]
df_a1 = df_a1[df_a1.norm_score!=0]

# %%
df_a1['same'] = df_a1.apply(same_result, axis=1)
total = df_a1.same.count()
equals = df_a1[df_a1.same == True].count()['same']
different = df_a1[df_a1.same == False].count()['same']
print 'Total:', total
print 'Equals:', equals
print 'Different:', different
print 'Accuracy:', float(equals) * 100 / total
# Out:
# Total: 3869
# Equals: 2669
# Different: 1200
# Accuracy: 68.9842336521

# %%
df_a1[['norm_score', 'norm_liwc']].hist(sharey=True, sharex=True, range=[-1, 1], bins=15)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1c7f7cff90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1c7f54e910>]], dtype=object)
# /home/antonio/.virtualenvs/lexisnexis/local/lib/python2.7/site-packages/matplotlib/figure.py:1653: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
df_a1[['norm_score', 'norm_liwc']].plot(kind='hist', alpha=0.5, color=['b', 'r'], bins=15)

# %%
df_a1[['norm_score', 'norm_liwc']].plot(kind='kde', xlim=[-1, 1])

# %% [markdown]
# ###a) 2)

# %%
df_a2 = pd.read_csv('results_minmax_100.csv')
df_a2 = df_a2[df_a2.norm_liwc!=0]
df_a2 = df_a2[df_a2.norm_score!=0]

# %%
df_a2['same'] = df_a2.apply(same_result, axis=1)
total = df_a2.same.count()
equals = df_a2[df_a2.same == True].count()['same']
different = df_a2[df_a2.same == False].count()['same']
print 'Total:', total
print 'Equals:', equals
print 'Different:', different
print 'Accuracy:', float(equals) * 100 / total
# Out:
# Total: 3869
# Equals: 2669
# Different: 1200
# Accuracy: 68.9842336521

# %%
df_a2[['norm_score', 'norm_liwc']].hist(sharey=True, sharex=True, range=[-1, 1], bins=15)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1c65b21f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1c65aea5d0>]], dtype=object)

# %%
df_a2[['norm_score', 'norm_liwc']].plot(kind='hist', alpha=0.5, color=['b', 'r'], bins=15)

# %%
df_a2[['norm_score', 'norm_liwc']].plot(kind='kde', xlim=[-1, 1])

# %% [markdown]
# ###b) 1)

# %%
df_b1 = pd.read_csv('results_subtraction_minmax.csv')
df_b1 = df_b1[df_b1.norm_liwc!=0]
df_b1 = df_b1[df_b1.norm_score!=0]

# %%
df_b1['same'] = df_b1.apply(same_result, axis=1)
total = df_b1.same.count()
equals = df_b1[df_b1.same == True].count()['same']
different = df_b1[df_b1.same == False].count()['same']
print 'Total:', total
print 'Equals:', equals
print 'Different:', different
print 'Accuracy:', float(equals) * 100 / total
# Out:
# Total: 3869
# Equals: 2669
# Different: 1200
# Accuracy: 68.9842336521

# %%
df_b1[['norm_score', 'norm_liwc']].hist(sharey=True, sharex=True, range=[-1, 1], bins=15)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1c65552f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1c65527590>]], dtype=object)

# %%
df_b1[['norm_score', 'norm_liwc']].plot(kind='hist', alpha=0.5, color=['b', 'r'], bins=15)

# %%
df_b1[['norm_score', 'norm_liwc']].plot(kind='kde', xlim=[-1, 1])

# %% [markdown]
# ###b) 2)

# %%
df_b2 = pd.read_csv('results_minmax_minmax.csv')

# %%
df_b2[df_b2.norm_score==0].count()
# Out:
# #s            1020
# sentence      1020
# score         1020
# liwc          1020
# norm_score    1020
# norm_liwc     1020
# dtype: int64

# %%
# df_b2 = df_b2[df_b2.norm_liwc!=0]
df_b2 = df_b2[df_b2.norm_score!=0]

# %%
df_b2['same'] = df_b2.apply(same_result, axis=1)
total = df_b2.same.count()
equals = df_b2[df_b2.same == True].count()['same']
different = df_b2[df_b2.same == False].count()['same']
print 'Total:', total
print 'Equals:', equals
print 'Different:', different
print 'Accuracy:', float(equals) * 100 / total
# Out:
# Total: 7976
# Equals: 2669
# Different: 5307
# Accuracy: 33.462888666

# %%
df_b2[['norm_score', 'norm_liwc']].hist(sharey=True, sharex=True, range=[-1, 1], bins=15)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1c58899c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1c589f47d0>]], dtype=object)

# %%
df_b2[['norm_score', 'norm_liwc']].plot(kind='hist', alpha=0.5, color=['b', 'r'], bins=15)

# %%
df_b2[['norm_score', 'norm_liwc']].plot(kind='kde', xlim=[-1, 1])

# %% [markdown]
# ###Normal tests

# %%
from statsmodels.stats.diagnostic import normal_ad, kstest_normal

# %% [markdown]
# ####Anderson-Darling

# %%
normal_ad(df_b2['score'])
# Out:
# (33.249109936994955, 0.0)

# %%
normal_ad(df_b2['liwc'])
# Out:
# (91.887550215180909, 0.0)

# %%
df_b2.head()
# Out:
#    #s                                           sentence     score   liwc  \
# 2   3  " And Aim's problem is that many of its larges... -0.125000  10.00
# 3   4  "'Don't be evil,' he cried, while being chased... -0.250000  -7.14
# 5   6  "A sovereign issue would certainly warrant a l... -0.571429   2.63
# 6   7  "An entrepreneur may well be unreasonable beca... -0.666667   7.14
# 8   9  "As a result, Ford expects wholesale volume ne...  0.200000  -3.03
#
#    norm_score  norm_liwc   same
# 2   -0.062500     0.4000  False
# 3   -0.125000    -0.2856   True
# 5   -0.285714     0.1052  False
# 6   -0.333333     0.2856  False
# 8    0.100000    -0.1212  False

# %% [markdown]
# ####KS test

# %%
kstest_normal(df_b2['norm_score'])
# Out:
# (0.099061375253336859, 2.3293056397783205e-103)

# %%
kstest_normal(df_b2['norm_liwc'])
# Out:
# (0.16790880096418526, 8.1248808454573142e-305)

# %%
kstest_normal(df_b2['score'])
# Out:
# (0.099061375253336859, 2.3293056397783205e-103)

# %%
kstest_normal(df_b2['liwc'])
# Out:
# (0.1679088009641852, 8.1248808454591618e-305)

# %%
from scipy.stats.mstats import normaltest

# %% [markdown]
# ####scipy test

# %%
normaltest(df_b2['score'])
# Out:
# (151.21418182695237, 1.4596798857250103e-33)

# %%
normaltest(df_b2['liwc'])
# Out:
# (158.31665028874025, 4.1877060856403724e-35)

# %%
from statsmodels.graphics.gofplots import qqplot

# %%
qqplot(df_b2['liwc'], line='45')

# %%
qqplot(df_b2['score'], line='45')

# %%
from scipy.stats import ks_2samp

# %%
ks_2samp(df_b2['score'], df_b2['liwc'])
# Out:
# (0.7193073145515636, 0.0)

# %% [markdown]
# ###DEMO

# %%
df_runs = pd.read_json('tasks_runs_export.json')
df_runs.head()
# Out:
#    app_id  calibration                     created                finish_time  \
# 0       2          NaN  2015-01-15T20:10:02.754972 2015-01-15 20:10:02.755004
# 1       2          NaN  2015-01-15T20:10:33.135575 2015-01-15 20:10:33.135595
# 2       2          NaN  2015-01-19T05:07:13.067430 2015-01-19 05:07:13.067454
# 3       2          NaN  2015-01-19T15:03:52.019558 2015-01-19 15:03:52.019577
# 4       2          NaN  2015-01-19T15:04:07.983599 2015-01-19 15:04:07.983617
#
#       id info  task_id  timeout  user_id  user_ip
# 0  11153  pos    52763      NaN     1068      NaN
# 1  11154  pos    52764      NaN     1068      NaN
# 2  11155  neg    52765      NaN     1068      NaN
# 3  11156  pos    52763      NaN      870      NaN
# 4  11157  neg    52764      NaN      870      NaN

# %%
df_task = pd.read_json('tasks_export.json')
df_task.head()
# Out:
#    app_id  calibration                     created     id  \
# 0       2            0  2015-01-15T20:07:01.968888  61119
# 1       2            0  2015-01-15T20:07:04.148649  61136
# 2       2            0  2015-01-15T19:49:01.874219  52763
# 3       2            0  2015-01-15T19:55:52.545549  55987
# 4       2            0  2015-01-15T19:55:55.962911  56014
#
#                                                 info  n_answers  priority_0  \
# 0  {u'search_words': u'executive', u'appears_in_s...          3           0
# 1  {u'search_words': u'samsung', u'appears_in_sen...          3           0
# 2  {u'search_words': u'executive', u'appears_in_s...          3           0
# 3  {u'search_words': u'founder', u'appears_in_sen...          3           0
# 4  {u'search_words': u'nike', u'appears_in_senten...          3           0
#
#    quorum      state
# 0       0    ongoing
# 1       0    ongoing
# 2       0    ongoing
# 3       0  completed
# 4       0  completed

# %%
df_user = pd.read_csv('bossa_users.csv')
df_user.head()
# Out:
#    user_id user_name
# 0        2  jzambra3
# 1        3      Dago
# 2        1    versae
# 3        4       123
# 4      206      3655

# %%
df_demo = pd.read_excel('demographics.xlsx', converters={'ID_code': str})
df_demo.head()
# Out:
#             StartDate             EndDate ID_code  Age  Gender  \
# 0 2015-01-19 09:21:14 2015-01-19 10:04:38    4477   18       1
# 1 2015-01-19 09:21:36 2015-01-19 10:04:35    4708   18       1
# 2 2015-01-19 09:22:29 2015-01-19 10:03:53    5245   19       1
# 3 2015-01-19 09:22:39 2015-01-19 10:04:03    5605   18       1
# 4 2015-01-19 09:22:49 2015-01-19 10:03:33    5662   18       1
#
#           Country_Birth Postal_Code Primary_Language  Faculty
# 0                canada         K7P          English        9
# 1                canada         n0n          english        6
# 2                Canada         N6A          English       10
# 3  United Arab Emirates         L3S            Tamil       10
# 4                Canada         N6K          English        9

# %%
df_demographics = pd.merge(df_runs, df_task, left_on='task_id', right_on='id', suffixes=('_runs', '_task'))
df_demographics = df_demographics.drop('id_task', 1)
df_demographics = pd.merge(df_demographics, df_user, on='user_id', suffixes=('', '_user'))
df_demographics = pd.merge(df_demographics, df_demo, left_on='user_name', right_on='ID_code', suffixes=('', '_demo'))
df_demographics = df_demographics.drop('ID_code', 1)
df_demographics.head()
# Out:
#    app_id_runs  calibration_runs                created_runs  \
# 0            2               NaN  2015-01-19T15:03:52.019558
# 1            2               NaN  2015-01-19T15:04:07.983599
# 2            2               NaN  2015-01-19T15:04:14.584194
# 3            2               NaN  2015-01-19T15:04:34.182159
# 4            2               NaN  2015-01-19T15:04:44.380438
#
#                  finish_time  id_runs info_runs  task_id  timeout  user_id  \
# 0 2015-01-19 15:03:52.019577    11156       pos    52763      NaN      870
# 1 2015-01-19 15:04:07.983617    11157       neg    52764      NaN      870
# 2 2015-01-19 15:04:14.584212    11158       pos    52765      NaN      870
# 3 2015-01-19 15:04:34.182193    11161       pos    52766      NaN      870
# 4 2015-01-19 15:04:44.380459    11164       pos    52767      NaN      870
#
#    user_ip   ...      state  user_name           StartDate  \
# 0      NaN   ...    ongoing       5662 2015-01-19 09:22:49
# 1      NaN   ...    ongoing       5662 2015-01-19 09:22:49
# 2      NaN   ...    ongoing       5662 2015-01-19 09:22:49
# 3      NaN   ...    ongoing       5662 2015-01-19 09:22:49
# 4      NaN   ...    ongoing       5662 2015-01-19 09:22:49
#
#               EndDate  Age  Gender  Country_Birth Postal_Code  \
# 0 2015-01-19 10:03:33   18       1         Canada         N6K
# 1 2015-01-19 10:03:33   18       1         Canada         N6K
# 2 2015-01-19 10:03:33   18       1         Canada         N6K
# 3 2015-01-19 10:03:33   18       1         Canada         N6K
# 4 2015-01-19 10:03:33   18       1         Canada         N6K
#
#   Primary_Language Faculty
# 0          English       9
# 1          English       9
# 2          English       9
# 3          English       9
# 4          English       9
#
# [5 rows x 27 columns]

# %%
df_sub = df_demographics[['user_id', 'info_runs', 'Age', 'Gender', 'Country_Birth']]
sentence_ids = pd.Series([x['sentence_id'] for x in df_demographics['info_task']], index=df_sub.index)
df_sub['sentence_id'] = sentence_ids
cols = list(df_sub.columns)
cols[1] = 'polarity'
df_sub.columns = cols
df_sub.head()
# Out:
# /home/antonio/.virtualenvs/lexisnexis/lib/python2.7/site-packages/IPython/kernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#    user_id polarity  Age  Gender Country_Birth sentence_id
# 0      870      pos   18       1        Canada           1
# 1      870      neg   18       1        Canada           2
# 2      870      pos   18       1        Canada           3
# 3      870      pos   18       1        Canada           4
# 4      870      pos   18       1        Canada           5

# %% [markdown]
# ####Normalized list of countries

# %%
# All countries
df_sub.Country_Birth.unique()
# Out:
# array([u'Canada', u'United Arab Emirates', u'Syria', u'canada',
#        u'Australia', u'China', u'Romania', u'Pakistan', u'USA',
#        u'Saudi Arabia', u'India', u'United States', u'CHINA',
#        u"People's republic of China", u'Nigeria', u'china',
#        u'June 26, 1996', u'Japan', u'Singapore', u'Egypt', u'Belarus',
#        u'United States of America', u'Hong Kong, China', u'UAE',
#        u'Sint Maarten', u'France', u'Hong Kong', u'South Korea',
#        u'Moldova', u'Taiwan', u'Korea, South', u'Serbia', u'VIETNAM'], dtype=object)

# %%
# Normailzed countries
def normalize_country(c):
    if c =='canada':
        result = 'Canada'
    elif c == 'United States' or c == 'United States of America':
        result = 'USA'
    elif c == 'CHINA' or c == "People's republic of China" or c == 'china':
        result = 'China'
    elif c == 'Hong Kong, China':
        result = 'Hong Kong'
    elif c == 'UAE':
        result = 'United Arab Emirates'
    elif c == 'Korea, South':
        result = 'South Korea'
    elif c == 'VIETNAM':
        result = 'Vietnam'
    else:
        result = c
    return result

df_norm = pd.DataFrame(df_sub)
df_norm.Country_Birth = df_sub.Country_Birth.apply(normalize_country)
df_norm.Country_Birth.unique()
# Out:
# array([u'Canada', u'United Arab Emirates', u'Syria', u'Australia',
#        u'China', u'Romania', u'Pakistan', u'USA', u'Saudi Arabia',
#        u'India', u'Nigeria', u'June 26, 1996', u'Japan', u'Singapore',
#        u'Egypt', u'Belarus', 'Hong Kong', u'Sint Maarten', u'France',
#        u'South Korea', u'Moldova', u'Taiwan', u'Serbia', 'Vietnam'], dtype=object)

# %% [markdown]
# ####List of countries

# %%
df_norm['Country_Birth'].unique() #list(df_norm['Country_Birth'].unique())
# Out:
# array([u'Canada', u'United Arab Emirates', u'Syria', u'Australia',
#        u'China', u'Romania', u'Pakistan', u'USA', u'Saudi Arabia',
#        u'India', u'Nigeria', u'June 26, 1996', u'Japan', u'Singapore',
#        u'Egypt', u'Belarus', 'Hong Kong', u'Sint Maarten', u'France',
#        u'South Korea', u'Moldova', u'Taiwan', u'Serbia', 'Vietnam'], dtype=object)

# %% [markdown]
# ####Users per country

# %%
df_norm.groupby(['Country_Birth'])['user_id'].nunique()['Canada']
# Out:
# 125

# %% [markdown]
# ####Evaluations per country

# %%
df_norm.groupby(['Country_Birth'])['polarity'].count()['Canada']
# Out:
# 30821

# %% [markdown]
# ####Users by gender per country

# %%
df_norm.groupby(['Country_Birth', 'Gender'])['user_id'].nunique()['Canada']
# Out:
# Gender
# 1    77
# 2    48
# Name: user_id, dtype: int64

# %%
# Males
df_norm.groupby(['Country_Birth', 'Gender'])['user_id'].nunique()['Canada'][1]
# Out:
# 77

# %%
# Females
df_norm.groupby(['Country_Birth', 'Gender'])['user_id'].nunique()['Canada'][2]
# Out:
# 48

# %% [markdown]
# ####Evaluations by gender per country

# %%
df_norm.groupby(['Country_Birth', 'Gender'])['polarity'].count()['Canada']
# Out:
# Gender
# 1    17945
# 2    12876
# Name: polarity, dtype: int64

# %%
# Males
df_norm.groupby(['Country_Birth', 'Gender'])['polarity'].count()['Canada'][1]
# Out:
# 17945

# %%
# Females
df_norm.groupby(['Country_Birth', 'Gender'])['polarity'].count()['Canada'][2]
# Out:
# 12876

# %% [markdown]
# ####Polarity by gender per country

# %%
df_norm.groupby(['Country_Birth', 'Gender', 'polarity'])['sentence_id'].count()['Canada']
# Out:
# Gender  polarity
# 1       neg         4288
#         neu         4299
#         pos         6224
#         vneg        1285
#         vpos        1849
# 2       neg         3413
#         neu         2256
#         pos         5173
#         vneg         789
#         vpos        1245
# Name: sentence_id, dtype: int64

# %%
# Males
df_norm.groupby(['Country_Birth', 'Gender', 'polarity'])['sentence_id'].count()['Canada'][1]
# Out:
# polarity
# neg     4288
# neu     4299
# pos     6224
# vneg    1285
# vpos    1849
# Name: sentence_id, dtype: int64

# %%
# Females
df_norm.groupby(['Country_Birth', 'Gender', 'polarity'])['sentence_id'].count()['Canada'][2]
# Out:
# polarity
# neg     3413
# neu     2256
# pos     5173
# vneg     789
# vpos    1245
# Name: sentence_id, dtype: int64

# %% [markdown]
# ####Pie charts

# %%
country_list = list(df_norm['Country_Birth'].unique())
country_list.remove('June 26, 1996')
print len(country_list), country_list
# Out:
# 23 [u'Canada', u'United Arab Emirates', u'Syria', u'Australia', u'China', u'Romania', u'Pakistan', u'USA', u'Saudi Arabia', u'India', u'Nigeria', u'Japan', u'Singapore', u'Egypt', u'Belarus', 'Hong Kong', u'Sint Maarten', u'France', u'South Korea', u'Moldova', u'Taiwan', u'Serbia', 'Vietnam']

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=len(country_list), ncols=2)
fig.set_figwidth(7)
fig.set_figheight(70)
matplotlib.rcParams['figure.max_open_warning'] = len(country_list) * 2

polarity_by_gender_per_country = df_norm.groupby(['Country_Birth', 'Gender', 'polarity'])['sentence_id'].count()
n_users_by_gender_per_country = df_norm.groupby(['Country_Birth', 'Gender'])['user_id'].nunique()
n_evaluations_by_gender_per_country = df_norm.groupby(['Country_Birth', 'Gender'])['polarity'].count()
counter = 0
for c in country_list:
    for g in [1, 2]:
        ax = axes[counter / 2, counter % 2]
        pol_sr = polarity_by_gender_per_country[c][g]
        if not pol_sr.empty:
            if g == 1:
                gender = 'male'
            else:
                gender = 'female'
            pol_sr.name = ''
            n_users = n_users_by_gender_per_country[c][g]
            n_evaluations = n_evaluations_by_gender_per_country[c][g]
            title = '{}, {}\n#participants: {}, #evaluations: {}'.format(c, gender, n_users, n_evaluations)
            pol_sr.plot(kind='pie', title=title, ax=ax, autopct='%1.0f%%')
        ax.axis('off')
        counter += 1

matplotlib.rcParams['figure.figsize'] = (12, 7)
matplotlib.rcParams['figure.max_open_warning'] = 20

# %%
df_norm['user_id'].nunique()
# Out:
# 190

# %%
matplotlib.rcParams['figure.figsize'] = (10, 10)

n_users_per_country = df_norm[df_norm.Country_Birth != 'June 26, 1996'].groupby(['Country_Birth'])['user_id'].nunique()
n_users_per_country.name = ''
total_users = df_norm['user_id'].nunique()
title='Total #participants: {}\nTotal %participants per country'.format(total_users)
n_users_per_country.plot(kind='pie', title=title, autopct='%1.0f%%', pctdistance=0.9)

matplotlib.rcParams['figure.figsize'] = (12, 7)

# %%
len(df_norm)
# Out:
# 46679

# %%
matplotlib.rcParams['figure.figsize'] = (6, 6)

global_evaluations = df_norm.groupby(['polarity'])['sentence_id'].count()
global_evaluations.name = ''
total_evaluations = len(df_norm)
title='Total #evaluations: {}\nTotal %evaluations'.format(total_evaluations)
global_evaluations.plot(kind='pie', title=title, autopct='%1.0f%%')

matplotlib.rcParams['figure.figsize'] = (12, 7)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks")

rs = np.random.RandomState(4)

pos = rs.randint(-1, 2, (20, 5)).cumsum(axis=1)
pos -= pos[:, 0, np.newaxis]
step = np.tile(range(5), 20)
walk = np.repeat(range(20), 5)

df = pd.DataFrame(np.c_[pos.flat, step, walk],
                  columns=["position", "step", "walk"])

grid = sns.FacetGrid(df, col="walk", hue="walk", col_wrap=5, size=1.5)
grid.map(plt.axhline, y=0, ls=":", c=".5")
grid.map(plt.plot, "step", "position", marker="o", ms=4)
grid.set(xticks=np.arange(5), yticks=[-3, 3],
         xlim=(-.5, 4.5), ylim=(-3.5, 3.5))
grid.fig.tight_layout(w_pad=1)

# %%
import seaborn as sns

# %%
dicti = {'polarity': np.count_nonzero}

dff = pd.pivot_table(df_sub[df_sub.Gender==1][df_sub.Country_Birth=='Canada'], index=['polarity'], values=[], columns=[], aggfunc=dicti)
dff.plot(kind='pie', subplots=True)
dff
ind = dff.unstack()
grid = sns.FacetGrid(df_sub[['Gender', 'polarity', 'Country_Birth']], col="Country_Birth", hue="Country_Birth", col_wrap=5, size=1.5)
# Out:
# /home/antonio/.virtualenvs/lexisnexis/local/lib/python2.7/site-packages/pandas/core/frame.py:1815: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   "DataFrame index.", UserWarning)

# %%
import seaborn as sns

dff = pd.pivot_table(df_sub[df_sub.Gender == 1], index=['user_id'], values=['Country_Birth'], aggfunc=lambda x: len(x.unique()))
sns.violinplot(dff, color="Set3", bw=.2, cut=.6,
               lw=.5, inner="points", inner_kws={"ms": 6})

# %%
q=df_sub.groupby(['Country_Birth', 'Age', 'user_id', 'polarity']).count()

# %%
df2=q.reset_index()[['Country_Birth', 'polarity']]
df2
# Out:
#             Country_Birth polarity
# 0               Australia      neg
# 1               Australia      neu
# 2               Australia      pos
# 3               Australia     vneg
# 4               Australia     vpos
# 5                 Belarus      neg
# 6                 Belarus      neu
# 7                 Belarus      pos
# 8                 Belarus     vneg
# 9                 Belarus     vpos
# 10                 Canada      neg
# 11                 Canada      neu
# 12                 Canada      pos
# 13                 Canada     vneg
# 14                 Canada     vpos
# 15                 Canada      neg
# 16                 Canada      neu
# 17                 Canada      pos
# 18                 Canada     vneg
# 19                 Canada     vpos
# 20                 Canada      neg
# 21                 Canada      pos
# 22                 Canada     vneg
# 23                 Canada     vpos
# 24                 Canada      neg
# 25                 Canada      neu
# 26                 Canada      pos
# 27                 Canada     vneg
# 28                 Canada     vpos
# 29                 Canada      neg
# ..                    ...      ...
# 915                   USA     vneg
# 916                   USA     vpos
# 917                   USA      neg
# 918                   USA      neu
# 919                   USA      pos
# 920                   USA     vpos
# 921                   USA      neg
# 922                   USA      neu
# 923                   USA      pos
# 924                   USA     vneg
# 925                   USA     vpos
# 926  United Arab Emirates      neg
# 927  United Arab Emirates      neu
# 928  United Arab Emirates      pos
# 929  United Arab Emirates     vneg
# 930  United Arab Emirates     vpos
# 931  United Arab Emirates      neg
# 932  United Arab Emirates      neu
# 933  United Arab Emirates      pos
# 934  United Arab Emirates     vneg
# 935  United Arab Emirates     vpos
# 936  United Arab Emirates      neg
# 937  United Arab Emirates      neu
# 938  United Arab Emirates      pos
# 939  United Arab Emirates     vneg
# 940  United Arab Emirates     vpos
# 941               Vietnam      neg
# 942               Vietnam      neu
# 943               Vietnam      pos
# 944               Vietnam     vpos
#
# [945 rows x 2 columns]
