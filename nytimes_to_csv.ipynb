# %% [markdown]
# #CSV builder for The New York Times

# %%
import logging
import math

from blaze import Data, DataFrame
from joblib import Parallel, delayed
from nltk.tokenize import sent_tokenize
from pymongo import MongoClient
from pymongo.errors import BulkWriteError
from slugify import slugify

# %% [markdown]
# ##Logging

# %%
try:
    os.remove('newdb.log')
except:
    pass

# %%
logging.getLogger().handlers = []
logging.getLogger('requests.packages.urllib3').setLevel(logging.WARNING)
logging.basicConfig(filename='newdb.log', level=logging.INFO, format='%(asctime)s %(message)s')

# %%
def write_log(*args, status=None):
    record = '{} ==> {}'.format(args, status)
    logging.info(record)

# %% [markdown]
# ##MongoDB

# %%
client = MongoClient()
client.drop_database('nytimes_csv')
db = client.nytimes3
db_csv = client.nytimes_csv

# %%
def insert_rows(rows):
    try:
        db_csv.rows.insert_many(rows, ordered=False)
    except Exception as e:
        write_log('DB INSERTION EXCEPTION', status='{}'.format(e))

# %%
total = db.articles.count()
percent = math.ceil(total / 100)
count = 0
print('Total documents:', total)
print()

for doc in db.articles.find():
    rows = []
    try:
        # Texts
        common_texts = []
        if doc.get('abstract'):
            common_texts.append(doc['abstract'])
        if doc.get('headline') and isinstance(doc['headline'], dict) and doc['headline'].get('main'):
            common_texts.append(doc['headline']['main'])
        if doc.get('lead_paragraph'):
            common_texts.append(doc['lead_paragraph'])
        # add snippet as variable field

        # Fix fields
        article_id = doc['_id']
        pub_date = doc['pub_date']
        section_name = doc['section_name']
        web_url = doc['web_url']

        # Variable fields
        for term in doc['q_info']:
            texts = list(common_texts)
            q_info = doc['q_info'][term]
            term_category = q_info[0]['term_category']
            search_terms = []
            for info in q_info:
                search_terms.append(info['q']['term'])
                if info['snippet']:
                    texts.append(info['snippet'])

            for text in texts:
                sentences = sent_tokenize(text)
                for sentence in sentences:
                    if any([slugify(search_term) in slugify(sentence) for search_term in search_terms]):
                        term_aux = term.replace('_', '.')
                        sentence_aux = sentence.replace('<strong>', '').replace('</strong>', '').replace(',', '')
                        if article_id and pub_date and section_name and web_url and term_category and term_aux and sentence_aux:
                            row = {
                                'article_id': article_id,
                                'pub_date': pub_date,
                                'section_name': section_name,
                                'web_url': web_url,
                                'term_category': term_category,
                                'term': term_aux,
                                'sentence': sentence_aux,
                            }
                            rows.append(row)
        if rows:
            insert_rows(rows)

        if count % percent == 0:
            percentage = count // percent
            print('{} out of {} processed.'.format(count, total))
            print('{}% completed.'.format(percentage))
            print()
        count +=1

    except Exception as e:
        write_log('DOCUMENT {} PROCESS EXCEPTION'.format(doc), status='{}'.format(e))

print('{} out of {} processed.'.format(total, total))
print('100% completed.')
# Out:
# Total documents: 2965
#
# 0 out of 2965 processed.
# 0% completed.
#
# 30 out of 2965 processed.
# 1% completed.
#
# 60 out of 2965 processed.
# 2% completed.
#
# 90 out of 2965 processed.
# 3% completed.
#
# 120 out of 2965 processed.
# 4% completed.
#
# 150 out of 2965 processed.
# 5% completed.
#
# 180 out of 2965 processed.
# 6% completed.
#
# 210 out of 2965 processed.
# 7% completed.
#
# 240 out of 2965 processed.
# 8% completed.
#
# 270 out of 2965 processed.
# 9% completed.
#
# 300 out of 2965 processed.
# 10% completed.
#
# 330 out of 2965 processed.
# 11% completed.
#
# 360 out of 2965 processed.
# 12% completed.
#
# 390 out of 2965 processed.
# 13% completed.
#
# 420 out of 2965 processed.
# 14% completed.
#
# 450 out of 2965 processed.
# 15% completed.
#
# 480 out of 2965 processed.
# 16% completed.
#
# 510 out of 2965 processed.
# 17% completed.
#
# 540 out of 2965 processed.
# 18% completed.
#
# 570 out of 2965 processed.
# 19% completed.
#
# 600 out of 2965 processed.
# 20% completed.
#
# 630 out of 2965 processed.
# 21% completed.
#
# 660 out of 2965 processed.
# 22% completed.
#
# 690 out of 2965 processed.
# 23% completed.
#
# 720 out of 2965 processed.
# 24% completed.
#
# 750 out of 2965 processed.
# 25% completed.
#
# 780 out of 2965 processed.
# 26% completed.
#
# 810 out of 2965 processed.
# 27% completed.
#
# 840 out of 2965 processed.
# 28% completed.
#
# 870 out of 2965 processed.
# 29% completed.
#
# 900 out of 2965 processed.
# 30% completed.
#
# 930 out of 2965 processed.
# 31% completed.
#
# 960 out of 2965 processed.
# 32% completed.
#
# 990 out of 2965 processed.
# 33% completed.
#
# 1020 out of 2965 processed.
# 34% completed.
#
# 1050 out of 2965 processed.
# 35% completed.
#
# 1080 out of 2965 processed.
# 36% completed.
#
# 1110 out of 2965 processed.
# 37% completed.
#
# 1140 out of 2965 processed.
# 38% completed.
#
# 1170 out of 2965 processed.
# 39% completed.
#
# 1200 out of 2965 processed.
# 40% completed.
#
# 1230 out of 2965 processed.
# 41% completed.
#
# 1260 out of 2965 processed.
# 42% completed.
#
# 1290 out of 2965 processed.
# 43% completed.
#
# 1320 out of 2965 processed.
# 44% completed.
#
# 1350 out of 2965 processed.
# 45% completed.
#
# 1380 out of 2965 processed.
# 46% completed.
#
# 1410 out of 2965 processed.
# 47% completed.
#
# 1440 out of 2965 processed.
# 48% completed.
#
# 1470 out of 2965 processed.
# 49% completed.
#
# 1500 out of 2965 processed.
# 50% completed.
#
# 1530 out of 2965 processed.
# 51% completed.
#
# 1560 out of 2965 processed.
# 52% completed.
#
# 1590 out of 2965 processed.
# 53% completed.
#
# 1620 out of 2965 processed.
# 54% completed.
#
# 1650 out of 2965 processed.
# 55% completed.
#
# 1680 out of 2965 processed.
# 56% completed.
#
# 1710 out of 2965 processed.
# 57% completed.
#
# 1740 out of 2965 processed.
# 58% completed.
#
# 1770 out of 2965 processed.
# 59% completed.
#
# 1800 out of 2965 processed.
# 60% completed.
#
# 1830 out of 2965 processed.
# 61% completed.
#
# 1860 out of 2965 processed.
# 62% completed.
#
# 1890 out of 2965 processed.
# 63% completed.
#
# 1920 out of 2965 processed.
# 64% completed.
#
# 1950 out of 2965 processed.
# 65% completed.
#
# 1980 out of 2965 processed.
# 66% completed.
#
# 2010 out of 2965 processed.
# 67% completed.
#
# 2040 out of 2965 processed.
# 68% completed.
#
# 2070 out of 2965 processed.
# 69% completed.
#
# 2100 out of 2965 processed.
# 70% completed.
#
# 2130 out of 2965 processed.
# 71% completed.
#
# 2160 out of 2965 processed.
# 72% completed.
#
# 2190 out of 2965 processed.
# 73% completed.
#
# 2220 out of 2965 processed.
# 74% completed.
#
# 2250 out of 2965 processed.
# 75% completed.
#
# 2280 out of 2965 processed.
# 76% completed.
#
# 2310 out of 2965 processed.
# 77% completed.
#
# 2340 out of 2965 processed.
# 78% completed.
#
# 2370 out of 2965 processed.
# 79% completed.
#
# 2400 out of 2965 processed.
# 80% completed.
#
# 2430 out of 2965 processed.
# 81% completed.
#
# 2460 out of 2965 processed.
# 82% completed.
#
# 2490 out of 2965 processed.
# 83% completed.
#
# 2520 out of 2965 processed.
# 84% completed.
#
# 2550 out of 2965 processed.
# 85% completed.
#
# 2580 out of 2965 processed.
# 86% completed.
#
# 2610 out of 2965 processed.
# 87% completed.
#
# 2640 out of 2965 processed.
# 88% completed.
#
# 2670 out of 2965 processed.
# 89% completed.
#
# 2700 out of 2965 processed.
# 90% completed.
#
# 2730 out of 2965 processed.
# 91% completed.
#
# 2760 out of 2965 processed.
# 92% completed.
#
# 2790 out of 2965 processed.
# 93% completed.
#
# 2820 out of 2965 processed.
# 94% completed.
#
# 2850 out of 2965 processed.
# 95% completed.
#
# 2880 out of 2965 processed.
# 96% completed.
#
# 2910 out of 2965 processed.
# 97% completed.
#
# 2940 out of 2965 processed.
# 98% completed.
#
# 2965 out of 2965 processed.
# 100% completed.

# %%
# total_rows_df['term'] = total_rows_df['term'].apply(lambda x: x.replace('_', '.'))
# total_rows_df['sentence'] = total_rows_df['sentence'].apply(lambda x: x.replace('<strong>', '').replace('</strong>', ''))
# total_rows_df['sentence'] = total_rows_df['sentence'].apply(lambda x: x.replace(',', '')) # csv delimiter problems

# %%
# total_rows_df.to_csv('total_rows.csv', index=False)

# %%
# print(total_rows_df['term'].value_counts())

# %%
db_csv.rows.count()
# Out:
# 4108
